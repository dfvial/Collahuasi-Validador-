# %%
import random
import numpy as np
from collections import deque
import pandas as pd

# %% [markdown]
# # Parámetros

# %%
#Horizonte de simulacion (Turnos)
Turnos = 1
Reloj = 0
tiempo_aculatamiento = 70/60

# %%
#Se leen las caracteristicas de las palas
dfPalas = pd.read_excel('Informacion Palas.xlsx',  1)
InfoPalas = list(zip(dfPalas[dfPalas.columns[0]].values, dfPalas[dfPalas.columns[1]].values, dfPalas[dfPalas.columns[2]].values, \
                            dfPalas[dfPalas.columns[3]].values, dfPalas[dfPalas.columns[4]].values, \
                            dfPalas[dfPalas.columns[5]].values, dfPalas[dfPalas.columns[6]].values, \
                            dfPalas[dfPalas.columns[7]].values, dfPalas[dfPalas.columns[8]].values))

#Lista de nodos de mineral y esteril
Nodos_Mineral = ["P1", "P2"]
Nodos_Esteril = ["P6", "P7"]
Polvorazos = Nodos_Mineral + Nodos_Esteril


#Número de camiones disponibles
total_camiones = 20

#Lista de stocks/botaderos
#ID, espacios, ubicacion, tiempo_atencion ID=ubicacion?
SoB = ["S1", "S2"]
espacios = 5
tiempo_atencion_stock = 70 #segundos

#Se lee la informacion del chancador
dfChancador = pd.read_excel('Informacion Palas.xlsx',  0)
InfoChancador = list(zip(dfChancador[dfChancador.columns[0]].values, dfChancador[dfChancador.columns[1]].values, dfChancador[dfChancador.columns[2]].values, \
                            dfChancador[dfChancador.columns[3]].values, dfChancador[dfChancador.columns[4]].values, \
                            dfChancador[dfChancador.columns[5]].values, dfChancador[dfChancador.columns[6]].values, \
                            dfChancador[dfChancador.columns[7]].values, dfChancador[dfChancador.columns[8]].values))

# %% [markdown]
# # Dinamico

# %%
def dinamico(destinos, palas):
    return (random.choice(palas), random.choice(destinos))

# %% [markdown]
# # 1. Clases
# ## 1.1. Palas

# %%
class Pala:
    def __init__(self, ID, capacidad, ubicacion, media_recuperacion, media_falla, velocidad, tiempo_aculatado, min_carga, moda_carga, max_carga):
        self.ubicacion = ubicacion #Nodo en que esta ubicada la pala
        self.capacidad = capacidad #Capacidad nominal de excavacion
        self.ID = ID #ID pala
        self.fila = deque() #camiones en fila para se atendidos
        
        self.espacios_aculatamiento = [0, 0] #camiones aculatados 
        self.orden_llegada = deque() #orden de llegada al aculatamiento
        
        self.horas_eventos = {"Recuperacion":99999999, "Caida":9999999, "Inicio Movimiento":99999999, "Fin Movimiento":99999999, "Carga":999999} 
        self.proximo_evento = None #Nombre del evento mas proximo
        self.toneladas_sacadas = {} #Diccionario de tuplas con toneladas sacadas por posicion/nodo y ley
        self.TPH = {} #Diccionario con los resultados del PL
        
        self.media_recuperacion = media_recuperacion
        self.media_falla = media_falla
        self.velocidad = velocidad
        
        self.tiempo_aculatado = tiempo_aculatado
        
        self.min = min_carga
        self.moda = moda_carga
        self.max = max_carga
        
        self.hora_siguiente = 999999999
        self.disponibilidad = True
                     
    def caida(self, Reloj):#Completar comn PL y con Dinamico
        self.estado = 0
        #POR FUERA:
        #Se debe correr el PL y luego el dinámico para todos los camiones en la fila, y en camion hacia la pala
        #for cada camion if camion hacia pala.ID correr dinamico 
        self.horas_eventos["Caida"] = 99999999
        self.horas_eventos["Recuperacion"] = Reloj + self.tiempo_recuperacion()
        if self.horas_eventos["Recuperacion"] > self.horas_eventos["Inicio Movimiento"]:
            self.horas_eventos["Inicio Movimiento"] = self.horas_eventos["Recuperacion"] + 0.0001 #Postergo el movimiento hasta que se arregle la pala
        self.proximo_evento = "Recuperacion"
        return None
    
    def recuperacion(self, Reloj):
        self.estado = 1
        self.horas_eventos["Recuperacion"] = 99999999
        self.horas_eventos["Caida"] = Reloj + self.tiempo_falla()
        self.proximo_evento = min(self.horas_eventos, key=self.horas_eventos.get)
        self.hora_siguiente = self.horas_eventos[self.proximo_evento]
        return None
    
    def disponible(self):
        for espacio in self.espacios_aculatamiento:
            if espacio != 0:
                return True
        return False
    
    def inicio_movimiento(self, Reloj, destino, MTV):
        pass
    
    def fin_movimiento(self, Reloj, Lista_movimientos_agendados):
        pass
       
    def tiempo_recuperacion(self):
        return(np.random.exponential(self.media_recuperacion))
    
    def tiempo_falla(self):
        return(np.random.exponential(self.media_falla))
    
    def hora_proximo_evento(self):
        self.hora_siguiente = min(self.horas_eventos.values())
        return(self.hora_siguiente)
    
    def nombre_proximo_evento(self):
        self.proximo_evento = min(self.horas_eventos, key=self.horas_eventos.get)
        return(self.proximo_evento)
    
    def duracion_atencion(self):
        return(np.random.triangular(self.min, self.moda, self.max))
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# ## 1.2. Camiones

# %%
class Camion:
    def __init__(self, ID):
        self.ID = ID
        self.Nombre = "C"+str(ID)
        self.destino = "CS03"
        self.origen = "CS03"
        self.almuerzo = 0 #0: No almorzo, 1 primera colacion, 2 segunda colacion (solo aplica turno B)
        self.hora_siguiente = 0
        self.descargas = {} #Diccionario que almacena la historia de las descargas: key = (Origen, Destino)| value = toneladas
        self.carga = 0
        #self.aculatandose = False
        self.estado = "Descargando" #Viajando, Aculatandose, Cargando, Descargando, Almorzando, En fila
        self.OD = None
        
    def descargar(self, nuevo_destino, Reloj, TdV):
        self.toneladas = 0
        self.origen = self.destino
        self.destino = nuevo_destino
        if self.carga > 0:
            self.descargas[(self.origen, destino)] = self.carga 
        self.carga = 0
        self.estado = "Viajando"
        self.hora_siguiente = Reloj + TdV
        return None
    
    def cargar(self, toneladas_cargadas, nuevo_destino):
        self.origen = self.destino
        self.destino = nuevo_destino
        self.carga = toneladas_cargadas
        return None
    
    def asignar_destino(self, Reloj, nuevo_destino, MTV):
        self.destino = nuevo_destino
        self.actualizar_estado("Viajando", Reloj + MTV[self.origen][self.destino])
    
    def actualizar_estado(self, Estado, Hora):
        self.estado = Estado 
        self.hora_siguiente = Hora
        
    def nuevo_viaje(self, Estado, Hora):
        self.estado = Estado 
        self.hora_siguiente = Hora
        self.origen = self.OD[0]
        self.destino = self.OD[1]
        
    def comenzar_almuerzo(self, destino, reloj, MTV, tiempo_colacion, almuerzo):
        self.origen = self.destino
        self.destino = destino
        self.estado = "Almorzando"
        self.hora_siguiente = Reloj + MTV[self.origen][self.destino] + tiempo_colacion
        self.almuerzo = almuerzo
        
    def __str__(self):
        return str(self.Nombre)
    def __unicode__(self):
        return str(self.Nombre)
    def __repr__(self):
        return str(self.Nombre)

# %% [markdown]
# ## 1.3. Stock - Botadero

# %%
class Stock:
    
    def __init__(self, ID, espacios, ubicacion, tiempo_atencion, tiempo_aculatado):
        self.ID = ID
        self.fila = deque()
        self.espacios_aculatamiento = [0 for i in range(espacios)]
        self.ubicacion = ubicacion
        self.tiempo_atencion = tiempo_atencion
        self.hora_siguiente = 99999999
        self.tiempo_aculatado = tiempo_aculatado 
    
    def avanzar_fila(self):
        camion = self.fila.popleft()
        return camion
    
    def duracion_atencion(self):
        return(self.tiempo_atencion)
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# ## 1.4. Chancador

# %%
class Chancador:
    
    def __init__(self, ID, ubicacion, media_falla, media_recuperacion, tiempo_aculatado, min_carga, moda_carga, max_carga):
        self.ID = ID
        self.ubicacion = ubicacion
        self.espacios_aculatamiento = [0, 0]
        self.fila = deque()
        self.media_falla = media_falla
        self.media_recuperacion = media_recuperacion
        self.tiempo_aculatado = tiempo_aculatado
        self.min = min_carga
        self.moda = moda_carga
        self.max = max_carga
        self.hora_siguiente = 999999999
        
    def tiempo_recuperacion(self):
        return(np.random.exponential(self.media_recuperacion))
    
    def tiempo_falla(self):
        return(np.random.exponential(self.media_falla))
    
    def hora_proximo_evento(self):
        return(min(horas_eventos.values()))
    
    def duracion_atencion(self):
        return(np.random.triangular(self.min, self.moda, self.max))
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# # 2. Simulación
# ## 2.1. Inicialización

# %%
#Se evalúa que palas estarán operativas y en que condición y se generan las instancias 
L_Entidades = []
#Esteril: 303
#Mineral: 293
D_Palas = {}
D_Entidades = {}
for pala in InfoPalas:
    u = np.random.uniform(0,1)
    
    if 0 <= u and u < pala[3]:
        pass
    
    elif pala[3] <= u and u < 1:#pala[4]
        D_Palas[pala[0]] = Pala(pala[0], "TONELADAS X CARGA", random.choice(Polvorazos), pala[2], pala[1], "velocidad", \
                                pala[8], pala[5], pala[6], pala[7])
        L_Entidades.append(D_Palas[pala[0]])
        D_Entidades[pala[0]] = D_Palas[pala[0]]
       
    else:
        #D_Palas[pala[0]] = Pala(pala[0], "TONELADAS X CARGA", random.choice(Polvorazos), pala[2], pala[1], "velocidad", \
        #                        pala[8], pala[5], pala[6], pala[7]) 
        #D_Palas[pala[0]].recuperacion(0)#Se inicializa el tiempo de la siguiente falla
        #print(pala[0], D_Palas[pala[0]].hora_siguiente)
        #L_Entidades.append(D_Palas[pala[0]])
        #D_Entidades[pala[0]] = D_Palas[pala[0]]
        pass
        
#Se inicializan los camiones
D_Camiones = {}
for i in range(total_camiones):
    D_Camiones[i] = Camion(i)
    L_Entidades.append(D_Camiones[i])
    D_Entidades[i] = D_Camiones[i]


    
#Se inicializan los stocks/botaderos
D_Stocks = {}
for stock in SoB:
    D_Stocks[stock] = Stock(stock, espacios, random.choice(SoB), tiempo_atencion_stock, tiempo_aculatamiento)
    L_Entidades.append(D_Stocks[stock])
    D_Entidades[stock] = D_Stocks[stock]
#print("Stocks y Botaderos :", D_Stocks)    

#Se inicializa el Chancador
D_Chancador ={}
for chancador in InfoChancador:
    D_Chancador[chancador[0]] = Chancador(chancador[0], "CS03", chancador[1], chancador[2], chancador[8], \
                                          chancador[5], chancador[6], chancador[7])
    L_Entidades.append(D_Chancador[chancador[0]])
    D_Entidades[chancador[0]] = D_Chancador[chancador[0]]
    
#print("Chancador: ", D_Chancador)


L_Entidades.sort(key=lambda x: x.hora_siguiente, reverse=False)

# %% [markdown]
# ## 2.2. Matriz de tiempos de viaje

# %%
MTV = {}
Destinos = []
Palas = []

for destino1 in L_Entidades:
    if destino1.__class__.__name__ in ["Stock", "Chancador"]:
        Destinos.append(destino1.ID)
    if destino1.__class__.__name__ == "Pala":
        Palas.append(destino1.ID)
    if destino1.__class__.__name__ in ["Stock", "Chancador", "Pala"]:
        MTV[destino1.ID] = {}
        for destino2 in L_Entidades:
            if destino2.__class__.__name__ in ["Stock", "Chancador", "Pala"] and destino1.__class__.__name__ != destino2.__class__.__name__:
                MTV[destino1.ID][destino2.ID] = random.uniform(20, 40)

# %%
#Identificamos el siguiente evento que va a ocurrir}
TurnoA = True
TurnoB = False
NTurnos = 0

trucks = 0 
while Reloj < 12*60:
    
    NTurnos = int(Reloj/(12*60))
    
    
    if int(Reloj/12)%2 == 0:
        TurnoB = True
        TurnoA = False
    else:
        TurnoA = True
        TurnoB = False

    #Tomamos el primer elemento de la lista de Entidades
    Entidad = L_Entidades[0]
    Reloj = Entidad.hora_siguiente
    print('------------------------------------------------------------')
    print(Entidad, Reloj)
   
    #En caso de que la entidad sea un camion
    if Entidad.__class__.__name__ == "Camion":
        print(Entidad, Entidad.origen, Entidad.destino, Entidad.estado, Reloj)
        if Entidad.estado == "Descargando":#Salida de un stock, botadero o chancador
            #Comienzo de almuerzos
            
            #Almuerzo turno A
            MIT = NTurnos*60*12 #Minuto en que inicio turno
            if (TurnoA and 0 <= Entidad.ID and Entidad.ID <= 40 and Reloj >= (4.5*60 + MIT) and Entidad.almuerzo == 0):
                Entidad.comenzar_almuerzo("CASINO", Reloj, MTV, 60, 1)
                
            if (TurnoA and Entidad.ID > 40 and Reloj >= (6*60 + MIT) and Entidad.almuerzo ==0):
                Entidad.comenzar_almuerzo("CASINO", Reloj, MTV, 60, 1)
            
            #Primera colacion turno B
            if (TurnoB and 0 <= Entidad.ID and Entidad.ID <= 27 and Reloj >= (5*60 + MIT) and Entidad.almuerzo == 0):
                Entidad.comenzar_almuerzo(Entidad.origen, Reloj, MTV, 40, 1)
                
            if (TurnoB and 28 <= Entidad.ID and Entidad.ID <= 54 and Reloj >= (5.5*60 + MIT)and Entidad.almuerzo == 0):
                Entidad.comenzar_almuerzo(Entidad.origen, Reloj, MTV, 40, 1)
                
            if (TurnoB and 55 <= Entidad.ID and Reloj >= (4.5*60 + MIT) and Entidad.almuerzo == 0):
                Entidad.comenzar_almuerzo(Entidad.origen, Reloj, MTV, 40, 1)
                
            #Segunda colacion turno B
            if (TurnoB and 0 <= Entidad.ID and Entidad.ID <= 45 and Reloj >= (9*60 + MIT) and Entidad.almuerzo == 1):
                Entidad.comenzar_almuerzo(Entidad.origen, Reloj, MTV, 20, 2)
                
            if (TurnoB and 46 <= Entidad.ID and Reloj >= (9.5*60 + MIT) and Entidad.almuerzo == 1):
                Entidad.comenzar_almuerzo(Entidad.origen, Reloj, MTV, 20, 2)
            
            #En caso contrario, hay que asignarle un nuevo destino corriendo el dinámico
            else: #Posible fuente de error; probar -- (if Entidad.estado == "Descargando")
                nuevo_destino = dinamico(Destinos, Palas) #Decido hacia donde enviar el camion
                Entidad.OD = nuevo_destino #Guardo el resultado del dinamico - par OD
                print("El resultado del dinamico fue: {}".format(nuevo_destino))
                #Finalizo descarga, actualizo tiempo de sgte evento, y cambio estado a "Viajando", y origen
                Entidad.descargar(nuevo_destino[0], Reloj, MTV[Entidad.destino][nuevo_destino[0]]) 
        
        elif Entidad.estado == "Viajando":
            Destino = D_Entidades[Entidad.destino]
            #print("Entre")
            if len(Destino.fila) > 0:#Reviso si hay fila en el destino
                Destino.fila.append(Entidad)#El camion se pone a la fila
                Entidad.actualizar_estado("En fila", Reloj*99)
                print("Camion {} se pone a la fila {}".format(Entidad, Destino.fila))
            
            if len(Destino.fila) == 0:
                #Se revisa la disponibilidad de espacios de aculatamiento
                if 0 in Destino.espacios_aculatamiento:
                    #Camion comienza a aculatarse
                    try:
                        print("No hay fila, {} se aculata {}".format(Entidad, Destino.orden_llegada))
                    except:
                        pass
                    Entidad.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                    #El camion se ubica en el lugar disponible
                    lugar = 0
                    for espacio in Destino.espacios_aculatamiento:
                        if espacio == 0:
                            Destino.espacios_aculatamiento[lugar] = Entidad
                            if Destino.__class__.__name__ == "Pala":
                                Destino.orden_llegada.append(Entidad)
                                
                                print("Camion aculatandose en {}:{}".format(Destino, Destino.espacios_aculatamiento))
                            break
                        lugar += 1
                else:
                    Destino.fila.append(Entidad)
                    Entidad.actualizar_estado("En fila", Reloj*99)  
                    print("Esta es la fila ahora: {}".format(Destino.fila))
        
        elif Entidad.estado == "Aculatandose":#Termina de aculatarse
            Destino = D_Entidades[Entidad.destino]
            
            if Destino.__class__.__name__ in ["Chancador", "Stock"]:
                Entidad.actualizar_estado("Descargando", Reloj + Destino.duracion_atencion())#Comienza descarga solo
                
            if Destino.__class__.__name__ == "Pala":
                Entidad.actualizar_estado("Cargando", Reloj*99)
                Primero = Destino.orden_llegada.popleft()
                #Reviso si hay alguien mas siendo atendido:
                if Destino.disponibilidad and Entidad == Primero:#Si no hay nadie
                    print("El primero en aculatarse: {}".format(Entidad))
                    Destino.horas_eventos["Carga"] = Reloj + Destino.duracion_atencion()
                    Destino.hora_proximo_evento()#Actualizamos la hora del evento siguiente
                    Destino.disponibilidad = False
                    print("Camion termino de aculatarse y comienza atencion. Fin atencion: {}".format(Destino.horas_eventos["Carga"]))
                else: #Si no hay disponibilidad, se espera a que termine la atencion en el lugar de aculatamiento
                    print("{} No era el primero: {} o la pala no estaba disponible: {}".format(Entidad, Primero, Destino.disponibilidad))
                    pass
                Destino.orden_llegada.insert(0, Primero)
        #elif Entidad.estado == "Cargando":
        #    Destino = D_Entidades[Entidad.destino]
        #    Entidad.cargar(Destino.capacidad, Entidad.OD[1])
        #    Entidad.actualizar_estado("Viajando", Reloj + MTV[Entidad.origen][Entidad.destino])
    
    if Entidad.__class__.__name__ == "Pala":
        
        print(Entidad, Entidad.horas_eventos, Entidad.nombre_proximo_evento())
        if Entidad.nombre_proximo_evento() == "Carga":#Finaliza la carga del camion en atencion
            #Se busca el camion que termino la atencion
            print("Orden de llegada: {}".format(Entidad.orden_llegada))
            Camion = Entidad.orden_llegada.popleft()
            #Despacho al camion:
            i = Entidad.espacios_aculatamiento.index(Camion)
            Entidad.espacios_aculatamiento[i] = 0 
            
            #El camion sale del lugar de aculatamiento
            #Camion.cargar(Entidad.capacidad, Camion.OD[1])
            #Camion.actualizar_estado("Viajando", Reloj + MTV[Camion.origen][Camion.destino])
            Camion.nuevo_viaje("Viajando", MTV[Camion.OD[0]][Camion.OD[1]]+Reloj)
            print("Camion despachado: {}, llega a las: {} a {}".format(Camion, Camion.hora_siguiente, Camion.destino))
            Entidad.disponibilidad = True
            Entidad.horas_eventos["Carga"] = Reloj*99
            Entidad.hora_proximo_evento()
            print("Estado del orden de llegada {}".format(Entidad.orden_llegada))
            #Reviso si quedan camiones por atender
            if len(Entidad.orden_llegada) > 0:
                Camion = Entidad.orden_llegada.pop()
                print(Camion, Camion.estado)
                if Camion.estado == "Cargando":
                    Entidad.disponibilidad = False
                    
                   
                    Entidad.horas_eventos["Carga"] = Reloj + Entidad.duracion_atencion()
                    print("Comienzo a atender a: {} y termino a las {}".format(Camion, Entidad.horas_eventos["Carga"]))
                    Entidad.hora_proximo_evento()
                    print("Proximo evento: {}".format(Entidad.hora_siguiente))
                Entidad.orden_llegada.append(Camion)
            
            print(Entidad.disponibilidad)
            if len(Entidad.fila) > 0:
                Camion = Entidad.fila.popleft()
                Entidad.orden_llegada.append(Camion)
                i = Entidad.espacios_aculatamiento.index(0)
                Entidad.espacios_aculatamiento[i] = Camion
                Camion.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                print("Lugar aculatado: {}".format(Entidad.espacios_aculatamiento))
                print("Fila: {}".format(Entidad.fila))     
    try:        
        print(Entidad, Entidad.hora_siguiente, Entidad.destino, Entidad.estado)  
        print('\n')
    except:
        print(Entidad, Entidad.hora_siguiente)
        print('\n')
    print('------------------------------------------------------------')              
    trucks += 1    
    L_Entidades.sort(key=lambda x: x.hora_siguiente, reverse=False)
# Out:
# ------------------------------------------------------------
# C0 0
# C0 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA6', 'CS03')
# C0 37.23668734998424 PA6 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 0
# C1 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA13', 'S2')
# C1 21.058602228769967 PA13 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 0
# C2 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA9', 'S2')
# C2 32.468468382004616 PA9 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 0
# C3 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA8', 'S2')
# C3 39.82933245726626 PA8 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 0
# C4 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA9', 'CS03')
# C4 32.468468382004616 PA9 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 0
# C5 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA9', 'S2')
# C5 32.468468382004616 PA9 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 0
# C6 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA10', 'S1')
# C6 32.2983935563137 PA10 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 0
# C7 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA8', 'S2')
# C7 39.82933245726626 PA8 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C8 0
# C8 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA12', 'CS03')
# C8 26.009310034447118 PA12 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C9 0
# C9 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA13', 'S1')
# C9 21.058602228769967 PA13 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C10 0
# C10 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA13', 'CS03')
# C10 21.058602228769967 PA13 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C11 0
# C11 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA10', 'CS03')
# C11 32.2983935563137 PA10 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C12 0
# C12 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA13', 'S2')
# C12 21.058602228769967 PA13 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C13 0
# C13 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA21', 'CS03')
# C13 35.09280536350698 PA21 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C14 0
# C14 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA10', 'S2')
# C14 32.2983935563137 PA10 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C15 0
# C15 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA12', 'S2')
# C15 26.009310034447118 PA12 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C16 0
# C16 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA9', 'S1')
# C16 32.468468382004616 PA9 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C17 0
# C17 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA13', 'S1')
# C17 21.058602228769967 PA13 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C18 0
# C18 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA15', 'CS03')
# C18 25.608021535846493 PA15 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C19 0
# C19 CS03 CS03 Descargando 0
# El resultado del dinamico fue: ('PA13', 'S2')
# C19 21.058602228769967 PA13 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C19 21.058602228769967
# C19 CS03 PA13 Viajando 21.058602228769967
# No hay fila, C19 se aculata deque([])
# Camion aculatandose en PA13:[C19, 0]
# C19 22.225268895436635 PA13 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C17 21.058602228769967
# C17 CS03 PA13 Viajando 21.058602228769967
# No hay fila, C17 se aculata deque([C19])
# Camion aculatandose en PA13:[C19, C17]
# C17 22.225268895436635 PA13 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C12 21.058602228769967
# C12 CS03 PA13 Viajando 21.058602228769967
# Esta es la fila ahora: deque([C12])
# C12 2084.8016206482266 PA13 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C10 21.058602228769967
# C10 CS03 PA13 Viajando 21.058602228769967
# Camion C10 se pone a la fila deque([C12, C10])
# C10 2084.8016206482266 PA13 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C9 21.058602228769967
# C9 CS03 PA13 Viajando 21.058602228769967
# Camion C9 se pone a la fila deque([C12, C10, C9])
# C9 2084.8016206482266 PA13 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 21.058602228769967
# C1 CS03 PA13 Viajando 21.058602228769967
# Camion C1 se pone a la fila deque([C12, C10, C9, C1])
# C1 2084.8016206482266 PA13 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C17 22.225268895436635
# C17 CS03 PA13 Aculatandose 22.225268895436635
# C17 No era el primero: C19 o la pala no estaba disponible: True
# C17 2200.301620648227 PA13 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C19 22.225268895436635
# C19 CS03 PA13 Aculatandose 22.225268895436635
# El primero en aculatarse: C19
# Camion termino de aculatarse y comienza atencion. Fin atencion: 24.294905488890382
# C19 2200.301620648227 PA13 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 24.294905488890382
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 24.294905488890382} Carga
# Orden de llegada: deque([C19, C17])
# Camion despachado: C19, llega a las: 51.81659177095144 a S2
# Estado del orden de llegada deque([C17])
# C17 Cargando
# Comienzo a atender a: C17 y termino a las 25.289631807935606
# Proximo evento: 25.289631807935606
# False
# Lugar aculatado: [C12, C17]
# Fila: deque([C10, C9, C1])
# PA13 25.289631807935606
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 25.289631807935606
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 25.289631807935606} Carga
# Orden de llegada: deque([C17, C12])
# Camion despachado: C17, llega a las: 58.41883568242206 a S1
# Estado del orden de llegada deque([C12])
# C12 Aculatandose
# True
# Lugar aculatado: [C12, C10]
# Fila: deque([C9, C1])
# PA13 2503.673548985625
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C12 25.46157215555705
# C12 CS03 PA13 Aculatandose 25.46157215555705
# El primero en aculatarse: C12
# Camion termino de aculatarse y comienza atencion. Fin atencion: 26.93560786112631
# C12 2520.695643400148 PA13 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C18 25.608021535846493
# C18 CS03 PA15 Viajando 25.608021535846493
# No hay fila, C18 se aculata deque([])
# Camion aculatandose en PA15:[C18, 0]
# C18 26.77468820251316 PA15 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C15 26.009310034447118
# C15 CS03 PA12 Viajando 26.009310034447118
# No hay fila, C15 se aculata deque([])
# Camion aculatandose en PA12:[C15, 0]
# C15 27.175976701113786 PA12 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C8 26.009310034447118
# C8 CS03 PA12 Viajando 26.009310034447118
# No hay fila, C8 se aculata deque([C15])
# Camion aculatandose en PA12:[C15, C8]
# C8 27.175976701113786 PA12 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C10 26.456298474602274
# C10 CS03 PA13 Aculatandose 26.456298474602274
# C10 No era el primero: C12 o la pala no estaba disponible: False
# C10 2619.173548985625 PA13 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C18 26.77468820251316
# C18 CS03 PA15 Aculatandose 26.77468820251316
# El primero en aculatarse: C18
# Camion termino de aculatarse y comienza atencion. Fin atencion: 32.60674499395206
# C18 2650.694132048803 PA15 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 26.93560786112631
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 26.93560786112631} Carga
# Orden de llegada: deque([C12, C10])
# Camion despachado: C12, llega a las: 54.45729414318737 a S2
# Estado del orden de llegada deque([C10])
# C10 Cargando
# Comienzo a atender a: C10 y termino a las 28.364793953727975
# Proximo evento: 28.364793953727975
# False
# Lugar aculatado: [C9, C10]
# Fila: deque([C1])
# PA13 28.364793953727975
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C8 27.175976701113786
# C8 CS03 PA12 Aculatandose 27.175976701113786
# C8 No era el primero: C15 o la pala no estaba disponible: True
# C8 2690.4216934102647 PA12 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C15 27.175976701113786
# C15 CS03 PA12 Aculatandose 27.175976701113786
# El primero en aculatarse: C15
# Camion termino de aculatarse y comienza atencion. Fin atencion: 29.29160341919176
# C15 2690.4216934102647 PA12 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C9 28.10227452779298
# C9 CS03 PA13 Aculatandose 28.10227452779298
# C9 No era el primero: C10 o la pala no estaba disponible: False
# C9 2782.125178251505 PA13 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 28.364793953727975
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 28.364793953727975} Carga
# Orden de llegada: deque([C10, C9])
# Camion despachado: C10, llega a las: 48.93370269486631 a CS03
# Estado del orden de llegada deque([C9])
# C9 Cargando
# Comienzo a atender a: C9 y termino a las 30.11249081617685
# Proximo evento: 30.11249081617685
# False
# Lugar aculatado: [C9, C1]
# Fila: deque([])
# PA13 30.11249081617685
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA12 29.29160341919176
# PA12 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 29.29160341919176} Carga
# Orden de llegada: deque([C15, C8])
# Camion despachado: C15, llega a las: 64.29646012253866 a S2
# Estado del orden de llegada deque([C8])
# C8 Cargando
# Comienzo a atender a: C8 y termino a las 31.17159933907002
# Proximo evento: 31.17159933907002
# False
# PA12 31.17159933907002
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 29.531460620394643
# C1 CS03 PA13 Aculatandose 29.531460620394643
# C1 No era el primero: C9 o la pala no estaba disponible: False
# C1 2923.6146014190695 PA13 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 30.11249081617685
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 30.11249081617685} Carga
# Orden de llegada: deque([C9, C1])
# Camion despachado: C9, llega a las: 63.24169469066331 a S1
# Estado del orden de llegada deque([C1])
# C1 Cargando
# Comienzo a atender a: C1 y termino a las 31.2950588010315
# Proximo evento: 31.2950588010315
# False
# PA13 31.2950588010315
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA12 31.17159933907002
# PA12 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 31.17159933907002} Carga
# Orden de llegada: deque([C8])
# Camion despachado: C8, llega a las: 63.3074968356166 a CS03
# Estado del orden de llegada deque([])
# True
# PA12 3085.988334567932
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 31.2950588010315
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 31.2950588010315} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega a las: 58.816745083092556 a S2
# Estado del orden de llegada deque([])
# True
# PA13 3098.210821302119
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C14 32.2983935563137
# C14 CS03 PA10 Viajando 32.2983935563137
# No hay fila, C14 se aculata deque([])
# Camion aculatandose en PA10:[C14, 0]
# C14 33.46506022298036 PA10 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C11 32.2983935563137
# C11 CS03 PA10 Viajando 32.2983935563137
# No hay fila, C11 se aculata deque([C14])
# Camion aculatandose en PA10:[C14, C11]
# C11 33.46506022298036 PA10 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 32.2983935563137
# C6 CS03 PA10 Viajando 32.2983935563137
# Esta es la fila ahora: deque([C6])
# C6 3197.540962075056 PA10 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C16 32.468468382004616
# C16 CS03 PA9 Viajando 32.468468382004616
# No hay fila, C16 se aculata deque([])
# Camion aculatandose en PA9:[C16, 0]
# C16 33.63513504867128 PA9 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 32.468468382004616
# C5 CS03 PA9 Viajando 32.468468382004616
# No hay fila, C5 se aculata deque([C16])
# Camion aculatandose en PA9:[C16, C5]
# C5 33.63513504867128 PA9 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 32.468468382004616
# C4 CS03 PA9 Viajando 32.468468382004616
# Esta es la fila ahora: deque([C4])
# C4 3214.378369818457 PA9 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 32.468468382004616
# C2 CS03 PA9 Viajando 32.468468382004616
# Camion C2 se pone a la fila deque([C4, C2])
# C2 3214.378369818457 PA9 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA15 32.60674499395206
# PA15 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 32.60674499395206} Carga
# Orden de llegada: deque([C18])
# Camion despachado: C18, llega a las: 68.76231417170212 a CS03
# Estado del orden de llegada deque([])
# True
# PA15 3228.067754401254
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C11 33.46506022298036
# C11 CS03 PA10 Aculatandose 33.46506022298036
# C11 No era el primero: C14 o la pala no estaba disponible: True
# C11 3313.040962075056 PA10 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C14 33.46506022298036
# C14 CS03 PA10 Aculatandose 33.46506022298036
# El primero en aculatarse: C14
# Camion termino de aculatarse y comienza atencion. Fin atencion: 35.176313591957495
# C14 3313.040962075056 PA10 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 33.63513504867128
# C5 CS03 PA9 Aculatandose 33.63513504867128
# C5 No era el primero: C16 o la pala no estaba disponible: True
# C5 3329.8783698184566 PA9 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C16 33.63513504867128
# C16 CS03 PA9 Aculatandose 33.63513504867128
# El primero en aculatarse: C16
# Camion termino de aculatarse y comienza atencion. Fin atencion: 34.925536964447396
# C16 3329.8783698184566 PA9 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA9 34.925536964447396
# PA9 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 34.925536964447396} Carga
# Orden de llegada: deque([C16, C5])
# Camion despachado: C16, llega a las: 62.6624623834567 a S1
# Estado del orden de llegada deque([C5])
# C5 Cargando
# Comienzo a atender a: C5 y termino a las 36.81276119601493
# Proximo evento: 36.81276119601493
# False
# Lugar aculatado: [C4, C5]
# Fila: deque([C2])
# PA9 36.81276119601493
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C13 35.09280536350698
# C13 CS03 PA21 Viajando 35.09280536350698
# No hay fila, C13 se aculata deque([])
# Camion aculatandose en PA21:[C13, 0]
# C13 36.25947203017365 PA21 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA10 35.176313591957495
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 35.176313591957495} Carga
# Orden de llegada: deque([C14, C11])
# Camion despachado: C14, llega a las: 73.3485834195366 a S2
# Estado del orden de llegada deque([C11])
# C11 Cargando
# Comienzo a atender a: C11 y termino a las 37.64026572580336
# Proximo evento: 37.64026572580336
# False
# Lugar aculatado: [C6, C11]
# Fila: deque([])
# PA10 37.64026572580336
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 36.09220363111406
# C4 CS03 PA9 Aculatandose 36.09220363111406
# C4 No era el primero: C5 o la pala no estaba disponible: False
# C4 3573.1281594802917 PA9 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C13 36.25947203017365
# C13 CS03 PA21 Aculatandose 36.25947203017365
# El primero en aculatarse: C13
# Camion termino de aculatarse y comienza atencion. Fin atencion: 37.855197073156354
# C13 3589.687730987191 PA21 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 36.34298025862416
# C6 CS03 PA10 Aculatandose 36.34298025862416
# C6 No era el primero: C11 o la pala no estaba disponible: False
# C6 3597.955045603792 PA10 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA9 36.81276119601493
# PA9 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 36.81276119601493} Carga
# Orden de llegada: deque([C5, C4])
# Camion despachado: C5, llega a las: 75.91963712763686 a S2
# Estado del orden de llegada deque([C4])
# C4 Cargando
# Comienzo a atender a: C4 y termino a las 38.902029922958256
# Proximo evento: 38.902029922958256
# False
# Lugar aculatado: [C4, C2]
# Fila: deque([])
# PA9 38.902029922958256
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 37.23668734998424
# C0 CS03 PA6 Viajando 37.23668734998424
# No hay fila, C0 se aculata deque([])
# Camion aculatandose en PA6:[C0, 0]
# C0 38.4033540166509 PA6 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA10 37.64026572580336
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 37.64026572580336} Carga
# Orden de llegada: deque([C11, C6])
# Camion despachado: C11, llega a las: 65.97149487371371 a CS03
# Estado del orden de llegada deque([C6])
# C6 Cargando
# Comienzo a atender a: C6 y termino a las 39.44330619239823
# Proximo evento: 39.44330619239823
# False
# PA10 39.44330619239823
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA21 37.855197073156354
# PA21 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 37.855197073156354} Carga
# Orden de llegada: deque([C13])
# Camion despachado: C13, llega a las: 69.46672537739336 a CS03
# Estado del orden de llegada deque([])
# True
# PA21 3747.664510242479
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 37.9794278626816
# C2 CS03 PA9 Aculatandose 37.9794278626816
# C2 No era el primero: C4 o la pala no estaba disponible: False
# C2 3759.963358405478 PA9 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 38.4033540166509
# C0 CS03 PA6 Aculatandose 38.4033540166509
# El primero en aculatarse: C0
# Camion termino de aculatarse y comienza atencion. Fin atencion: 41.148438589928006
# C0 3801.932047648439 PA6 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA9 38.902029922958256
# PA9 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 38.902029922958256} Carga
# Orden de llegada: deque([C4, C2])
# Camion despachado: C4, llega a las: 72.0332602009592 a CS03
# Estado del orden de llegada deque([C2])
# C2 Cargando
# Comienzo a atender a: C2 y termino a las 40.89372285633076
# Proximo evento: 40.89372285633076
# False
# PA9 40.89372285633076
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA10 39.44330619239823
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 39.44330619239823} Carga
# Orden de llegada: deque([C6])
# Camion despachado: C6, llega a las: 59.846643217008506 a S1
# Estado del orden de llegada deque([])
# True
# PA10 3904.887313047425
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 39.82933245726626
# C7 CS03 PA8 Viajando 39.82933245726626
# No hay fila, C7 se aculata deque([])
# Camion aculatandose en PA8:[C7, 0]
# C7 40.995999123932926 PA8 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 39.82933245726626
# C3 CS03 PA8 Viajando 39.82933245726626
# No hay fila, C3 se aculata deque([C7])
# Camion aculatandose en PA8:[C7, C3]
# C3 40.995999123932926 PA8 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA9 40.89372285633076
# PA9 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 40.89372285633076} Carga
# Orden de llegada: deque([C2])
# Camion despachado: C2, llega a las: 80.00059878795268 a S2
# Estado del orden de llegada deque([])
# True
# PA9 4048.4785627767455
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 40.995999123932926
# C3 CS03 PA8 Aculatandose 40.995999123932926
# C3 No era el primero: C7 o la pala no estaba disponible: True
# C3 4058.6039132693595 PA8 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 40.995999123932926
# C7 CS03 PA8 Aculatandose 40.995999123932926
# El primero en aculatarse: C7
# Camion termino de aculatarse y comienza atencion. Fin atencion: 43.154397443898816
# C7 4058.6039132693595 PA8 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA6 41.148438589928006
# PA6 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 41.148438589928006} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega a las: 78.79303763150455 a CS03
# Estado del orden de llegada deque([])
# True
# PA6 4073.6954204028725
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA8 43.154397443898816
# PA8 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 43.154397443898816} Carga
# Orden de llegada: deque([C7, C3])
# Camion despachado: C7, llega a las: 78.9748284158979 a S2
# Estado del orden de llegada deque([C3])
# C3 Cargando
# Comienzo a atender a: C3 y termino a las 44.9082796755282
# Proximo evento: 44.9082796755282
# False
# PA8 44.9082796755282
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA8 44.9082796755282
# PA8 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 44.9082796755282} Carga
# Orden de llegada: deque([C3])
# Camion despachado: C3, llega a las: 80.7287106475273 a S2
# Estado del orden de llegada deque([])
# True
# PA8 4445.919687877292
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C10 48.93370269486631
# C10 PA13 CS03 Viajando 48.93370269486631
# C10 50.10036936153298 CS03 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C10 50.10036936153298
# C10 PA13 CS03 Aculatandose 50.10036936153298
# C10 51.96350012841429 CS03 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C19 51.81659177095144
# C19 PA13 S2 Viajando 51.81659177095144
# C19 52.983258437618105 S2 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C10 51.96350012841429
# C10 PA13 CS03 Descargando 51.96350012841429
# El resultado del dinamico fue: ('PA21', 'S2')
# C10 87.05630549192128 PA21 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C19 52.983258437618105
# C19 PA13 S2 Aculatandose 52.983258437618105
# C19 122.9832584376181 S2 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C12 54.45729414318737
# C12 PA13 S2 Viajando 54.45729414318737
# C12 55.62396080985403 S2 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C12 55.62396080985403
# C12 PA13 S2 Aculatandose 55.62396080985403
# C12 125.62396080985403 S2 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C17 58.41883568242206
# C17 PA13 S1 Viajando 58.41883568242206
# C17 59.58550234908873 S1 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 58.816745083092556
# C1 PA13 S2 Viajando 58.816745083092556
# C1 59.98341174975922 S2 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C17 59.58550234908873
# C17 PA13 S1 Aculatandose 59.58550234908873
# C17 129.58550234908873 S1 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 59.846643217008506
# C6 PA10 S1 Viajando 59.846643217008506
# C6 61.01330988367517 S1 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 59.98341174975922
# C1 PA13 S2 Aculatandose 59.98341174975922
# C1 129.98341174975923 S2 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 61.01330988367517
# C6 PA10 S1 Aculatandose 61.01330988367517
# C6 131.01330988367516 S1 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C16 62.6624623834567
# C16 PA9 S1 Viajando 62.6624623834567
# C16 63.82912905012336 S1 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C9 63.24169469066331
# C9 PA13 S1 Viajando 63.24169469066331
# C9 64.40836135732998 S1 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C8 63.3074968356166
# C8 PA12 CS03 Viajando 63.3074968356166
# C8 64.47416350228326 CS03 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C16 63.82912905012336
# C16 PA9 S1 Aculatandose 63.82912905012336
# C16 133.82912905012336 S1 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C15 64.29646012253866
# C15 PA12 S2 Viajando 64.29646012253866
# C15 65.46312678920533 S2 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C9 64.40836135732998
# C9 PA13 S1 Aculatandose 64.40836135732998
# C9 134.40836135732997 S1 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C8 64.47416350228326
# C8 PA12 CS03 Aculatandose 64.47416350228326
# C8 65.92996586686641 CS03 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C15 65.46312678920533
# C15 PA12 S2 Aculatandose 65.46312678920533
# C15 135.46312678920532 S2 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C8 65.92996586686641
# C8 PA12 CS03 Descargando 65.92996586686641
# El resultado del dinamico fue: ('PA8', 'CS03')
# C8 105.75929832413267 PA8 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C11 65.97149487371371
# C11 PA10 CS03 Viajando 65.97149487371371
# Esta es la fila ahora: deque([C11])
# C11 6531.177992497657 CS03 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C18 68.76231417170212
# C18 PA15 CS03 Viajando 68.76231417170212
# Camion C18 se pone a la fila deque([C11, C18])
# C18 6807.46910299851 CS03 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C13 69.46672537739336
# C13 PA21 CS03 Viajando 69.46672537739336
# Camion C13 se pone a la fila deque([C11, C18, C13])
# C13 6877.205812361943 CS03 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 72.0332602009592
# C4 PA9 CS03 Viajando 72.0332602009592
# Camion C4 se pone a la fila deque([C11, C18, C13, C4])
# C4 7131.292759894961 CS03 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C14 73.3485834195366
# C14 PA10 S2 Viajando 73.3485834195366
# C14 74.51525008620327 S2 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C14 74.51525008620327
# C14 PA10 S2 Aculatandose 74.51525008620327
# C14 144.51525008620325 S2 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 75.91963712763686
# C5 PA9 S2 Viajando 75.91963712763686
# Esta es la fila ahora: deque([C5])
# C5 7516.0440756360495 S2 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 78.79303763150455
# C0 PA6 CS03 Viajando 78.79303763150455
# Camion C0 se pone a la fila deque([C11, C18, C13, C4, C0])
# C0 7800.5107255189505 CS03 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 78.9748284158979
# C7 PA8 S2 Viajando 78.9748284158979
# Camion C7 se pone a la fila deque([C5, C7])
# C7 7818.508013173892 S2 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 80.00059878795268
# C2 PA9 S2 Viajando 80.00059878795268
# Camion C2 se pone a la fila deque([C5, C7, C2])
# C2 7920.0592800073155 S2 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 80.7287106475273
# C3 PA8 S2 Viajando 80.7287106475273
# Camion C3 se pone a la fila deque([C5, C7, C2, C3])
# C3 7992.142354105202 S2 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C10 87.05630549192128
# C10 CS03 PA21 Viajando 87.05630549192128
# No hay fila, C10 se aculata deque([])
# Camion aculatandose en PA21:[C10, 0]
# C10 88.22297215858795 PA21 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C10 88.22297215858795
# C10 CS03 PA21 Aculatandose 88.22297215858795
# El primero en aculatarse: C10
# Camion termino de aculatarse y comienza atencion. Fin atencion: 89.97329941817112
# C10 8734.074243700206 PA21 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA21 89.97329941817112
# PA21 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 89.97329941817112} Carga
# Orden de llegada: deque([C10])
# Camion despachado: C10, llega a las: 115.96168008138642 a S2
# Estado del orden de llegada deque([])
# True
# PA21 8907.356642398941
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C8 105.75929832413267
# C8 CS03 PA8 Viajando 105.75929832413267
# No hay fila, C8 se aculata deque([])
# Camion aculatandose en PA8:[C8, 0]
# C8 106.92596499079934 PA8 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C8 106.92596499079934
# C8 CS03 PA8 Aculatandose 106.92596499079934
# El primero en aculatarse: C8
# Camion termino de aculatarse y comienza atencion. Fin atencion: 109.10397015710312
# C8 10585.670534089135 PA8 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA8 109.10397015710312
# PA8 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 109.10397015710312} Carga
# Orden de llegada: deque([C8])
# Camion despachado: C8, llega a las: 138.29918940651257 a CS03
# Estado del orden de llegada deque([])
# True
# PA8 10801.29304555321
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C10 115.96168008138642
# C10 PA21 S2 Viajando 115.96168008138642
# Camion C10 se pone a la fila deque([C5, C7, C2, C3, C10])
# C10 11480.206328057255 S2 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C19 122.9832584376181
# C19 PA13 S2 Descargando 122.9832584376181
# El resultado del dinamico fue: ('PA15', 'S2')
# C19 154.8797380759076 PA15 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C12 125.62396080985403
# C12 PA13 S2 Descargando 125.62396080985403
# El resultado del dinamico fue: ('PA13', 'CS03')
# C12 163.15094908339756 PA13 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C17 129.58550234908873
# C17 PA13 S1 Descargando 129.58550234908873
# El resultado del dinamico fue: ('PA6', 'S2')
# C17 165.48126487477154 PA6 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 129.98341174975923
# C1 PA13 S2 Descargando 129.98341174975923
# El resultado del dinamico fue: ('PA8', 'CS03')
# C1 158.73295715024165 PA8 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 131.01330988367516
# C6 PA10 S1 Descargando 131.01330988367516
# El resultado del dinamico fue: ('PA6', 'S1')
# C6 166.90907240935798 PA6 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C16 133.82912905012336
# C16 PA9 S1 Descargando 133.82912905012336
# El resultado del dinamico fue: ('PA10', 'CS03')
# C16 154.3022912055271 PA10 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C9 134.40836135732997
# C9 PA13 S1 Descargando 134.40836135732997
# El resultado del dinamico fue: ('PA9', 'S2')
# C9 162.42628645962998 PA9 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C15 135.46312678920532
# C15 PA12 S2 Descargando 135.46312678920532
# El resultado del dinamico fue: ('PA6', 'S2')
# C15 166.27176802564065 PA6 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C8 138.29918940651257
# C8 PA8 CS03 Viajando 138.29918940651257
# Camion C8 se pone a la fila deque([C11, C18, C13, C4, C0, C8])
# C8 13691.619751244743 CS03 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C14 144.51525008620325
# C14 PA10 S2 Descargando 144.51525008620325
# El resultado del dinamico fue: ('PA9', 'CS03')
# C14 183.22738689989728 PA9 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C16 154.3022912055271
# C16 S1 PA10 Viajando 154.3022912055271
# No hay fila, C16 se aculata deque([])
# Camion aculatandose en PA10:[C16, 0]
# C16 155.46895787219376 PA10 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C19 154.8797380759076
# C19 S2 PA15 Viajando 154.8797380759076
# No hay fila, C19 se aculata deque([])
# Camion aculatandose en PA15:[C19, 0]
# C19 156.04640474257425 PA15 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C16 155.46895787219376
# C16 S1 PA10 Aculatandose 155.46895787219376
# El primero en aculatarse: C16
# Camion termino de aculatarse y comienza atencion. Fin atencion: 157.91351201822118
# C16 15391.426829347181 PA10 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C19 156.04640474257425
# C19 S2 PA15 Aculatandose 156.04640474257425
# El primero en aculatarse: C19
# Camion termino de aculatarse y comienza atencion. Fin atencion: 160.65492285729096
# C19 15448.594069514851 PA15 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA10 157.91351201822118
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 157.91351201822118} Carga
# Orden de llegada: deque([C16])
# Camion despachado: C16, llega a las: 186.24474116613152 a CS03
# Estado del orden de llegada deque([])
# True
# PA10 15633.437689803897
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 158.73295715024165
# C1 S2 PA8 Viajando 158.73295715024165
# No hay fila, C1 se aculata deque([])
# Camion aculatandose en PA8:[C1, 0]
# C1 159.8996238169083 PA8 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 159.8996238169083
# C1 S2 PA8 Aculatandose 159.8996238169083
# El primero en aculatarse: C1
# Camion termino de aculatarse y comienza atencion. Fin atencion: 161.7052457952136
# C1 15830.062757873922 PA8 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA15 160.65492285729096
# PA15 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 160.65492285729096} Carga
# Orden de llegada: deque([C19])
# Camion despachado: C19, llega a las: 185.8060691673963 a S2
# Estado del orden de llegada deque([])
# True
# PA15 15904.837362871805
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA8 161.7052457952136
# PA8 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 161.7052457952136} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega a las: 190.90046504462305 a CS03
# Estado del orden de llegada deque([])
# True
# PA8 16008.819333726147
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C9 162.42628645962998
# C9 S1 PA9 Viajando 162.42628645962998
# No hay fila, C9 se aculata deque([])
# Camion aculatandose en PA9:[C9, 0]
# C9 163.59295312629663 PA9 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C12 163.15094908339756
# C12 S2 PA13 Viajando 163.15094908339756
# No hay fila, C12 se aculata deque([])
# Camion aculatandose en PA13:[C12, 0]
# C12 164.31761575006422 PA13 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C9 163.59295312629663
# C9 S1 PA9 Aculatandose 163.59295312629663
# El primero en aculatarse: C9
# Camion termino de aculatarse y comienza atencion. Fin atencion: 165.47314686994184
# C9 16195.702359503366 PA9 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C12 164.31761575006422
# C12 S2 PA13 Aculatandose 164.31761575006422
# El primero en aculatarse: C12
# Camion termino de aculatarse y comienza atencion. Fin atencion: 165.21439080196052
# C12 16267.443959256358 PA13 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 165.21439080196052
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 165.21439080196052} Carga
# Orden de llegada: deque([C12])
# Camion despachado: C12, llega a las: 185.78329954309885 a CS03
# Estado del orden de llegada deque([])
# True
# PA13 16356.224689394092
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA9 165.47314686994184
# PA9 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 165.47314686994184} Carga
# Orden de llegada: deque([C9])
# Camion despachado: C9, llega a las: 204.58002280156376 a S2
# Estado del orden de llegada deque([])
# True
# PA9 16381.841540124242
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C17 165.48126487477154
# C17 S1 PA6 Viajando 165.48126487477154
# No hay fila, C17 se aculata deque([])
# Camion aculatandose en PA6:[C17, 0]
# C17 166.6479315414382 PA6 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C15 166.27176802564065
# C15 S2 PA6 Viajando 166.27176802564065
# No hay fila, C15 se aculata deque([C17])
# Camion aculatandose en PA6:[C17, C15]
# C15 167.4384346923073 PA6 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C17 166.6479315414382
# C17 S1 PA6 Aculatandose 166.6479315414382
# El primero en aculatarse: C17
# Camion termino de aculatarse y comienza atencion. Fin atencion: 168.5183345983869
# C17 16498.145222602383 PA6 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 166.90907240935798
# C6 S1 PA6 Viajando 166.90907240935798
# Esta es la fila ahora: deque([C6])
# C6 16523.99816852644 PA6 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C15 167.4384346923073
# C15 S2 PA6 Aculatandose 167.4384346923073
# C15 No era el primero: C17 o la pala no estaba disponible: False
# C15 16576.405034538424 PA6 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA6 168.5183345983869
# PA6 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 168.5183345983869} Carga
# Orden de llegada: deque([C17, C15])
# Camion despachado: C17, llega a las: 207.4523212799031 a S2
# Estado del orden de llegada deque([C15])
# C15 Cargando
# Comienzo a atender a: C15 y termino a las 170.08789200221204
# Proximo evento: 170.08789200221204
# False
# Lugar aculatado: [C6, C15]
# Fila: deque([])
# PA6 170.08789200221204
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 169.68500126505356
# C6 S1 PA6 Aculatandose 169.68500126505356
# C6 No era el primero: C15 o la pala no estaba disponible: False
# C6 16798.8151252403 PA6 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA6 170.08789200221204
# PA6 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 170.08789200221204} Carga
# Orden de llegada: deque([C15, C6])
# Camion despachado: C15, llega a las: 209.02187868372823 a S2
# Estado del orden de llegada deque([C6])
# C6 Cargando
# Comienzo a atender a: C6 y termino a las 172.84209014851487
# Proximo evento: 172.84209014851487
# False
# PA6 172.84209014851487
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA6 172.84209014851487
# PA6 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 172.84209014851487} Carga
# Orden de llegada: deque([C6])
# Camion despachado: C6, llega a las: 204.4189536531381 a S1
# Estado del orden de llegada deque([])
# True
# PA6 17111.366924702972
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C14 183.22738689989728
# C14 S2 PA9 Viajando 183.22738689989728
# No hay fila, C14 se aculata deque([])
# Camion aculatandose en PA9:[C14, 0]
# C14 184.39405356656394 PA9 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C14 184.39405356656394
# C14 S2 PA9 Aculatandose 184.39405356656394
# El primero en aculatarse: C14
# Camion termino de aculatarse y comienza atencion. Fin atencion: 186.8255322766763
# C14 18255.01130308983 PA9 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C12 185.78329954309885
# C12 PA13 CS03 Viajando 185.78329954309885
# Camion C12 se pone a la fila deque([C11, C18, C13, C4, C0, C8, C12])
# C12 18392.546654766786 CS03 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C19 185.8060691673963
# C19 PA15 S2 Viajando 185.8060691673963
# Camion C19 se pone a la fila deque([C5, C7, C2, C3, C10, C19])
# C19 18394.80084757223 S2 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C16 186.24474116613152
# C16 PA10 CS03 Viajando 186.24474116613152
# Camion C16 se pone a la fila deque([C11, C18, C13, C4, C0, C8, C12, C16])
# C16 18438.22937544702 CS03 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA9 186.8255322766763
# PA9 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 186.8255322766763} Carga
# Orden de llegada: deque([C14])
# Camion despachado: C14, llega a las: 219.95676255467725 a CS03
# Estado del orden de llegada deque([])
# True
# PA9 18495.727695390953
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 190.90046504462305
# C1 PA8 CS03 Viajando 190.90046504462305
# Camion C1 se pone a la fila deque([C11, C18, C13, C4, C0, C8, C12, C16, C1])
# C1 18899.146039417683 CS03 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 204.4189536531381
# C6 PA6 S1 Viajando 204.4189536531381
# C6 205.58562031980475 S1 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C9 204.58002280156376
# C9 PA9 S2 Viajando 204.58002280156376
# Camion C9 se pone a la fila deque([C5, C7, C2, C3, C10, C19, C9])
# C9 20253.42225735481 S2 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 205.58562031980475
# C6 PA6 S1 Aculatandose 205.58562031980475
# C6 275.5856203198048 S1 Descargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C17 207.4523212799031
# C17 PA6 S2 Viajando 207.4523212799031
# Camion C17 se pone a la fila deque([C5, C7, C2, C3, C10, C19, C9, C17])
# C17 20537.779806710405 S2 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C15 209.02187868372823
# C15 PA6 S2 Viajando 209.02187868372823
# Camion C15 se pone a la fila deque([C5, C7, C2, C3, C10, C19, C9, C17, C15])
# C15 20693.165989689096 S2 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C14 219.95676255467725
# C14 PA9 CS03 Viajando 219.95676255467725
# Camion C14 se pone a la fila deque([C11, C18, C13, C4, C0, C8, C12, C16, C1, C14])
# C14 21775.71949291305 CS03 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 275.5856203198048
# C6 PA6 S1 Descargando 275.5856203198048
# El resultado del dinamico fue: ('PA6', 'S1')
# C6 311.4813828454876 PA6 Viajando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 311.4813828454876
# C6 S1 PA6 Viajando 311.4813828454876
# No hay fila, C6 se aculata deque([])
# Camion aculatandose en PA6:[C6, 0]
# C6 312.6480495121543 PA6 Aculatandose
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 312.6480495121543
# C6 S1 PA6 Aculatandose 312.6480495121543
# El primero en aculatarse: C6
# Camion termino de aculatarse y comienza atencion. Fin atencion: 315.2251594752891
# C6 30952.156901703274 PA6 Cargando
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA6 315.2251594752891
# PA6 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 315.2251594752891} Carga
# Orden de llegada: deque([C6])
# Camion despachado: C6, llega a las: 346.8020229799123 a S1
# Estado del orden de llegada deque([])
# True
# PA6 31207.290788053622
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 346.8020229799123
# C6 PA6 S1 Viajando 346.8020229799123
# Esta es la fila ahora: deque([C6])
# C6 34333.400275011314 S1 En fila
#
#
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA12 3085.988334567932
# PA12 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 3085.988334567932} Carga
# Orden de llegada: deque([])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-d06cf2a04a74> in <module>
#     126             #Se busca el camion que termino la atencion
#     127             print("Orden de llegada: {}".format(Entidad.orden_llegada))
# --> 128             Camion = Entidad.orden_llegada.popleft()
#     129             #Despacho al camion:
#     130             i = Entidad.espacios_aculatamiento.index(Camion)
#
# IndexError: pop from an empty deque

# %%
C18 25.207152898055735
C18 CS03 PA11 Aculatandose 25.207152898055735
Camion termino de aculatarse y comienza atencion. Fin atencion: 26.431309474589128
C18 2495.508136907518 PA11 Cargando

# %%
a = deque()
a.append(1)
a.append(2)
a.popleft()
