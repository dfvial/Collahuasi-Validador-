# %%
import random
import numpy as np
from collections import deque
import pandas as pd

# %% [markdown]
# # Parámetros

# %%
#Horizonte de simulacion (Turnos)
Turnos = 1
Reloj = 0
tiempo_aculatamiento = 70/60

# %%
#Se leen las caracteristicas de las palas
dfPalas = pd.read_excel('Informacion Palas.xlsx',  1)
InfoPalas = list(zip(dfPalas[dfPalas.columns[0]].values, dfPalas[dfPalas.columns[1]].values, dfPalas[dfPalas.columns[2]].values, \
                            dfPalas[dfPalas.columns[3]].values, dfPalas[dfPalas.columns[4]].values, \
                            dfPalas[dfPalas.columns[5]].values, dfPalas[dfPalas.columns[6]].values, \
                            dfPalas[dfPalas.columns[7]].values, dfPalas[dfPalas.columns[8]].values))

#Lista de nodos de mineral y esteril
Nodos_Mineral = ["P1", "P2"]
Nodos_Esteril = ["P6", "P7"]
Polvorazos = Nodos_Mineral + Nodos_Esteril


#Número de camiones disponibles
total_camiones = 2

#Lista de stocks/botaderos
#ID, espacios, ubicacion, tiempo_atencion ID=ubicacion?
SoB = ["S1", "S2"]
espacios = 5
tiempo_atencion_stock = 70 #segundos

#Se lee la informacion del chancador
dfChancador = pd.read_excel('Informacion Palas.xlsx',  0)
InfoChancador = list(zip(dfChancador[dfChancador.columns[0]].values, dfChancador[dfChancador.columns[1]].values, dfChancador[dfChancador.columns[2]].values, \
                            dfChancador[dfChancador.columns[3]].values, dfChancador[dfChancador.columns[4]].values, \
                            dfChancador[dfChancador.columns[5]].values, dfChancador[dfChancador.columns[6]].values, \
                            dfChancador[dfChancador.columns[7]].values, dfChancador[dfChancador.columns[8]].values))

# %% [markdown]
# # Dinamico

# %%
def dinamico(destinos, palas):
    return (random.choice(palas), random.choice(destinos))

# %% [markdown]
# # 1. Clases
# ## 1.1. Palas

# %%
class Pala:
    def __init__(self, ID, capacidad, ubicacion, media_recuperacion, media_falla, velocidad, tiempo_aculatado, min_carga, moda_carga, max_carga):
        self.ubicacion = ubicacion #Nodo en que esta ubicada la pala
        self.capacidad = capacidad #Capacidad nominal de excavacion
        self.ID = ID #ID pala
        self.fila = deque() #camiones en fila para se atendidos
        
        self.espacios_aculatamiento = [0, 0] #camiones aculatados 
        self.orden_llegada = deque() #orden de llegada al aculatamiento
        
        self.horas_eventos = {"Recuperacion":99999999, "Caida":9999999, "Inicio Movimiento":99999999, "Fin Movimiento":99999999, "Carga":999999} 
        self.proximo_evento = None #Nombre del evento mas proximo
        self.toneladas_sacadas = {} #Diccionario de tuplas con toneladas sacadas por posicion/nodo y ley
        self.TPH = {} #Diccionario con los resultados del PL
        
        self.media_recuperacion = media_recuperacion
        self.media_falla = media_falla
        self.velocidad = velocidad
        
        self.tiempo_aculatado = tiempo_aculatado
        
        self.min = min_carga
        self.moda = moda_carga
        self.max = max_carga
        
        self.hora_siguiente = 999999999
        self.disponibilidad = True
                     
    def caida(self, Reloj):#Completar comn PL y con Dinamico
        self.estado = 0
        #POR FUERA:
        #Se debe correr el PL y luego el dinámico para todos los camiones en la fila, y en camion hacia la pala
        #for cada camion if camion hacia pala.ID correr dinamico 
        self.horas_eventos["Caida"] = 99999999
        self.horas_eventos["Recuperacion"] = Reloj + self.tiempo_recuperacion()
        if self.horas_eventos["Recuperacion"] > self.horas_eventos["Inicio Movimiento"]:
            self.horas_eventos["Inicio Movimiento"] = self.horas_eventos["Recuperacion"] + 0.0001 #Postergo el movimiento hasta que se arregle la pala
        self.proximo_evento = "Recuperacion"
        return None
    
    def recuperacion(self, Reloj):
        self.estado = 1
        self.horas_eventos["Recuperacion"] = 99999999
        self.horas_eventos["Caida"] = Reloj + self.tiempo_falla()
        self.proximo_evento = min(self.horas_eventos, key=self.horas_eventos.get)
        self.hora_siguiente = self.horas_eventos[self.proximo_evento]
        return None
    
    def disponible(self):
        for espacio in self.espacios_aculatamiento:
            if espacio != 0:
                return True
        return False
    
    def inicio_movimiento(self, Reloj, destino, MTV):
        pass
    
    def fin_movimiento(self, Reloj, Lista_movimientos_agendados):
        pass
       
    def tiempo_recuperacion(self):
        return(np.random.exponential(self.media_recuperacion))
    
    def tiempo_falla(self):
        return(np.random.exponential(self.media_falla))
    
    def hora_proximo_evento(self):
        self.hora_siguiente = min(self.horas_eventos.values())
        return(self.hora_siguiente)
    
    def nombre_proximo_evento(self):
        self.proximo_evento = min(self.horas_eventos, key=self.horas_eventos.get)
        return(self.proximo_evento)
    
    def duracion_atencion(self):
        return(np.random.triangular(self.min, self.moda, self.max))
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# ## 1.2. Camiones

# %%
class Camion:
    def __init__(self, ID):
        self.ID = ID
        self.Nombre = "C"+str(ID)
        self.destino = "CS03"
        self.origen = "CS03"
        self.almuerzo = 0 #0: No almorzo, 1 primera colacion, 2 segunda colacion (solo aplica turno B)
        self.hora_siguiente = 0
        self.descargas = {} #Diccionario que almacena la historia de las descargas: key = (Origen, Destino)| value = toneladas
        self.carga = 0
        #self.aculatandose = False
        self.estado = "Descargando" #Viajando, Aculatandose, Cargando, Descargando, Almorzando, En fila
        self.OD = None
        
    def descargar(self, nuevo_destino, Reloj, TdV):
        self.toneladas = 0
        self.origen = self.destino
        self.destino = nuevo_destino
        if self.carga > 0:
            self.descargas[(self.origen, destino)] = self.carga 
        self.carga = 0
        self.estado = "Viajando"
        self.hora_siguiente = Reloj + TdV
        return None
    
    def cargar(self, toneladas_cargadas, nuevo_destino):
        self.origen = self.destino
        self.destino = nuevo_destino
        self.carga = toneladas_cargadas
        return None
    
    def asignar_destino(self, Reloj, nuevo_destino, MTV):
        self.destino = nuevo_destino
        self.actualizar_estado("Viajando", Reloj + MTV[self.origen][self.destino])
    
    def actualizar_estado(self, Estado, Hora):
        self.estado = Estado 
        self.hora_siguiente = Hora
        
    def comenzar_almuerzo(self, destino, reloj, MTV, tiempo_colacion, almuerzo):
        self.origen = self.destino
        self.destino = destino
        self.estado = "Almorzando"
        self.hora_siguiente = Reloj + MTV[self.origen][self.destino] + tiempo_colacion
        self.almuerzo = almuerzo
        
    def __str__(self):
        return str(self.Nombre)
    def __unicode__(self):
        return str(self.Nombre)
    def __repr__(self):
        return str(self.Nombre)

# %% [markdown]
# ## 1.3. Stock - Botadero

# %%
class Stock:
    
    def __init__(self, ID, espacios, ubicacion, tiempo_atencion, tiempo_aculatado):
        self.ID = ID
        self.fila = deque()
        self.espacios_aculatamiento = [0 for i in range(espacios)]
        self.ubicacion = ubicacion
        self.tiempo_atencion = tiempo_atencion
        self.hora_siguiente = 99999999
        self.tiempo_aculatado = tiempo_aculatado 
    
    def avanzar_fila(self):
        camion = self.fila.pop()
        return camion
    
    def duracion_atencion(self):
        return(self.tiempo_atencion)
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# ## 1.4. Chancador

# %%
class Chancador:
    
    def __init__(self, ID, ubicacion, media_falla, media_recuperacion, tiempo_aculatado, min_carga, moda_carga, max_carga):
        self.ID = ID
        self.ubicacion = ubicacion
        self.espacios_aculatamiento = [0, 0]
        self.fila = deque()
        self.media_falla = media_falla
        self.media_recuperacion = media_recuperacion
        self.tiempo_aculatado = tiempo_aculatado
        self.min = min_carga
        self.moda = moda_carga
        self.max = max_carga
        self.hora_siguiente = 999999999
        
    def tiempo_recuperacion(self):
        return(np.random.exponential(self.media_recuperacion))
    
    def tiempo_falla(self):
        return(np.random.exponential(self.media_falla))
    
    def hora_proximo_evento(self):
        return(min(horas_eventos.values()))
    
    def duracion_atencion(self):
        return(np.random.triangular(self.min, self.moda, self.max))
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# # 2. Simulación
# ## 2.1. Inicialización

# %%
#Se evalúa que palas estarán operativas y en que condición y se generan las instancias 
L_Entidades = []
#Esteril: 303
#Mineral: 293
D_Palas = {}
D_Entidades = {}
for pala in InfoPalas:
    u = np.random.uniform(0,1)
    
    if 0 <= u and u < pala[3]:
        pass
    
    elif pala[3] <= u and u < 1:#pala[4]
        D_Palas[pala[0]] = Pala(pala[0], "TONELADAS X CARGA", random.choice(Polvorazos), pala[2], pala[1], "velocidad", \
                                pala[8], pala[5], pala[6], pala[7])
        L_Entidades.append(D_Palas[pala[0]])
        D_Entidades[pala[0]] = D_Palas[pala[0]]
       
    else:
        #D_Palas[pala[0]] = Pala(pala[0], "TONELADAS X CARGA", random.choice(Polvorazos), pala[2], pala[1], "velocidad", \
        #                        pala[8], pala[5], pala[6], pala[7]) 
        #D_Palas[pala[0]].recuperacion(0)#Se inicializa el tiempo de la siguiente falla
        #print(pala[0], D_Palas[pala[0]].hora_siguiente)
        #L_Entidades.append(D_Palas[pala[0]])
        #D_Entidades[pala[0]] = D_Palas[pala[0]]
        pass
        
#Se inicializan los camiones
D_Camiones = {}
for i in range(total_camiones):
    D_Camiones[i] = Camion(i)
    L_Entidades.append(D_Camiones[i])
    D_Entidades[i] = D_Camiones[i]


    
#Se inicializan los stocks/botaderos
D_Stocks = {}
for stock in SoB:
    D_Stocks[stock] = Stock(stock, espacios, random.choice(SoB), tiempo_atencion_stock, tiempo_aculatamiento)
    L_Entidades.append(D_Stocks[stock])
    D_Entidades[stock] = D_Stocks[stock]
#print("Stocks y Botaderos :", D_Stocks)    

#Se inicializa el Chancador
D_Chancador ={}
for chancador in InfoChancador:
    D_Chancador[chancador[0]] = Chancador(chancador[0], "CS03", chancador[1], chancador[2], chancador[8], \
                                          chancador[5], chancador[6], chancador[7])
    L_Entidades.append(D_Chancador[chancador[0]])
    D_Entidades[chancador[0]] = D_Chancador[chancador[0]]
    
#print("Chancador: ", D_Chancador)


L_Entidades.sort(key=lambda x: x.hora_siguiente, reverse=False)

# %% [markdown]
# ## 2.2. Matriz de tiempos de viaje

# %%
MTV = {}
Destinos = []
Palas = []

for destino1 in L_Entidades:
    if destino1.__class__.__name__ in ["Stock", "Chancador"]:
        Destinos.append(destino1.ID)
    if destino1.__class__.__name__ == "Pala":
        Palas.append(destino1.ID)
    if destino1.__class__.__name__ in ["Stock", "Chancador", "Pala"]:
        MTV[destino1.ID] = {}
        for destino2 in L_Entidades:
            if destino2.__class__.__name__ in ["Stock", "Chancador", "Pala"] and destino1.__class__.__name__ != destino2.__class__.__name__:
                MTV[destino1.ID][destino2.ID] = random.uniform(20, 40)

# %%
#Identificamos el siguiente evento que va a ocurrir}
TurnoA = True
TurnoB = False
NTurnos = 0

trucks = 0 
while trucks < 81:
    
    NTurnos = int(Reloj/(12*60))
    
    
    if int(Reloj/12)%2 == 0:
        TurnoB = True
        TurnoA = False
    else:
        TurnoA = True
        TurnoB = False

    #Tomamos el primer elemento de la lista de Entidades
    Entidad = L_Entidades[0]
    Reloj = Entidad.hora_siguiente

    print(Entidad, Reloj)
    print('------------------------------------------------------------')
    #En caso de que la entidad sea un camion
    if Entidad.__class__.__name__ == "Camion":
        print(Entidad, Entidad.origen, Entidad.destino, Entidad.estado, Reloj)
        if Entidad.estado == "Descargando":#Salida de un stock, botadero o chancador
            #Comienzo de almuerzos
            
            #Almuerzo turno A
            MIT = NTurnos*60*12 #Minuto en que inicio turno
            if (TurnoA and 0 <= Entidad.ID and Entidad.ID <= 40 and Reloj >= (4.5*60 + MIT) and Entidad.almuerzo == 0):
                Entidad.comenzar_almuerzo("CASINO", Reloj, MTV, 60, 1)
                
            if (TurnoA and Entidad.ID > 40 and Reloj >= (6*60 + MIT) and Entidad.almuerzo ==0):
                Entidad.comenzar_almuerzo("CASINO", Reloj, MTV, 60, 1)
            
            #Primera colacion turno B
            if (TurnoB and 0 <= Entidad.ID and Entidad.ID <= 27 and Reloj >= (5*60 + MIT) and Entidad.almuerzo == 0):
                Entidad.comenzar_almuerzo(Entidad.origen, Reloj, MTV, 40, 1)
                
            if (TurnoB and 28 <= Entidad.ID and Entidad.ID <= 54 and Reloj >= (5.5*60 + MIT)and Entidad.almuerzo == 0):
                Entidad.comenzar_almuerzo(Entidad.origen, Reloj, MTV, 40, 1)
                
            if (TurnoB and 55 <= Entidad.ID and Reloj >= (4.5*60 + MIT) and Entidad.almuerzo == 0):
                Entidad.comenzar_almuerzo(Entidad.origen, Reloj, MTV, 40, 1)
                
            #Segunda colacion turno B
            if (TurnoB and 0 <= Entidad.ID and Entidad.ID <= 45 and Reloj >= (9*60 + MIT) and Entidad.almuerzo == 1):
                Entidad.comenzar_almuerzo(Entidad.origen, Reloj, MTV, 20, 2)
                
            if (TurnoB and 46 <= Entidad.ID and Reloj >= (9.5*60 + MIT) and Entidad.almuerzo == 1):
                Entidad.comenzar_almuerzo(Entidad.origen, Reloj, MTV, 20, 2)
            
            #En caso contrario, hay que asignarle un nuevo destino corriendo el dinámico
            else: #Posible fuente de error; probar -- (if Entidad.estado == "Descargando")
                nuevo_destino = dinamico(Destinos, Palas) #Decido hacia donde enviar el camion
                Entidad.OD = nuevo_destino #Guardo el resultado del dinamico - par OD
                #Finalizo descarga, actualizo tiempo de sgte evento, y cambio estado a "Viajando"
                Entidad.descargar(nuevo_destino[0], Reloj, MTV[Entidad.origen][nuevo_destino[0]]) 
        
        elif Entidad.estado == "Viajando":
            Destino = D_Entidades[Entidad.destino]
            #print("Entre")
            if len(Destino.fila) > 0:#Reviso si hay fila en el destino
                Destino.fila.append(Entidad)#El camion se pone a la fila
                Entidad.actualizar_estado("En fila", Reloj*99)
            
            if len(Destino.fila) == 0:
                #Se revisa la disponibilidad de espacios de aculatamiento
                if 0 in Destino.espacios_aculatamiento:
                    #Camion comienza a aculatarse
                    print("Espacio de aculatamiento: {}".format(Destino.orden_llegada))
                    Entidad.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                    #El camion se ubica en el lugar disponible
                    lugar = 0
                    for espacio in Destino.espacios_aculatamiento:
                        if espacio == 0:
                            Destino.espacios_aculatamiento[lugar] = Entidad
                            if Destino.__class__.__name__ == "Pala":
                                Destino.orden_llegada.append(Entidad)
                                
                                print("Camion aculatandose en {}:{}".format(Destino, Destino.orden_llegada))
                            break
                        lugar += 1
                else:
                    Destino.fila.append(Entidad)
                    Entidad.actualizar_estado("En fila", Reloj*99)            
        
        elif Entidad.estado == "Aculatandose":#Termina de aculatarse
            Destino = D_Entidades[Entidad.destino]
            
            if Destino.__class__.__name__ in ["Chancador", "Stock"]:
                Entidad.actualizar_estado("Descargando", Reloj + Destino.duracion_atencion())#Comienza descarga solo
                
            if Destino.__class__.__name__ == "Pala":
                Entidad.actualizar_estado("Cargando", Reloj*99)
                #Reviso si hay alguien mas siendo atendido:
                if Destino.disponible():#Si no hay nadie
                    Destino.horas_eventos["Carga"] = Reloj + Destino.duracion_atencion()
                    Destino.hora_proximo_evento()#Actualizamos la hora del evento siguiente
                else: #Si no hay disponibilidad, se espera a que termine la atencion en el lugar de aculatamiento
                    pass
        
        #elif Entidad.estado == "Cargando":
        #    Destino = D_Entidades[Entidad.destino]
        #    Entidad.cargar(Destino.capacidad, Entidad.OD[1])
        #    Entidad.actualizar_estado("Viajando", Reloj + MTV[Entidad.origen][Entidad.destino])
    
    if Entidad.__class__.__name__ == "Pala":
        
        print(Entidad, Entidad.horas_eventos, Entidad.nombre_proximo_evento())
        if Entidad.nombre_proximo_evento() == "Carga":#Finaliza la carga del camion en atencion
            #Se busca el camion que termino la atencion
            print("Orden de llegada: {}".format(Entidad.orden_llegada))
            Camion = Entidad.orden_llegada.pop()
            #Despacho al camion:
            i = Entidad.espacios_aculatamiento.index(Camion)
            Entidad.espacios_aculatamiento[i] = 0 
            #El camion sale del lugar de aculatamiento
            #Camion.cargar(Entidad.capacidad, Camion.OD[1])
            Camion.actualizar_estado("Viajando", Reloj + MTV[Camion.origen][Camion.destino])
            print("Camion despachado: {}, llega en: {}".format(Camion, Camion.hora_siguiente))
            Entidad.horas_eventos["Carga"] = Reloj*99
            Entidad.hora_proximo_evento()
            try:#Reviso si quedan camiones por atender
                Camion = Entidad.orden_llegada.pop()
                if Camion.estado == "Cargando":
                    Entidad.horas_eventos["Carga"] = Reloj + Entidad.duracion_estacion()
                    Entidad.hora_proximo_evento()
                Entidad.orden_llegada.append(Camion)
            except:
                pass
            #Avanzar fila
            #Si hay un camion en la fila comenzar el aculatamiento de este
                        
    try:        
        print(Entidad, Entidad.hora_siguiente, Entidad.destino, Entidad.estado)  
        print('\n')
    except:
        print(Entidad, Entidad.hora_siguiente)
        print('\n')
                  
    trucks += 1    
    L_Entidades.sort(key=lambda x: x.hora_siguiente, reverse=False)
# Out:
# C0 0
# ------------------------------------------------------------
# C0 CS03 CS03 Descargando 0
# C0 36.51999225422681 PA10 Viajando
#
#
# C1 0
# ------------------------------------------------------------
# C1 CS03 CS03 Descargando 0
# C1 36.583285089685155 PA20 Viajando
#
#
# C0 36.51999225422681
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 36.51999225422681
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 37.68665892089347 PA10 Aculatandose
#
#
# C1 36.583285089685155
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 36.583285089685155
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 37.74995175635182 PA20 Aculatandose
#
#
# C0 37.68665892089347
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 37.68665892089347
# C0 3730.9792331684534 PA10 Cargando
#
#
# C1 37.74995175635182
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 37.74995175635182
# C1 3737.24522387883 PA20 Cargando
#
#
# PA20 39.290703890556394
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 39.290703890556394} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 75.87398898024155
# PA20 3889.779685165083
#
#
# PA10 40.42779342843402
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 40.42779342843402} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 76.94778568266082
# PA10 4002.3515494149683
#
#
# C1 75.87398898024155
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 75.87398898024155
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 77.04065564690822 PA20 Aculatandose
#
#
# C0 76.94778568266082
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 76.94778568266082
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 78.1144523493275 PA10 Aculatandose
#
#
# C1 77.04065564690822
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 77.04065564690822
# C1 7627.024909043914 PA20 Cargando
#
#
# C0 78.1144523493275
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 78.1144523493275
# C0 7733.330782583422 PA10 Cargando
#
#
# PA20 78.8125078031488
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 78.8125078031488} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 115.39579289283395
# PA20 7802.438272511732
#
#
# PA10 79.59738192693511
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 79.59738192693511} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 116.11737418116192
# PA10 7880.140810766577
#
#
# C1 115.39579289283395
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 115.39579289283395
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 116.56245955950062 PA20 Aculatandose
#
#
# C0 116.11737418116192
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 116.11737418116192
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 117.28404084782859 PA10 Aculatandose
#
#
# C1 116.56245955950062
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 116.56245955950062
# C1 11539.683496390562 PA20 Cargando
#
#
# C0 117.28404084782859
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 117.28404084782859
# C0 11611.12004393503 PA10 Cargando
#
#
# PA20 118.21049197671599
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 118.21049197671599} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 154.79377706640113
# PA20 11702.838705694883
#
#
# PA10 118.97229535711922
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 118.97229535711922} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 155.49228761134603
# PA10 11778.257240354804
#
#
# C1 154.79377706640113
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 154.79377706640113
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 155.9604437330678 PA20 Aculatandose
#
#
# C0 155.49228761134603
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 155.49228761134603
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 156.6589542780127 PA10 Aculatandose
#
#
# C1 155.9604437330678
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 155.9604437330678
# C1 15440.083929573711 PA20 Cargando
#
#
# C0 156.6589542780127
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 156.6589542780127
# C0 15509.236473523257 PA10 Cargando
#
#
# PA20 156.92427616326597
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 156.92427616326597} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 193.50756125295112
# PA20 15535.503340163332
#
#
# PA10 158.825315697375
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 158.825315697375} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 195.3453079516018
# PA10 15723.706254040126
#
#
# C1 193.50756125295112
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 193.50756125295112
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 194.67422791961778 PA20 Aculatandose
#
#
# C1 194.67422791961778
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 194.67422791961778
# C1 19272.74856404216 PA20 Cargando
#
#
# C0 195.3453079516018
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 195.3453079516018
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 196.51197461826845 PA10 Aculatandose
#
#
# PA20 196.27132913773218
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 196.27132913773218} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 232.85461422741733
# PA20 19430.861584635484
#
#
# C0 196.51197461826845
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 196.51197461826845
# C0 19454.68548720858 PA10 Cargando
#
#
# PA10 197.8871931564017
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 197.8871931564017} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 234.40718541062853
# PA10 19590.832122483767
#
#
# C1 232.85461422741733
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 232.85461422741733
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 234.021280894084 PA20 Aculatandose
#
#
# C1 234.021280894084
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 234.021280894084
# C1 23168.106808514316 PA20 Cargando
#
#
# C0 234.40718541062853
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 234.40718541062853
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 235.5738520772952 PA10 Aculatandose
#
#
# PA20 235.31912453493507
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 235.31912453493507} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 271.90240962462025
# PA20 23296.593328958574
#
#
# C0 235.5738520772952
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 235.5738520772952
# C0 23321.811355652222 PA10 Cargando
#
#
# PA10 237.55540404430374
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 237.55540404430374} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 274.07539629853056
# PA10 23517.98500038607
#
#
# C1 271.90240962462025
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 271.90240962462025
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 273.06907629128693 PA20 Aculatandose
#
#
# C1 273.06907629128693
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 273.06907629128693
# C1 27033.838552837406 PA20 Cargando
#
#
# C0 274.07539629853056
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 274.07539629853056
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 275.24206296519725 PA10 Aculatandose
#
#
# PA20 274.13752005359754
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 274.13752005359754} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 310.7208051432827
# PA20 27139.614485306156
#
#
# C0 275.24206296519725
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 275.24206296519725
# C0 27248.96423355453 PA10 Cargando
#
#
# PA10 278.10298053122403
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 278.10298053122403} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 314.6229727854508
# PA10 27532.19507259118
#
#
# C1 310.7208051432827
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 310.7208051432827
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 311.8874718099494 PA20 Aculatandose
#
#
# C1 311.8874718099494
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 311.8874718099494
# C1 30876.859709184988 PA20 Cargando
#
#
# PA20 313.38171711350424
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 313.38171711350424} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 349.9650022031894
# PA20 31024.78999423692
#
#
# C0 314.6229727854508
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 314.6229727854508
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 315.7896394521175 PA10 Aculatandose
#
#
# C0 315.7896394521175
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 315.7896394521175
# C0 31263.174305759632 PA10 Cargando
#
#
# PA10 317.76091758203455
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 317.76091758203455} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 354.28090983626134
# PA10 31458.33084062142
#
#
# C1 349.9650022031894
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 349.9650022031894
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 351.13166886985607 PA20 Aculatandose
#
#
# C1 351.13166886985607
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 351.13166886985607
# C1 34762.03521811575 PA20 Cargando
#
#
# PA20 352.74103018773394
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 352.74103018773394} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 389.3243152774191
# PA20 34921.36198858566
#
#
# C0 354.28090983626134
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 354.28090983626134
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 355.44757650292803 PA10 Aculatandose
#
#
# C0 355.44757650292803
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 355.44757650292803
# C0 35189.31007378988 PA10 Cargando
#
#
# PA10 357.2705490045417
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 357.2705490045417} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 393.7905412587685
# PA10 35369.78435144963
#
#
# C1 389.3243152774191
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 389.3243152774191
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 390.4909819440858 PA20 Aculatandose
#
#
# C1 390.4909819440858
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 390.4909819440858
# C1 38658.60721246449 PA20 Cargando
#
#
# PA20 392.21370953551803
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 392.21370953551803} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 428.7969946252032
# PA20 38829.157244016285
#
#
# C0 393.7905412587685
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 393.7905412587685
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 394.95720792543517 PA10 Aculatandose
#
#
# C0 394.95720792543517
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 394.95720792543517
# C0 39100.76358461808 PA10 Cargando
#
#
# PA10 397.2545214511592
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 397.2545214511592} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 433.77451370538597
# PA10 39328.19762366476
#
#
# C1 428.7969946252032
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 428.7969946252032
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 429.96366129186987 PA20 Aculatandose
#
#
# C1 429.96366129186987
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 429.96366129186987
# C1 42566.40246789512 PA20 Cargando
#
#
# PA20 432.32114118206533
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 432.32114118206533} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 468.9044262717505
# PA20 42799.79297702447
#
#
# C0 433.77451370538597
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 433.77451370538597
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 434.94118037205266 PA10 Aculatandose
#
#
# C0 434.94118037205266
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 434.94118037205266
# C0 43059.17685683321 PA10 Cargando
#
#
# PA10 437.0847796219978
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 437.0847796219978} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 473.6047718762246
# PA10 43271.39318257778
#
#
# C1 468.9044262717505
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 468.9044262717505
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 470.07109293841717 PA20 Aculatandose
#
#
# C1 470.07109293841717
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 470.07109293841717
# C1 46537.0382009033 PA20 Cargando
#
#
# PA20 471.41483705879034
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 471.41483705879034} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 507.9981221484755
# PA20 46670.06886882024
#
#
# C0 473.6047718762246
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 473.6047718762246
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 474.7714385428913 PA10 Aculatandose
#
#
# C0 474.7714385428913
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 474.7714385428913
# C0 47002.37241574624 PA10 Cargando
#
#
# PA10 475.91674439078434
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 475.91674439078434} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 512.4367366450111
# PA10 47115.75769468765
#
#
# C1 507.9981221484755
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 507.9981221484755
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 509.1647888151422 PA20 Aculatandose
#
#
# C1 509.1647888151422
# ------------------------------------------------------------
# C1 CS03 PA20 Aculatandose 509.1647888151422
# C1 50407.314092699075 PA20 Cargando
#
#
# PA20 510.5680961645869
# ------------------------------------------------------------
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 510.5680961645869} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega en: 547.1513812542721
# PA20 50546.241520294105
#
#
# C0 512.4367366450111
# ------------------------------------------------------------
# C0 CS03 PA10 Viajando 512.4367366450111
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA10:deque([C0])
# C0 513.6034033116778 PA10 Aculatandose
#
#
# C0 513.6034033116778
# ------------------------------------------------------------
# C0 CS03 PA10 Aculatandose 513.6034033116778
# C0 50846.7369278561 PA10 Cargando
#
#
# PA10 516.05463261364
# ------------------------------------------------------------
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 516.05463261364} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega en: 552.5746248678669
# PA10 51089.40862875036
#
#
# C1 547.1513812542721
# ------------------------------------------------------------
# C1 CS03 PA20 Viajando 547.1513812542721
# Espacio de aculatamiento: deque([])
# Camion aculatandose en PA20:deque([C1])
# C1 548.3180479209387 PA20 Aculatandose

# %%
print(Destino.tiempo_aculatado)
# Out:
# 1.1666666666666667

# %%
a = deque()
a.append(1)
len(a)
# Out:
# 1
