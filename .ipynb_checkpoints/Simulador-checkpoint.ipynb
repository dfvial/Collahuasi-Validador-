# %%
import random
import numpy as np
from collections import deque
import pandas as pd 
import time

# %% [markdown]
# # Parámetros

# %%
#Horizonte de simulacion (Turnos)
Turnos = 1
Reloj = 0
tiempo_aculatamiento = 70/60
AlmuerzoTA = 60 #Duracion almuerzo turno A
Almuerzo1TB = 40 #Duracion colacion 1 turno B
Almuerzo2TB = 20 #Duracion colacion 2 turno B

# %%
#Se leen las caracteristicas de las palas
dfPalas = pd.read_excel('Informacion Palas.xlsx',  1)
InfoPalas = list(zip(dfPalas[dfPalas.columns[0]].values, dfPalas[dfPalas.columns[1]].values, dfPalas[dfPalas.columns[2]].values, \
                            dfPalas[dfPalas.columns[3]].values, dfPalas[dfPalas.columns[4]].values, \
                            dfPalas[dfPalas.columns[5]].values, dfPalas[dfPalas.columns[6]].values, \
                            dfPalas[dfPalas.columns[7]].values, dfPalas[dfPalas.columns[8]].values))

#Lista de nodos de mineral y esteril
Nodos_Mineral = ["PO1", "PO2", "PO3", "PO4", "PO5"]
Nodos_Esteril = ["PO6", "PO7", "PO8", "PO9", "PO10"]
Polvorazos = Nodos_Mineral + Nodos_Esteril


#Número de camiones disponibles
total_camiones = 81

#Lista de stocks/botaderos
#ID, espacios, ubicacion, tiempo_atencion ID=ubicacion?
SoB = ["S1", "S2"]
espacios = 5
tiempo_atencion_stock = 70/60 #segundos

#Se lee la informacion del chancador
dfChancador = pd.read_excel('Informacion Palas.xlsx',  0)
InfoChancador = list(zip(dfChancador[dfChancador.columns[0]].values, dfChancador[dfChancador.columns[1]].values, dfChancador[dfChancador.columns[2]].values, \
                            dfChancador[dfChancador.columns[3]].values, dfChancador[dfChancador.columns[4]].values, \
                            dfChancador[dfChancador.columns[5]].values, dfChancador[dfChancador.columns[6]].values, \
                            dfChancador[dfChancador.columns[7]].values, dfChancador[dfChancador.columns[8]].values))

# %% [markdown]
# # PL

# %%
dfPL = pd.read_excel('EjemploFlujosPl.xlsx')
PL = {}
for i in range(len(dfPL)):
    PL[dfPL.columns[i]] = {} 
    for j in range(len(dfPL)):
        PL[dfPL.columns[i]][dfPL.columns[j]] =  dfPL.iloc[i, j]
print(PL["PA14"]["CS03"])
TPH_Teorico(PL, D_Entidades["PA21"])
# Out:
# 2669.33132870822
# 5338.66265741645

# %% [markdown]
# # Dinamico

# %%
def dinamico(destinos, pala):
    return (random.choice(pala), random.choice(destinos))

def dinamico_dispatch(Camion, Trucks, Palas, MTV, reloj, TPH_PL, FCamiones_PL):#Hay un camion que llama al dinamico.
    need_time = {}
    for Pala in Palas:
        Aj, Pi = Input_Dinamico(Pala.toneladas_sacadas, reloj)
        Lj = Pala.hora_ultima_asignacion
        Rj = TPH_Teorico(TPH_PL, Pala)
        if Pala.estado == "Funcionando":
            for key in TPH_PL[Pala.ID].keys():
                Pi_teorico = TPH_PL[Pala.ID][key]
                Pi_real = Pi[key]
                needtimei = Lj + ((Pi_teorico/Rj)*(Aj-Rj))/Pi_real 
                need_time[(Pala.ID, key)] = needtimei
    
    
        
    pass

# %% [markdown]
# # Funciones

# %%
def Input_Dinamico(toneladas_sacadas, reloj):#Toneladas sacadas la ultima hora
    Aj = 0
    Pi_real = {}
    for item in toneladas_sacadas[::-1]:
        if item[0] >= reloj-60:
            Aj += item[2]
            try:
                Pi_real[item[4]] += item[2]
            except:
                Pi_real[item[4]] = item[2]
    return(Aj, Pi_real)

def TPH_Teorico(TPH_PL, Pala):
    idPala = Pala.ID
    Rj = 0
    for key in TPH_PL[idPala].keys():
        Rj += TPH_PL[idPala][key]
    return(Rj)
    
    
def camiones_viajando(D_Camiones, Pala):#Identifica los camiones viajando a la pala y los que van a descargr
    output = []
    a_descarga = []
    for camion in D_Camiones.keys():
        #Si el camion va viajando hacia la pala
        if D_Camiones[camion].estado == "Viajando" and D_Camiones[camion].destino == Pala.ID:
            output.append(D_Camiones[camion]) 
        #Si el camion esta descargando o aculatandose, en la fila o viajando hacia un chancador, stock o botadero  
        elif D_Camiones[camion].estado == "Descargando" or ((D_Camiones[camion].estado in ["En fila", "Aculatandose", "Viajando"] and \
                                                           D_Camiones[camion].destino.__class__.name in ["Chancador", "Stock"])):
            a_descarga.append(D_Camiones[camion])

    output.sort(key=lambda x: x.hora_siguiente, reverse=False)
    return(output, a_descarga)#output: camiones viajando a Pala, a_descarga = camiones en camino a descarga

#viajando = camiones_viajando()[0]
#descarga = camiones_viajando()[1]
def correr_dinamico(aculatados, fila, viajando, descarga, Reloj):#viajando = camiones_viajando()[0]
    orden_asignacion = aculatados + fila + viajando
    todos = orden_asignacion + descarga
    for camion in orden_asignacion:
        #nodo_inicio lo debo obtener de la funcion de shortest path(OD, tiempo_transcurrido)
        #dinamico(camion, todos nodo_inicio)#output: OD
        #TiempoViaje = MTV[nodo_inicio][OD[0]][camion.cargado]
        #camion.reasignacion(OD, Reloj + TiempoViaje, nodo_inicio)
        #sacar camion asignado de la lista todos
        pass
    pass

# %% [markdown]
# # 1. Clases
# ## 1.1. Palas

# %%
class Pala:
    def __init__(self, ID, capacidad, ubicacion, media_recuperacion, media_falla, velocidad, tiempo_aculatado, min_carga, moda_carga, max_carga):
        self.ubicacion = ubicacion #Nodo en que esta ubicada la pala
        self.capacidad = capacidad #Capacidad nominal de excavacion
        self.ID = ID #ID pala
        self.fila = deque() #camiones en fila para se atendidos
        
        self.espacios_aculatamiento = [0, 0] #camiones aculatados 
        self.orden_llegada = deque() #orden de llegada al aculatamiento
        self.llegada_ultimo_camion = 0
        self.hora_ultima_asignacion = 0 #Lj
        
        self.horas_eventos = {"Recuperacion":99999999, "Caida":9999999, "Inicio Movimiento":99999999, "Fin Movimiento":99999999, "Carga":999999} 
        self.proximo_evento = None #Nombre del evento mas proximo
        #self.toneladas_sacadas = {} #Diccionario de tuplas con toneladas sacadas por posicion/nodo y ley
        self.TPH = {} #Diccionario con los resultados del PL
        
        self.media_recuperacion = media_recuperacion
        self.media_falla = media_falla
        self.velocidad = velocidad
        
        self.tiempo_aculatado = tiempo_aculatado
        
        self.min = min_carga
        self.moda = moda_carga
        self.max = max_carga
        
        self.hora_siguiente = 999999999
        self.disponibilidad = True #True: Disponible, False: Ocupada
        self.estado = "Funcionando" #Funcionando o Mala
        self.toneladas_sacadas = []#Lleva el registro de las excavaciones: Lugar, toneladas y destino
        
    def caida(self, Reloj):#Completar comn PL y con Dinamico
        self.estado = 0
        #POR FUERA:
        #Se debe correr el PL y luego el dinámico para todos los camiones en la fila, y en camion hacia la pala
        #for cada camion if camion hacia pala.ID correr dinamico 
        self.horas_eventos["Caida"] = 99999999
        self.horas_eventos["Recuperacion"] = Reloj + self.tiempo_recuperacion()
        if self.horas_eventos["Recuperacion"] > self.horas_eventos["Inicio Movimiento"]:
            self.horas_eventos["Inicio Movimiento"] = self.horas_eventos["Recuperacion"] + 0.0001 #Postergo el movimiento hasta que se arregle la pala
        self.proximo_evento = "Recuperacion"
        return None
    
    def recuperacion(self, Reloj):
        self.estado = 1
        self.horas_eventos["Recuperacion"] = 99999999
        self.horas_eventos["Caida"] = Reloj + self.tiempo_falla()
        self.proximo_evento = min(self.horas_eventos, key=self.horas_eventos.get)
        self.hora_siguiente = self.horas_eventos[self.proximo_evento]
        return None
    
    def disponible(self):
        for espacio in self.espacios_aculatamiento:
            if espacio != 0:
                return True
        return False
    
  
    def fin_movimiento(self, Reloj, Lista_movimientos_agendados):
        pass
       
    def tiempo_recuperacion(self):
        return(np.random.exponential(self.media_recuperacion))
    
    def tiempo_falla(self):
        return(np.random.exponential(self.media_falla))
    
    def hora_proximo_evento(self):
        self.hora_siguiente = min(self.horas_eventos.values())
        return(self.hora_siguiente)
    
    def nombre_proximo_evento(self):
        self.proximo_evento = min(self.horas_eventos, key=self.horas_eventos.get)
        return(self.proximo_evento)
    
    def duracion_atencion(self):
        return(np.random.triangular(self.min, self.moda, self.max))
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# ## 1.2. Camiones

# %%
class Camion:
    def __init__(self, ID):
        self.ID = ID
        self.Nombre = "C"+str(ID)
        self.destino = "CS03"
        self.origen = "CS03"
        self.almuerzo = 0 #0: No almorzo, 1 primera colacion, 2 segunda colacion (solo aplica turno B)
        self.hora_siguiente = 0
        self.descargas = {} #Diccionario que almacena la historia de las descargas: key = (Origen, Destino)| value = toneladas
        self.carga = 0
        #self.aculatandose = False
        self.estado = "Descargando" #Viajando, Aculatandose, Cargando, Descargando, Almorzando, En fila
        self.OD = None
        self.hora_salida = 0
        self.cargado = 0 #1 si esta cargado, 0 en caso contrario
        
    def descargar(self, nuevo_destino, Reloj, TdV):
        self.toneladas = 0
        self.origen = self.destino
        self.destino = nuevo_destino
        if self.carga > 0:
            self.descargas[(self.origen, destino)] = self.carga 
        self.carga = 0
        self.estado = "Viajando"
        self.hora_siguiente = Reloj + TdV
        return None
    
    def cargar(self, toneladas_cargadas, nuevo_destino):
        self.origen = self.destino
        self.destino = nuevo_destino
        self.carga = toneladas_cargadas
        return None
    
    #def asignar_destino(self, Reloj, nuevo_destino, MTV):
    #    self.destino = nuevo_destino
    #    self.actualizar_estado("Viajando", Reloj + MTV[self.origen][self.destino])
    
    def actualizar_estado(self, Estado, Hora):
        self.estado = Estado 
        self.hora_siguiente = Hora
        
    def nuevo_viaje(self, Estado, Hora):
        self.estado = Estado 
        self.hora_siguiente = Hora
        self.origen = self.OD[0]
        self.destino = self.OD[1]
        
    def reasignacion(self, OD, siguiente, nodo_inicio):
        self.origen = nodo_inicio
        self.destino = OD[0]
        self.OD= OD
        self.estado = "Viajando"
        self.hora_siguiente = siguiente 
        
    def comenzar_almuerzo(self, destino, reloj, MTV, tiempo_colacion, almuerzo):
        self.origen = self.destino
        self.destino = destino
        self.estado = "Almorzando"
        self.hora_siguiente = Reloj + MTV[self.origen][self.destino][self.cargado] + tiempo_colacion
        self.almuerzo = almuerzo
        
    def __str__(self):
        return str(self.Nombre)
    def __unicode__(self):
        return str(self.Nombre)
    def __repr__(self):
        return str(self.Nombre)

# %% [markdown]
# ## 1.3. Stock - Botadero

# %%
class Stock:
    
    def __init__(self, ID, espacios, ubicacion, tiempo_atencion, tiempo_aculatado):
        self.ID = ID
        self.fila = deque()
        self.espacios_aculatamiento = [0 for i in range(espacios)]
        self.ubicacion = ubicacion
        self.tiempo_atencion = tiempo_atencion
        self.hora_siguiente = 99999999
        self.tiempo_aculatado = tiempo_aculatado 
    
    def avanzar_fila(self):
        camion = self.fila.popleft()
        return camion
    
    def duracion_atencion(self):
        return(self.tiempo_atencion)
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# ## 1.4. Chancador

# %%
class Chancador:
    
    def __init__(self, ID, ubicacion, media_falla, media_recuperacion, tiempo_aculatado, min_carga, moda_carga, max_carga):
        self.ID = ID
        self.ubicacion = ubicacion
        self.espacios_aculatamiento = [0, 0]
        self.fila = deque()
        self.media_falla = media_falla
        self.media_recuperacion = media_recuperacion
        self.tiempo_aculatado = tiempo_aculatado
        self.min = min_carga
        self.moda = moda_carga
        self.max = max_carga
        self.hora_siguiente = 999999999
        
    def tiempo_recuperacion(self):
        return(np.random.exponential(self.media_recuperacion))
    
    def tiempo_falla(self):
        return(np.random.exponential(self.media_falla))
    
    def hora_proximo_evento(self):
        return(min(horas_eventos.values()))
    
    def duracion_atencion(self):
        return(np.random.triangular(self.min, self.moda, self.max))
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# # 2. Simulación
# ## 2.1. Inicialización

# %%
#Se evalúa que palas estarán operativas y en que condición y se generan las instancias 
L_Entidades = []
#Esteril: 303
#Mineral: 293
Capacidades = [303, 293]
D_Palas = {}
D_Entidades = {}
for pala in InfoPalas:
    u = np.random.uniform(0,1)
    
    if 0 <= u and u < pala[3]:
        pass
    
    elif pala[3] <= u and u < 1:#pala[4]
        D_Palas[pala[0]] = Pala(pala[0], random.choice(Capacidades), random.choice(Polvorazos), pala[2], pala[1], "velocidad", \
                                pala[8], pala[5], pala[6], pala[7])
        L_Entidades.append(D_Palas[pala[0]])
        D_Entidades[pala[0]] = D_Palas[pala[0]]
       
    else:
        #D_Palas[pala[0]] = Pala(pala[0], "TONELADAS X CARGA", random.choice(Polvorazos), pala[2], pala[1], "velocidad", \
        #                        pala[8], pala[5], pala[6], pala[7]) 
        #D_Palas[pala[0]].recuperacion(0)#Se inicializa el tiempo de la siguiente falla
        #print(pala[0], D_Palas[pala[0]].hora_siguiente)
        #L_Entidades.append(D_Palas[pala[0]])
        #D_Entidades[pala[0]] = D_Palas[pala[0]]
        pass
        
#Se inicializan los camiones
D_Camiones = {}
for i in range(total_camiones):
    D_Camiones[i] = Camion(i)
    L_Entidades.append(D_Camiones[i])
    D_Entidades[i] = D_Camiones[i]


    
#Se inicializan los stocks/botaderos
D_Stocks = {}
for stock in SoB:
    D_Stocks[stock] = Stock(stock, espacios, stock, tiempo_atencion_stock, tiempo_aculatamiento)
    L_Entidades.append(D_Stocks[stock])
    D_Entidades[stock] = D_Stocks[stock]
#print("Stocks y Botaderos :", D_Stocks)    

#Se inicializa el Chancador
D_Chancador ={}
for chancador in InfoChancador:
    D_Chancador[chancador[0]] = Chancador(chancador[0], "CS03", chancador[1], chancador[2], chancador[8], \
                                          chancador[5], chancador[6], chancador[7])
    L_Entidades.append(D_Chancador[chancador[0]])
    D_Entidades[chancador[0]] = D_Chancador[chancador[0]]
    
#print("Chancador: ", D_Chancador)


L_Entidades.sort(key=lambda x: x.hora_siguiente, reverse=False)

# %% [markdown]
# ## 2.2. Matriz de tiempos de viaje

# %%
MTV = {}
Destinos = []
Palas = []

for destino1 in L_Entidades:
    if destino1.__class__.__name__ in ["Stock", "Chancador"]:
        Destinos.append(destino1.ID)
        MTV[destino1.ID] = {}
        for destino2 in L_Entidades:
            if destino2.__class__.__name__ in ["Stock", "Chancador"]:
                MTV[destino1.ID][destino2.ID] = {}
                MTV[destino1.ID][destino2.ID][0] = random.uniform(20, 40)
                MTV[destino1.ID][destino2.ID][1] = random.uniform(30, 50)
                    
    if destino1.__class__.__name__ == "Pala":
        Palas.append(destino1.ID)
    #La Matriz de tiempos de viajes debe ser entre los polvorazos y los destinos    
    
for destino1 in Polvorazos:
    MTV[destino1] = {}
    for key in MTV.keys():
        MTV[key][destino1] = {}
        MTV[destino1][key] = {}
        MTV[key][destino1][0] = random.uniform(20, 40)
        MTV[destino1][key][0] = random.uniform(20, 40)
        MTV[key][destino1][1] = random.uniform(30, 50)
        MTV[destino1][key][1] = random.uniform(30, 50)
    
MTV["CASINO"] = {}
for key in MTV.keys():
    MTV[key]["CASINO"] = {}
    MTV["CASINO"][key] = {}
    MTV[key]["CASINO"][0] = random.uniform(20, 40)
    MTV["CASINO"][key][0] = random.uniform(20, 40)
    MTV[key]["CASINO"][1] = random.uniform(30, 50)
    MTV["CASINO"][key][1] = random.uniform(30, 50)

#print(MTV)

# %% [markdown]
# ## 2.3 Simulación

# %%
#Identificamos el siguiente evento que va a ocurrir}
TurnoA = True
TurnoB = False
NTurnos = 0
start_time = time.time()
print("--- %s seconds ---" % (time.time() - start_time))

Entidad = L_Entidades[0]
Reloj = Entidad.hora_siguiente

while Reloj < 12*60:
    
    Entidad = L_Entidades[0]
    Reloj = Entidad.hora_siguiente
    NTurnos = int(Reloj/(12*60))
    
    if int(Reloj/(12*60))%2 == 0 and TurnoB:
        #Se deben acutualizar todos los estados de almuerzo de los camiones
        for camion in D_Camiones.keys():
            D_Camiones[camion].almuerzo = 0
        TurnoB = False
        TurnoA = True
        
    elif int(Reloj/(12*60))%2 != 0 and TurnoA:
        #Se deben acutualizar todos los estados de almuerzo de los camiones
        for camion in D_Camiones.keys():
            D_Camiones[camion].almuerzo = 0   
        TurnoA = False
        TurnoB = True

    #En caso de que la entidad sea un camion
    if Entidad.__class__.__name__ == "Camion":
        
        print(Entidad, Entidad.origen, Entidad.destino, Entidad.estado, Reloj, Entidad.almuerzo)
        
        if Entidad.estado == "Almorzando":#Cuando termina de almorzar
            Entidad.estado = "Descargando"
            print("El camion {} termino de almorzar.".format(Entidad))
            
        if Entidad.estado == "Descargando":#Salida de un stock, botadero o chancador
            #Comienzo de almuerzos
            #Almuerzo turno A
            Entidad.hora_salida = Reloj
            Entidad.cargado = 0
            MIT = NTurnos*60*12 #Minuto en que inicio turno
            if (TurnoA and 0 <= Entidad.ID and Entidad.ID <= 40 and Reloj >= (4.5*60 + MIT) and Entidad.almuerzo == 0):
                Destino = D_Entidades[Entidad.destino]
                print("El camion {} se va a almorzar desde {}".format(Entidad, Destino))
                print("La cola en el destino es {}".format(Destino.fila))
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo("CASINO", Reloj, MTV, AlmuerzoTA, 1)
                print("La cola en el destino queda {}".format(Destino.fila))
                
            if (TurnoA and Entidad.ID > 40 and Reloj >= (6*60 + MIT) and Entidad.almuerzo ==0):
                Destino = D_Entidades[Entidad.destino]
                print("El camion {} se va a almorzar desde {}".format(Entidad, Destino))
                print("La cola en el destino es {}".format(Destino.fila))
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo("CASINO", Reloj, MTV, AlmuerzoTA, 1)
                print("La cola en el destino queda {}".format(Destino.fila))
            
            #Primera colacion turno B
            if (TurnoB and 0 <= Entidad.ID and Entidad.ID <= 27 and Reloj >= (5*60 + MIT) and Entidad.almuerzo == 0):
                Destino = D_Entidades[Entidad.destino]
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo(Entidad.destino, Reloj, MTV, Almuerzo1TB, 1)
                
            if (TurnoB and 28 <= Entidad.ID and Entidad.ID <= 54 and Reloj >= (5.5*60 + MIT)and Entidad.almuerzo == 0):
                Destino = D_Entidades[Entidad.destino]
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo(Entidad.destino, Reloj, MTV, Almuerzo1TB, 1)
                
            if (TurnoB and 55 <= Entidad.ID and Reloj >= (4.5*60 + MIT) and Entidad.almuerzo == 0):
                Destino = D_Entidades[Entidad.destino]
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo(Entidad.destino, Reloj, MTV, Almuerzo1TB, 1)
                
            #Segunda colacion turno B
            if (TurnoB and 0 <= Entidad.ID and Entidad.ID <= 45 and Reloj >= (9*60 + MIT) and Entidad.almuerzo == 1):
                Destino = D_Entidades[Entidad.destino]
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo(Entidad.destino, Reloj, MTV, Almuerzo2TB, 2)
                
            if (TurnoB and 46 <= Entidad.ID and Reloj >= (9.5*60 + MIT) and Entidad.almuerzo == 1):
                Destino = D_Entidades[Entidad.destino]
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo(Entidad.destino, Reloj, MTV, Almuerzo2TB, 2)
            
            #En caso contrario, hay que asignarle un nuevo destino corriendo el dinámico
            if Entidad.estado == "Descargando": #Posible fuente de error; probar -- (if Entidad.estado == "Descargando")
                #Pregunto si hay fila en el stock/botadero/chancador
                try:
                    Destino = D_Entidades[Entidad.destino]
                    if len(Destino.fila) > 0:
                        #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                        i = Destino.espacios_aculatamiento.index(Entidad)

                        print("La fila en {} es {}".format(Destino, Destino.fila))
                        print("El lugar de aculatado en {} es {}".format(Destino, Destino.espacios_aculatamiento))
                        Siguiente = Destino.fila.popleft()
                        Destino.espacios_aculatamiento[i] = Siguiente
                        Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)

                        print("El camion {} sale y comienza el aculatado {}".format(Entidad, Siguiente))
                        print("La fila en {} quedo {}".format(Destino, Destino.fila))
                        print("El lugar de aculatado en {} quedo {}".format(Destino, Destino.espacios_aculatamiento))

                    elif Entidad in Destino.espacios_aculatamiento:
                        i = Destino.espacios_aculatamiento.index(Entidad)
                        print("No habia fila")
                        print("El lugar de aculatado en {} es {}".format(Destino, Destino.espacios_aculatamiento))
                        Destino.espacios_aculatamiento[i] = 0
                        print("El lugar de aculatado en {} quedo {}".format(Destino, Destino.espacios_aculatamiento))
                except:
                    pass

                nuevo_destino = dinamico(Destinos, Palas) #Decido hacia donde enviar el camion
                Entidad.OD = nuevo_destino #Guardo el resultado del dinamico - par OD
                print("El resultado del dinamico fue: {}".format(nuevo_destino))
                #Finalizo descarga, actualizo tiempo de sgte evento, y cambio estado a "Viajando", y origen
                Entidad.descargar(nuevo_destino[0], Reloj, MTV[Entidad.destino][D_Entidades[nuevo_destino[0]].ubicacion][Entidad.cargado]) 
                #Se debe actualizar el atributo Lj
                try:
                    D_Entidades[Entidad.destino].hora_ultima_asignacion = Reloj
                except:
                    pass
                
        elif Entidad.estado == "Viajando":
            Destino = D_Entidades[Entidad.destino]
            try:
                Destino.llegada_ultimo_camion = Reloj#Actualizacion de Lj 
            except:
                pass
            if len(Destino.fila) > 0:#Reviso si hay fila en el destino
                Destino.fila.append(Entidad)#El camion se pone a la fila
                Entidad.actualizar_estado("En fila", Reloj*99)
                print("Camion {} se pone a la fila {}".format(Entidad, Destino.fila))
            
            if len(Destino.fila) == 0:
                #Se revisa la disponibilidad de espacios de aculatamiento
                if 0 in Destino.espacios_aculatamiento:
                    #Camion comienza a aculatarse
                    try:
                        print("No hay fila, {} se aculata {}".format(Entidad, Destino.orden_llegada))
                    except:
                        pass
                    Entidad.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                    #El camion se ubica en el lugar disponible
                    lugar = 0
                    for espacio in Destino.espacios_aculatamiento:
                        if espacio == 0:
                            Destino.espacios_aculatamiento[lugar] = Entidad
                            if Destino.__class__.__name__ == "Pala":
                                Destino.orden_llegada.append(Entidad)
                                
                                print("Camion aculatandose en {}:{}".format(Destino, Destino.espacios_aculatamiento))
                            break
                        lugar += 1
                else:
                    Destino.fila.append(Entidad)
                    Entidad.actualizar_estado("En fila", Reloj*99)  
                    print("Esta es la fila ahora: {}".format(Destino.fila))
        
        elif Entidad.estado == "Aculatandose":#Termina de aculatarse
            Destino = D_Entidades[Entidad.destino]
            
            if Destino.__class__.__name__ in ["Chancador", "Stock"]:
                Entidad.actualizar_estado("Descargando", Reloj + Destino.duracion_atencion())#Comienza descarga solo
                #Destino.hora_siguiente = Reloj + Destino.duracion_atencion()
                #Entidad.actualizar_estado("Descargando", Reloj*99999)
                
            if Destino.__class__.__name__ == "Pala":
                Entidad.actualizar_estado("Cargando", Reloj*99)
                Primero = Destino.orden_llegada.popleft()
                #Reviso si hay alguien mas siendo atendido:
                if Destino.disponibilidad and Entidad == Primero:#Si no hay nadie
                    print("El primero en aculatarse: {}".format(Entidad))
                    Destino.horas_eventos["Carga"] = Reloj + Destino.duracion_atencion()
                    Destino.hora_proximo_evento()#Actualizamos la hora del evento siguiente
                    Destino.disponibilidad = False
                    print("Camion termino de aculatarse y comienza atencion. Fin atencion: {}".format(Destino.horas_eventos["Carga"]))
                else: #Si no hay disponibilidad, se espera a que termine la atencion en el lugar de aculatamiento
                    print("{} No era el primero: {} o la pala no estaba disponible: {}".format(Entidad, Primero, Destino.disponibilidad))
                    pass
                Destino.orden_llegada.insert(0, Primero)
                
        #elif Entidad.estado == "Cargando":
        #    Destino = D_Entidades[Entidad.destino]
        #    Entidad.cargar(Destino.capacidad, Entidad.OD[1])
        #    Entidad.actualizar_estado("Viajando", Reloj + MTV[Entidad.origen][Entidad.destino])
    
    if Entidad.__class__.__name__ == "Pala":
        
        print(Entidad, Entidad.horas_eventos, Entidad.nombre_proximo_evento())
        if Entidad.nombre_proximo_evento() == "Carga":#Finaliza la carga del camion en atencion
            #Se busca el camion que termino la atencion
            print("Orden de llegada: {}".format(Entidad.orden_llegada))
            Camion = Entidad.orden_llegada.popleft()
            #Despacho al camion:
            i = Entidad.espacios_aculatamiento.index(Camion)
            Entidad.espacios_aculatamiento[i] = 0 
            
            #El camion sale del lugar de aculatamiento
            #Camion.cargar(Entidad.capacidad, Camion.OD[1])
            #Camion.actualizar_estado("Viajando", Reloj + MTV[Camion.origen][Camion.destino])
            Entidad.toneladas_sacadas.append((Reloj, Entidad.ubicacion, Entidad.capacidad, Camion.Nombre, Camion.OD[1]))
            Camion.cargado = 1
            Camion.nuevo_viaje("Viajando", MTV[D_Entidades[Camion.OD[0]].ubicacion][Camion.OD[1]][Camion.cargado]+Reloj)
            Camion.hora_salida = Reloj
            print("Camion despachado: {}, llega a las: {} a {}".format(Camion, Camion.hora_siguiente, Camion.destino))
            Entidad.disponibilidad = True
            Entidad.horas_eventos["Carga"] = Reloj*99
            Entidad.hora_proximo_evento()
            print("Estado del orden de llegada {}".format(Entidad.orden_llegada))
            #Reviso si quedan camiones por atender
            if len(Entidad.orden_llegada) > 0:
                Camion = Entidad.orden_llegada.pop()
                print(Camion, Camion.estado)
                if Camion.estado == "Cargando":
                    Entidad.disponibilidad = False
                    Entidad.horas_eventos["Carga"] = Reloj + Entidad.duracion_atencion()
                    print("Comienzo a atender a: {} y termino a las {}".format(Camion, Entidad.horas_eventos["Carga"]))
                    Entidad.hora_proximo_evento()
                    print("Proximo evento: {}".format(Entidad.hora_siguiente))
                Entidad.orden_llegada.append(Camion)
            
            #print(Entidad.disponibilidad)
            if len(Entidad.fila) > 0:
                Camion = Entidad.fila.popleft()
                Entidad.orden_llegada.append(Camion)
                i = Entidad.espacios_aculatamiento.index(0)
                Entidad.espacios_aculatamiento[i] = Camion
                Camion.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                print("Lugar aculatado: {}".format(Entidad.espacios_aculatamiento))
                print("Fila: {}".format(Entidad.fila))     
    

    print('------------------------------------------------------------')              
 
    L_Entidades.sort(key=lambda x: x.hora_siguiente, reverse=False)

print("El tiempo de simulacion fue: %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0 seconds ---
# Camion termino de aculatarse y comienza atencion. Fin atencion: 24.06110924834186
# Camion termino de aculatarse y comienza atencion. Fin atencion: 25.66149034871222
# Camion termino de aculatarse y comienza atencion. Fin atencion: 25.783127743530756
# Camion termino de aculatarse y comienza atencion. Fin atencion: 26.162820354158875
# Camion termino de aculatarse y comienza atencion. Fin atencion: 26.23033338282882
# Camion termino de aculatarse y comienza atencion. Fin atencion: 28.093404301103217
# Camion termino de aculatarse y comienza atencion. Fin atencion: 28.801422709288026
# Camion termino de aculatarse y comienza atencion. Fin atencion: 30.305257280126423
# Camion termino de aculatarse y comienza atencion. Fin atencion: 33.59661271823175
# Camion termino de aculatarse y comienza atencion. Fin atencion: 34.743850108148315
# Camion termino de aculatarse y comienza atencion. Fin atencion: 35.20184555285462
# Camion termino de aculatarse y comienza atencion. Fin atencion: 38.57495331213369
# Camion termino de aculatarse y comienza atencion. Fin atencion: 42.20024727259147
# Camion termino de aculatarse y comienza atencion. Fin atencion: 41.48676044303207
# Camion termino de aculatarse y comienza atencion. Fin atencion: 47.49076743112714
# Camion termino de aculatarse y comienza atencion. Fin atencion: 49.74136867453595
# Camion termino de aculatarse y comienza atencion. Fin atencion: 50.122847347086605
# Camion termino de aculatarse y comienza atencion. Fin atencion: 88.84406265009387
# Camion termino de aculatarse y comienza atencion. Fin atencion: 89.84286921058069
# Camion termino de aculatarse y comienza atencion. Fin atencion: 90.13350842976728
# Camion termino de aculatarse y comienza atencion. Fin atencion: 91.9329335280703
# Camion termino de aculatarse y comienza atencion. Fin atencion: 91.36510846921298
# Camion termino de aculatarse y comienza atencion. Fin atencion: 93.58370725868525
# Camion termino de aculatarse y comienza atencion. Fin atencion: 94.59107529293324
# Camion termino de aculatarse y comienza atencion. Fin atencion: 96.46270174166159
# Camion termino de aculatarse y comienza atencion. Fin atencion: 95.58837022505676
# Camion termino de aculatarse y comienza atencion. Fin atencion: 96.82865866300143
# Camion termino de aculatarse y comienza atencion. Fin atencion: 97.47075213305449
# Camion termino de aculatarse y comienza atencion. Fin atencion: 98.21453576313509
# Camion termino de aculatarse y comienza atencion. Fin atencion: 98.77143766326911
# Camion termino de aculatarse y comienza atencion. Fin atencion: 99.75303976300634
# Camion termino de aculatarse y comienza atencion. Fin atencion: 101.5637907558162
# Camion termino de aculatarse y comienza atencion. Fin atencion: 102.49749001267578
# Camion termino de aculatarse y comienza atencion. Fin atencion: 101.9591971619596
# Camion termino de aculatarse y comienza atencion. Fin atencion: 102.42177446445409
# Camion termino de aculatarse y comienza atencion. Fin atencion: 103.48433662152596
# Camion termino de aculatarse y comienza atencion. Fin atencion: 103.66272753549983
# Camion termino de aculatarse y comienza atencion. Fin atencion: 103.87350141921156
# Camion termino de aculatarse y comienza atencion. Fin atencion: 104.68117897038677
# Camion termino de aculatarse y comienza atencion. Fin atencion: 105.2433968657009
# Camion termino de aculatarse y comienza atencion. Fin atencion: 105.80882933215263
# Camion termino de aculatarse y comienza atencion. Fin atencion: 107.46040107419817
# Camion termino de aculatarse y comienza atencion. Fin atencion: 108.53833707448553
# Camion termino de aculatarse y comienza atencion. Fin atencion: 109.5625053004152
# Camion termino de aculatarse y comienza atencion. Fin atencion: 108.8150570185575
# Camion termino de aculatarse y comienza atencion. Fin atencion: 110.54410112081393
# Camion termino de aculatarse y comienza atencion. Fin atencion: 110.97771285262537
# Camion termino de aculatarse y comienza atencion. Fin atencion: 110.6717301272785
# Camion termino de aculatarse y comienza atencion. Fin atencion: 110.82419830887171
# Camion termino de aculatarse y comienza atencion. Fin atencion: 112.38936722045736
# Camion termino de aculatarse y comienza atencion. Fin atencion: 113.12636623465563
# Camion termino de aculatarse y comienza atencion. Fin atencion: 113.60243379098257
# Camion termino de aculatarse y comienza atencion. Fin atencion: 114.94688238629875
# Camion termino de aculatarse y comienza atencion. Fin atencion: 114.54171128127686
# Camion termino de aculatarse y comienza atencion. Fin atencion: 115.27599459748346
# Camion termino de aculatarse y comienza atencion. Fin atencion: 116.01808102598419
# Camion termino de aculatarse y comienza atencion. Fin atencion: 115.49571475531059
# Camion termino de aculatarse y comienza atencion. Fin atencion: 118.38467888191485
# Camion termino de aculatarse y comienza atencion. Fin atencion: 119.1992876095453
# Camion termino de aculatarse y comienza atencion. Fin atencion: 119.35699439078414
# Camion termino de aculatarse y comienza atencion. Fin atencion: 119.73145049084896
# Camion termino de aculatarse y comienza atencion. Fin atencion: 120.49576607111602
# Camion termino de aculatarse y comienza atencion. Fin atencion: 121.90817167930105
# Camion termino de aculatarse y comienza atencion. Fin atencion: 121.4409095241644
# Camion termino de aculatarse y comienza atencion. Fin atencion: 122.65720415543136
# Camion termino de aculatarse y comienza atencion. Fin atencion: 122.3684302413525
# Camion termino de aculatarse y comienza atencion. Fin atencion: 124.2836657368828
# Camion termino de aculatarse y comienza atencion. Fin atencion: 124.32292646689517
# Camion termino de aculatarse y comienza atencion. Fin atencion: 124.56887499110293
# Camion termino de aculatarse y comienza atencion. Fin atencion: 125.3695026473189
# Camion termino de aculatarse y comienza atencion. Fin atencion: 127.37016742698212
# Camion termino de aculatarse y comienza atencion. Fin atencion: 126.71701617383597
# Camion termino de aculatarse y comienza atencion. Fin atencion: 132.19414808017615
# Camion termino de aculatarse y comienza atencion. Fin atencion: 133.80196985462126
# Camion termino de aculatarse y comienza atencion. Fin atencion: 143.38940950536002
# Camion termino de aculatarse y comienza atencion. Fin atencion: 147.02859052226142
# Camion termino de aculatarse y comienza atencion. Fin atencion: 152.33129383909505
# Camion termino de aculatarse y comienza atencion. Fin atencion: 154.7584531590019
# Camion termino de aculatarse y comienza atencion. Fin atencion: 155.8400971382403
# Camion termino de aculatarse y comienza atencion. Fin atencion: 157.69284683234517
# Camion termino de aculatarse y comienza atencion. Fin atencion: 162.11556113271192
# Camion termino de aculatarse y comienza atencion. Fin atencion: 163.56389188836164
# Camion termino de aculatarse y comienza atencion. Fin atencion: 165.56609868452915
# Camion termino de aculatarse y comienza atencion. Fin atencion: 167.95112108434336
# Camion termino de aculatarse y comienza atencion. Fin atencion: 170.95687694022016
# Camion termino de aculatarse y comienza atencion. Fin atencion: 170.4999958670456
# Camion termino de aculatarse y comienza atencion. Fin atencion: 171.62116506575956
# Camion termino de aculatarse y comienza atencion. Fin atencion: 172.6820613154692
# Camion termino de aculatarse y comienza atencion. Fin atencion: 173.0661848734225
# Camion termino de aculatarse y comienza atencion. Fin atencion: 172.91033805438963
# Camion termino de aculatarse y comienza atencion. Fin atencion: 173.06376097255753
# Camion termino de aculatarse y comienza atencion. Fin atencion: 173.37201741926182
# Camion termino de aculatarse y comienza atencion. Fin atencion: 175.6605363918306
# Camion termino de aculatarse y comienza atencion. Fin atencion: 176.1724761863931
# Camion termino de aculatarse y comienza atencion. Fin atencion: 178.0928134460047
# Camion termino de aculatarse y comienza atencion. Fin atencion: 177.48068388156946
# Camion termino de aculatarse y comienza atencion. Fin atencion: 178.52260436033603
# Camion termino de aculatarse y comienza atencion. Fin atencion: 180.1509290510705
# Camion termino de aculatarse y comienza atencion. Fin atencion: 181.2065875020968
# Camion termino de aculatarse y comienza atencion. Fin atencion: 181.77243364440452
# Camion termino de aculatarse y comienza atencion. Fin atencion: 181.65806993980306
# Camion termino de aculatarse y comienza atencion. Fin atencion: 181.98592607012534
# Camion termino de aculatarse y comienza atencion. Fin atencion: 183.45944330613335
# Camion termino de aculatarse y comienza atencion. Fin atencion: 185.81397254181402
# Camion termino de aculatarse y comienza atencion. Fin atencion: 187.04910414448366
# Camion termino de aculatarse y comienza atencion. Fin atencion: 188.88388721286566
# Camion termino de aculatarse y comienza atencion. Fin atencion: 187.9677912106798
# Camion termino de aculatarse y comienza atencion. Fin atencion: 189.40245563208532
# Camion termino de aculatarse y comienza atencion. Fin atencion: 189.87714392507885
# Camion termino de aculatarse y comienza atencion. Fin atencion: 189.75776434637226
# Camion termino de aculatarse y comienza atencion. Fin atencion: 189.23300652677787
# Camion termino de aculatarse y comienza atencion. Fin atencion: 192.40730677896167
# Camion termino de aculatarse y comienza atencion. Fin atencion: 191.51528696931797
# Camion termino de aculatarse y comienza atencion. Fin atencion: 193.03200901883702
# Camion termino de aculatarse y comienza atencion. Fin atencion: 192.43481039623353
# Camion termino de aculatarse y comienza atencion. Fin atencion: 192.9559954649358
# Camion termino de aculatarse y comienza atencion. Fin atencion: 193.14408142313198
# Camion termino de aculatarse y comienza atencion. Fin atencion: 192.8029976069407
# Camion termino de aculatarse y comienza atencion. Fin atencion: 193.64647761740562
# Camion termino de aculatarse y comienza atencion. Fin atencion: 194.3980573492619
# Camion termino de aculatarse y comienza atencion. Fin atencion: 194.73906758570246
# Camion termino de aculatarse y comienza atencion. Fin atencion: 193.85753380342038
# Camion termino de aculatarse y comienza atencion. Fin atencion: 196.4391218345988
# Camion termino de aculatarse y comienza atencion. Fin atencion: 199.87010403166872
# Camion termino de aculatarse y comienza atencion. Fin atencion: 201.00213008517548
# Camion termino de aculatarse y comienza atencion. Fin atencion: 202.45865686473704
# Camion termino de aculatarse y comienza atencion. Fin atencion: 204.39184614076822
# Camion termino de aculatarse y comienza atencion. Fin atencion: 205.11680695560682
# Camion termino de aculatarse y comienza atencion. Fin atencion: 204.89953593344256
# Camion termino de aculatarse y comienza atencion. Fin atencion: 207.07455075737656
# Camion termino de aculatarse y comienza atencion. Fin atencion: 208.66422586776795
# Camion termino de aculatarse y comienza atencion. Fin atencion: 214.17310778226076
# Camion termino de aculatarse y comienza atencion. Fin atencion: 219.78925257356585
# Camion termino de aculatarse y comienza atencion. Fin atencion: 224.2077048018042
# Camion termino de aculatarse y comienza atencion. Fin atencion: 229.28624315687975
# Camion termino de aculatarse y comienza atencion. Fin atencion: 231.14329321939383
# Camion termino de aculatarse y comienza atencion. Fin atencion: 231.47254281771873
# Camion termino de aculatarse y comienza atencion. Fin atencion: 235.18079895132013
# Camion termino de aculatarse y comienza atencion. Fin atencion: 236.9825855095753
# Camion termino de aculatarse y comienza atencion. Fin atencion: 238.22550595585773
# Camion termino de aculatarse y comienza atencion. Fin atencion: 239.64025694724236
# Camion termino de aculatarse y comienza atencion. Fin atencion: 238.5968424004153
# Camion termino de aculatarse y comienza atencion. Fin atencion: 241.36555528747945
# Camion termino de aculatarse y comienza atencion. Fin atencion: 243.85343436039759
# Camion termino de aculatarse y comienza atencion. Fin atencion: 244.39376489101377
# Camion termino de aculatarse y comienza atencion. Fin atencion: 245.34919744835165
# Camion termino de aculatarse y comienza atencion. Fin atencion: 244.7790724696259
# Camion termino de aculatarse y comienza atencion. Fin atencion: 245.47386504689285
# Camion termino de aculatarse y comienza atencion. Fin atencion: 246.79085980358914
# Camion termino de aculatarse y comienza atencion. Fin atencion: 247.99843399081996
# Camion termino de aculatarse y comienza atencion. Fin atencion: 249.2491025297832
# Camion termino de aculatarse y comienza atencion. Fin atencion: 250.58667111489152
# Camion termino de aculatarse y comienza atencion. Fin atencion: 250.21907831497805
# Camion termino de aculatarse y comienza atencion. Fin atencion: 250.330870307473
# Camion termino de aculatarse y comienza atencion. Fin atencion: 250.66499974394264
# Camion termino de aculatarse y comienza atencion. Fin atencion: 251.1762439161084
# Camion termino de aculatarse y comienza atencion. Fin atencion: 252.59759849455497
# Camion termino de aculatarse y comienza atencion. Fin atencion: 253.30516107083457
# Camion termino de aculatarse y comienza atencion. Fin atencion: 254.2732641202505
# Camion termino de aculatarse y comienza atencion. Fin atencion: 255.18126077436452
# Camion termino de aculatarse y comienza atencion. Fin atencion: 255.63823146401566
# Camion termino de aculatarse y comienza atencion. Fin atencion: 256.68755082377214
# Camion termino de aculatarse y comienza atencion. Fin atencion: 257.71567745838956
# Camion termino de aculatarse y comienza atencion. Fin atencion: 257.4132719001156
# Camion termino de aculatarse y comienza atencion. Fin atencion: 258.8522626523037
# Camion termino de aculatarse y comienza atencion. Fin atencion: 258.75296053867794
# Camion termino de aculatarse y comienza atencion. Fin atencion: 260.14952774695524
# Camion termino de aculatarse y comienza atencion. Fin atencion: 259.4885644105252
# Camion termino de aculatarse y comienza atencion. Fin atencion: 259.9404046580147
# Camion termino de aculatarse y comienza atencion. Fin atencion: 260.901227848975
# Camion termino de aculatarse y comienza atencion. Fin atencion: 261.57089368267043
# Camion termino de aculatarse y comienza atencion. Fin atencion: 262.16528355444285
# Camion termino de aculatarse y comienza atencion. Fin atencion: 263.60753393855083
# Camion termino de aculatarse y comienza atencion. Fin atencion: 263.24200318991063
# Camion termino de aculatarse y comienza atencion. Fin atencion: 264.87637985161507
# Camion termino de aculatarse y comienza atencion. Fin atencion: 266.071717373831
# Camion termino de aculatarse y comienza atencion. Fin atencion: 265.87061841016737
# Camion termino de aculatarse y comienza atencion. Fin atencion: 266.6485227234053
# Camion termino de aculatarse y comienza atencion. Fin atencion: 268.37961796422456
# Camion termino de aculatarse y comienza atencion. Fin atencion: 267.53745301171574
# Camion termino de aculatarse y comienza atencion. Fin atencion: 267.8775745199895
# Camion termino de aculatarse y comienza atencion. Fin atencion: 268.56698750300393
# Camion termino de aculatarse y comienza atencion. Fin atencion: 268.9612803231736
# Camion termino de aculatarse y comienza atencion. Fin atencion: 268.77855980752264
# Camion termino de aculatarse y comienza atencion. Fin atencion: 271.7884238676566
# Camion termino de aculatarse y comienza atencion. Fin atencion: 274.1957495764861
# Camion termino de aculatarse y comienza atencion. Fin atencion: 273.9871700169767
# Camion termino de aculatarse y comienza atencion. Fin atencion: 275.2450124000296
# Camion termino de aculatarse y comienza atencion. Fin atencion: 274.70444881500043
# Camion termino de aculatarse y comienza atencion. Fin atencion: 276.95481150317613
# Camion termino de aculatarse y comienza atencion. Fin atencion: 278.8952429959658
# Camion termino de aculatarse y comienza atencion. Fin atencion: 279.2190024756009
# Camion termino de aculatarse y comienza atencion. Fin atencion: 279.2388057170452
# Camion termino de aculatarse y comienza atencion. Fin atencion: 280.0542053674334
# Camion termino de aculatarse y comienza atencion. Fin atencion: 281.2374876884365
# Camion termino de aculatarse y comienza atencion. Fin atencion: 282.9905526715003
# Camion termino de aculatarse y comienza atencion. Fin atencion: 283.5077623237625
# Camion termino de aculatarse y comienza atencion. Fin atencion: 284.8666215041201
# Camion termino de aculatarse y comienza atencion. Fin atencion: 287.87312065448185
# Camion termino de aculatarse y comienza atencion. Fin atencion: 291.36310909930467
# Camion termino de aculatarse y comienza atencion. Fin atencion: 292.87452394087444
# Camion termino de aculatarse y comienza atencion. Fin atencion: 298.45031329372966
# Camion termino de aculatarse y comienza atencion. Fin atencion: 300.74426444263446
# Camion termino de aculatarse y comienza atencion. Fin atencion: 302.1600410556143
# Camion termino de aculatarse y comienza atencion. Fin atencion: 303.0179847202198
# Camion termino de aculatarse y comienza atencion. Fin atencion: 304.2890017947344
# Camion termino de aculatarse y comienza atencion. Fin atencion: 305.09796611090917
# Camion termino de aculatarse y comienza atencion. Fin atencion: 308.4470503345701
# Camion termino de aculatarse y comienza atencion. Fin atencion: 310.50830919617283
# Camion termino de aculatarse y comienza atencion. Fin atencion: 311.8243067642015
# Camion termino de aculatarse y comienza atencion. Fin atencion: 312.3803258922594
# Camion termino de aculatarse y comienza atencion. Fin atencion: 315.5197824861211
# Camion termino de aculatarse y comienza atencion. Fin atencion: 315.0806770463562
# Camion termino de aculatarse y comienza atencion. Fin atencion: 316.43477645028634
# Camion termino de aculatarse y comienza atencion. Fin atencion: 319.390004305244
# Camion termino de aculatarse y comienza atencion. Fin atencion: 321.1004611448532
# Camion termino de aculatarse y comienza atencion. Fin atencion: 328.29865649682864
# Camion termino de aculatarse y comienza atencion. Fin atencion: 329.0323961790695
# Camion termino de aculatarse y comienza atencion. Fin atencion: 329.0725298009163
# Camion termino de aculatarse y comienza atencion. Fin atencion: 330.91798526053975
# Camion termino de aculatarse y comienza atencion. Fin atencion: 332.20275024666756
# Camion termino de aculatarse y comienza atencion. Fin atencion: 336.27162559489034
# Camion termino de aculatarse y comienza atencion. Fin atencion: 337.9967463716533
# Camion termino de aculatarse y comienza atencion. Fin atencion: 337.6331643651299
# Camion termino de aculatarse y comienza atencion. Fin atencion: 340.15541402349277
# Camion termino de aculatarse y comienza atencion. Fin atencion: 340.26552469357426
# Camion termino de aculatarse y comienza atencion. Fin atencion: 340.68620278367416
# Camion termino de aculatarse y comienza atencion. Fin atencion: 341.8541750714306
# Camion termino de aculatarse y comienza atencion. Fin atencion: 343.6705727970139
# Camion termino de aculatarse y comienza atencion. Fin atencion: 343.8330607817984
# Camion termino de aculatarse y comienza atencion. Fin atencion: 346.7004021439126
# Camion termino de aculatarse y comienza atencion. Fin atencion: 355.216774341083
# Camion termino de aculatarse y comienza atencion. Fin atencion: 355.72179931941616
# Camion termino de aculatarse y comienza atencion. Fin atencion: 356.3662555635399
# Camion termino de aculatarse y comienza atencion. Fin atencion: 362.15077709975645
# Camion termino de aculatarse y comienza atencion. Fin atencion: 363.5294141591267
# Camion termino de aculatarse y comienza atencion. Fin atencion: 364.87337875143686
# Camion termino de aculatarse y comienza atencion. Fin atencion: 369.5137315100188
# Camion termino de aculatarse y comienza atencion. Fin atencion: 369.33194004897524
# Camion termino de aculatarse y comienza atencion. Fin atencion: 378.7981089743211
# Camion termino de aculatarse y comienza atencion. Fin atencion: 379.5579060132884
# Camion termino de aculatarse y comienza atencion. Fin atencion: 382.9017439373497
# Camion termino de aculatarse y comienza atencion. Fin atencion: 386.4945833535237
# Camion termino de aculatarse y comienza atencion. Fin atencion: 387.6289076144277
# Camion termino de aculatarse y comienza atencion. Fin atencion: 389.959056765956
# Camion termino de aculatarse y comienza atencion. Fin atencion: 391.192490709268
# Camion termino de aculatarse y comienza atencion. Fin atencion: 391.49208956193377
# Camion termino de aculatarse y comienza atencion. Fin atencion: 392.2948524469128
# Camion termino de aculatarse y comienza atencion. Fin atencion: 406.9427035886408
# Camion termino de aculatarse y comienza atencion. Fin atencion: 408.48932653700314
# Camion termino de aculatarse y comienza atencion. Fin atencion: 408.86856851887956
# Camion termino de aculatarse y comienza atencion. Fin atencion: 413.3074676342119
# Camion termino de aculatarse y comienza atencion. Fin atencion: 414.77655694765656
# Camion termino de aculatarse y comienza atencion. Fin atencion: 414.95727864480307
# Camion termino de aculatarse y comienza atencion. Fin atencion: 416.74338016311594
# Camion termino de aculatarse y comienza atencion. Fin atencion: 416.420235349032
# Camion termino de aculatarse y comienza atencion. Fin atencion: 419.725088176875
# Camion termino de aculatarse y comienza atencion. Fin atencion: 420.22087974278696
# Camion termino de aculatarse y comienza atencion. Fin atencion: 423.112596012585
# Camion termino de aculatarse y comienza atencion. Fin atencion: 424.7616981113338
# Camion termino de aculatarse y comienza atencion. Fin atencion: 426.74197997623105
# Camion termino de aculatarse y comienza atencion. Fin atencion: 426.1720881864353
# Camion termino de aculatarse y comienza atencion. Fin atencion: 426.7249445481173
# Camion termino de aculatarse y comienza atencion. Fin atencion: 426.81375653522144
# Camion termino de aculatarse y comienza atencion. Fin atencion: 427.10439089697155
# Camion termino de aculatarse y comienza atencion. Fin atencion: 428.88660262436355
# Camion termino de aculatarse y comienza atencion. Fin atencion: 428.79033380113
# Camion termino de aculatarse y comienza atencion. Fin atencion: 430.3163525791048
# Camion termino de aculatarse y comienza atencion. Fin atencion: 430.0617350256557
# Camion termino de aculatarse y comienza atencion. Fin atencion: 431.525152365608
# Camion termino de aculatarse y comienza atencion. Fin atencion: 433.5675018606118
# Camion termino de aculatarse y comienza atencion. Fin atencion: 438.05796952205674
# Camion termino de aculatarse y comienza atencion. Fin atencion: 438.77323522257905
# Camion termino de aculatarse y comienza atencion. Fin atencion: 439.76065989517224
# Camion termino de aculatarse y comienza atencion. Fin atencion: 440.0029670025614
# Camion termino de aculatarse y comienza atencion. Fin atencion: 447.14352703144704
# Camion termino de aculatarse y comienza atencion. Fin atencion: 447.1131563329521
# Camion termino de aculatarse y comienza atencion. Fin atencion: 448.1795919727937
# Camion termino de aculatarse y comienza atencion. Fin atencion: 454.68373029465937
# Camion termino de aculatarse y comienza atencion. Fin atencion: 457.23360440167653
# Camion termino de aculatarse y comienza atencion. Fin atencion: 467.7038668649462
# Camion termino de aculatarse y comienza atencion. Fin atencion: 472.56439830410744
# Camion termino de aculatarse y comienza atencion. Fin atencion: 473.9769107639887
# Camion termino de aculatarse y comienza atencion. Fin atencion: 479.2124032089871
# Camion termino de aculatarse y comienza atencion. Fin atencion: 480.9233312295229
# Camion termino de aculatarse y comienza atencion. Fin atencion: 482.39019721524676
# Camion termino de aculatarse y comienza atencion. Fin atencion: 482.30416975645375
# Camion termino de aculatarse y comienza atencion. Fin atencion: 483.4422211701291
# Camion termino de aculatarse y comienza atencion. Fin atencion: 482.71321603288897
# Camion termino de aculatarse y comienza atencion. Fin atencion: 482.85439367409685
# Camion termino de aculatarse y comienza atencion. Fin atencion: 483.0077873597916
# Camion termino de aculatarse y comienza atencion. Fin atencion: 486.4950385100716
# Camion termino de aculatarse y comienza atencion. Fin atencion: 486.5953359699206
# Camion termino de aculatarse y comienza atencion. Fin atencion: 487.3648493044493
# Camion termino de aculatarse y comienza atencion. Fin atencion: 489.0476982364755
# Camion termino de aculatarse y comienza atencion. Fin atencion: 488.51652309317757
# Camion termino de aculatarse y comienza atencion. Fin atencion: 489.8820951794545
# Camion termino de aculatarse y comienza atencion. Fin atencion: 490.3148253547121
# Camion termino de aculatarse y comienza atencion. Fin atencion: 491.10075016765654
# Camion termino de aculatarse y comienza atencion. Fin atencion: 491.55402344671126
# Camion termino de aculatarse y comienza atencion. Fin atencion: 490.9508375842266
# Camion termino de aculatarse y comienza atencion. Fin atencion: 491.45241393257425
# Camion termino de aculatarse y comienza atencion. Fin atencion: 491.8562365957739
# Camion termino de aculatarse y comienza atencion. Fin atencion: 493.96175741080293
# Camion termino de aculatarse y comienza atencion. Fin atencion: 494.8417414938394
# Camion termino de aculatarse y comienza atencion. Fin atencion: 494.87359547578865
# Camion termino de aculatarse y comienza atencion. Fin atencion: 495.8557119252706
# Camion termino de aculatarse y comienza atencion. Fin atencion: 496.7066003626042
# Camion termino de aculatarse y comienza atencion. Fin atencion: 496.93524686667695
# Camion termino de aculatarse y comienza atencion. Fin atencion: 498.82234032018977
# Camion termino de aculatarse y comienza atencion. Fin atencion: 499.65789830840396
# Camion termino de aculatarse y comienza atencion. Fin atencion: 499.1467462887361
# Camion termino de aculatarse y comienza atencion. Fin atencion: 499.4568501220057
# Camion termino de aculatarse y comienza atencion. Fin atencion: 501.5609083789897
# Camion termino de aculatarse y comienza atencion. Fin atencion: 501.2337434673623
# Camion termino de aculatarse y comienza atencion. Fin atencion: 501.4952736694659
# Camion termino de aculatarse y comienza atencion. Fin atencion: 504.93724378829984
# Camion termino de aculatarse y comienza atencion. Fin atencion: 504.87132820967446
# Camion termino de aculatarse y comienza atencion. Fin atencion: 505.3875644238859
# Camion termino de aculatarse y comienza atencion. Fin atencion: 505.65884651274257
# Camion termino de aculatarse y comienza atencion. Fin atencion: 506.56472320459056
# Camion termino de aculatarse y comienza atencion. Fin atencion: 507.3080248980536
# Camion termino de aculatarse y comienza atencion. Fin atencion: 507.72288824728525
# Camion termino de aculatarse y comienza atencion. Fin atencion: 508.1721957976353
# Camion termino de aculatarse y comienza atencion. Fin atencion: 509.87483719654205
# Camion termino de aculatarse y comienza atencion. Fin atencion: 510.64840055528504
# Camion termino de aculatarse y comienza atencion. Fin atencion: 511.7411903418312
# Camion termino de aculatarse y comienza atencion. Fin atencion: 512.3989783938124
# Camion termino de aculatarse y comienza atencion. Fin atencion: 513.5244344569122
# Camion termino de aculatarse y comienza atencion. Fin atencion: 515.0560468780728
# Camion termino de aculatarse y comienza atencion. Fin atencion: 519.0362862370363
# Camion termino de aculatarse y comienza atencion. Fin atencion: 519.8056710756665
# Camion termino de aculatarse y comienza atencion. Fin atencion: 519.7567686032969
# Camion termino de aculatarse y comienza atencion. Fin atencion: 523.3648168377309
# Camion termino de aculatarse y comienza atencion. Fin atencion: 523.6960713631307
# Camion termino de aculatarse y comienza atencion. Fin atencion: 526.7554626472862
# Camion termino de aculatarse y comienza atencion. Fin atencion: 527.6728753870069
# Camion termino de aculatarse y comienza atencion. Fin atencion: 527.6162445081849
# Camion termino de aculatarse y comienza atencion. Fin atencion: 532.3344867721705
# Camion termino de aculatarse y comienza atencion. Fin atencion: 534.6189012584038
# Camion termino de aculatarse y comienza atencion. Fin atencion: 537.2608926819481
# Camion termino de aculatarse y comienza atencion. Fin atencion: 539.1883961491085
# Camion termino de aculatarse y comienza atencion. Fin atencion: 541.764494350621
# Camion termino de aculatarse y comienza atencion. Fin atencion: 541.317381065667
# Camion termino de aculatarse y comienza atencion. Fin atencion: 545.3408613009931
# Camion termino de aculatarse y comienza atencion. Fin atencion: 545.0815306122782
# Camion termino de aculatarse y comienza atencion. Fin atencion: 545.6762798122315
# Camion termino de aculatarse y comienza atencion. Fin atencion: 547.0037701025831
# Camion termino de aculatarse y comienza atencion. Fin atencion: 549.1014020174875
# Camion termino de aculatarse y comienza atencion. Fin atencion: 551.3453810468085
# Camion termino de aculatarse y comienza atencion. Fin atencion: 550.763099753
# Camion termino de aculatarse y comienza atencion. Fin atencion: 554.3839541672405
# Camion termino de aculatarse y comienza atencion. Fin atencion: 554.8381516982362
# Camion termino de aculatarse y comienza atencion. Fin atencion: 555.6311990846989
# Camion termino de aculatarse y comienza atencion. Fin atencion: 557.0240689079502
# Camion termino de aculatarse y comienza atencion. Fin atencion: 557.6517949862965
# Camion termino de aculatarse y comienza atencion. Fin atencion: 558.3202685179765
# Camion termino de aculatarse y comienza atencion. Fin atencion: 560.0167619478228
# Camion termino de aculatarse y comienza atencion. Fin atencion: 559.4685041124975
# Camion termino de aculatarse y comienza atencion. Fin atencion: 559.797208339373
# Camion termino de aculatarse y comienza atencion. Fin atencion: 560.6221863154499
# Camion termino de aculatarse y comienza atencion. Fin atencion: 561.7914453939424
# Camion termino de aculatarse y comienza atencion. Fin atencion: 562.0906031285432
# Camion termino de aculatarse y comienza atencion. Fin atencion: 561.6839534892948
# Camion termino de aculatarse y comienza atencion. Fin atencion: 564.2475084335667
# Camion termino de aculatarse y comienza atencion. Fin atencion: 564.3602598293277
# Camion termino de aculatarse y comienza atencion. Fin atencion: 565.3912339321757
# Camion termino de aculatarse y comienza atencion. Fin atencion: 565.866933774951
# Camion termino de aculatarse y comienza atencion. Fin atencion: 566.2913120561689
# Camion termino de aculatarse y comienza atencion. Fin atencion: 567.2561402201446
# Camion termino de aculatarse y comienza atencion. Fin atencion: 568.1803439086088
# Camion termino de aculatarse y comienza atencion. Fin atencion: 569.2383365382749
# Camion termino de aculatarse y comienza atencion. Fin atencion: 568.9151481497879
# Camion termino de aculatarse y comienza atencion. Fin atencion: 569.961571677798
# Camion termino de aculatarse y comienza atencion. Fin atencion: 570.5695807445726
# Camion termino de aculatarse y comienza atencion. Fin atencion: 571.1500206125392
# Camion termino de aculatarse y comienza atencion. Fin atencion: 573.0822583583988
# Camion termino de aculatarse y comienza atencion. Fin atencion: 572.7345195757267
# Camion termino de aculatarse y comienza atencion. Fin atencion: 572.562294429477
# Camion termino de aculatarse y comienza atencion. Fin atencion: 572.7980220710539
# Camion termino de aculatarse y comienza atencion. Fin atencion: 574.0449100706571
# Camion termino de aculatarse y comienza atencion. Fin atencion: 574.8341578265274
# Camion termino de aculatarse y comienza atencion. Fin atencion: 575.2708847192416
# Camion termino de aculatarse y comienza atencion. Fin atencion: 576.2782759237637
# Camion termino de aculatarse y comienza atencion. Fin atencion: 576.875969365028
# Camion termino de aculatarse y comienza atencion. Fin atencion: 577.8146935218736
# Camion termino de aculatarse y comienza atencion. Fin atencion: 580.442298817669
# Camion termino de aculatarse y comienza atencion. Fin atencion: 580.7851720477446
# Camion termino de aculatarse y comienza atencion. Fin atencion: 581.6732781068265
# Camion termino de aculatarse y comienza atencion. Fin atencion: 583.2783537903739
# Camion termino de aculatarse y comienza atencion. Fin atencion: 584.3030426554731
# Camion termino de aculatarse y comienza atencion. Fin atencion: 585.2616237710081
# Camion termino de aculatarse y comienza atencion. Fin atencion: 587.0746603727923
# Camion termino de aculatarse y comienza atencion. Fin atencion: 588.6574096528266
# Camion termino de aculatarse y comienza atencion. Fin atencion: 591.9449414323688
# Camion termino de aculatarse y comienza atencion. Fin atencion: 591.9774810265102
# Camion termino de aculatarse y comienza atencion. Fin atencion: 594.4893796834219
# Camion termino de aculatarse y comienza atencion. Fin atencion: 594.2352126368654
# Camion termino de aculatarse y comienza atencion. Fin atencion: 594.9806160982356
# Camion termino de aculatarse y comienza atencion. Fin atencion: 595.1194558219833
# Camion termino de aculatarse y comienza atencion. Fin atencion: 597.2540015786536
# Camion termino de aculatarse y comienza atencion. Fin atencion: 598.7569623106805
# Camion termino de aculatarse y comienza atencion. Fin atencion: 601.0544864774307
# Camion termino de aculatarse y comienza atencion. Fin atencion: 601.98725129271
# Camion termino de aculatarse y comienza atencion. Fin atencion: 601.2318150478936
# Camion termino de aculatarse y comienza atencion. Fin atencion: 602.3274037987901
# Camion termino de aculatarse y comienza atencion. Fin atencion: 605.9883360169993
# Camion termino de aculatarse y comienza atencion. Fin atencion: 607.2940178151315
# Camion termino de aculatarse y comienza atencion. Fin atencion: 608.635841702023
# Camion termino de aculatarse y comienza atencion. Fin atencion: 613.2112634534516
# Camion termino de aculatarse y comienza atencion. Fin atencion: 615.8741885864657
# Camion termino de aculatarse y comienza atencion. Fin atencion: 615.7719515595866
# Camion termino de aculatarse y comienza atencion. Fin atencion: 617.5538857721755
# Camion termino de aculatarse y comienza atencion. Fin atencion: 618.4088161649834
# Camion termino de aculatarse y comienza atencion. Fin atencion: 620.318936405503
# Camion termino de aculatarse y comienza atencion. Fin atencion: 621.4921478770827
# Camion termino de aculatarse y comienza atencion. Fin atencion: 621.888812909207
# Camion termino de aculatarse y comienza atencion. Fin atencion: 622.6088615145154
# Camion termino de aculatarse y comienza atencion. Fin atencion: 625.7515672650505
# Camion termino de aculatarse y comienza atencion. Fin atencion: 625.2686934518651
# Camion termino de aculatarse y comienza atencion. Fin atencion: 626.7918783907957
# Camion termino de aculatarse y comienza atencion. Fin atencion: 626.9451548611003
# Camion termino de aculatarse y comienza atencion. Fin atencion: 627.5470080721732
# Camion termino de aculatarse y comienza atencion. Fin atencion: 628.8747674872549
# Camion termino de aculatarse y comienza atencion. Fin atencion: 629.0932075531612
# Camion termino de aculatarse y comienza atencion. Fin atencion: 630.2690740521764
# Camion termino de aculatarse y comienza atencion. Fin atencion: 630.2350908079829
# Camion termino de aculatarse y comienza atencion. Fin atencion: 632.27151491019
# Camion termino de aculatarse y comienza atencion. Fin atencion: 632.1068774267067
# Camion termino de aculatarse y comienza atencion. Fin atencion: 632.4347020442065
# Camion termino de aculatarse y comienza atencion. Fin atencion: 633.5951057751286
# Camion termino de aculatarse y comienza atencion. Fin atencion: 634.3272754309402
# Camion termino de aculatarse y comienza atencion. Fin atencion: 634.3437250136932
# Camion termino de aculatarse y comienza atencion. Fin atencion: 635.2724076638033
# Camion termino de aculatarse y comienza atencion. Fin atencion: 634.8578615548136
# Camion termino de aculatarse y comienza atencion. Fin atencion: 637.057056579889
# Camion termino de aculatarse y comienza atencion. Fin atencion: 637.8678516426429
# Camion termino de aculatarse y comienza atencion. Fin atencion: 638.1245341778623
# Camion termino de aculatarse y comienza atencion. Fin atencion: 639.9554949091058
# Camion termino de aculatarse y comienza atencion. Fin atencion: 638.7995122273252
# Camion termino de aculatarse y comienza atencion. Fin atencion: 639.7018525881327
# Camion termino de aculatarse y comienza atencion. Fin atencion: 641.3413041482255
# Camion termino de aculatarse y comienza atencion. Fin atencion: 641.3673711968812
# Camion termino de aculatarse y comienza atencion. Fin atencion: 645.716818509661
# Camion termino de aculatarse y comienza atencion. Fin atencion: 645.3747317646865
# Camion termino de aculatarse y comienza atencion. Fin atencion: 646.0364495147246
# Camion termino de aculatarse y comienza atencion. Fin atencion: 647.0131407225463
# Camion termino de aculatarse y comienza atencion. Fin atencion: 648.7264549771518
# Camion termino de aculatarse y comienza atencion. Fin atencion: 649.3255273324828
# Camion termino de aculatarse y comienza atencion. Fin atencion: 649.025995758551
# Camion termino de aculatarse y comienza atencion. Fin atencion: 651.2592489090924
# Camion termino de aculatarse y comienza atencion. Fin atencion: 651.9932122313922
# Camion termino de aculatarse y comienza atencion. Fin atencion: 652.2636161421647
# Camion termino de aculatarse y comienza atencion. Fin atencion: 653.7794108496117
# Camion termino de aculatarse y comienza atencion. Fin atencion: 654.5008884503637
# Camion termino de aculatarse y comienza atencion. Fin atencion: 654.4109574307746
# Camion termino de aculatarse y comienza atencion. Fin atencion: 656.0615989465539
# Camion termino de aculatarse y comienza atencion. Fin atencion: 657.6093830889454
# Camion termino de aculatarse y comienza atencion. Fin atencion: 660.3189467596884
# Camion termino de aculatarse y comienza atencion. Fin atencion: 661.4528018275549
# Camion termino de aculatarse y comienza atencion. Fin atencion: 661.9498448772114
# Camion termino de aculatarse y comienza atencion. Fin atencion: 662.780384156697
# Camion termino de aculatarse y comienza atencion. Fin atencion: 666.639660615019
# Camion termino de aculatarse y comienza atencion. Fin atencion: 668.1672941063623
# Camion termino de aculatarse y comienza atencion. Fin atencion: 669.8400786335948
# Camion termino de aculatarse y comienza atencion. Fin atencion: 670.3727271141225
# Camion termino de aculatarse y comienza atencion. Fin atencion: 671.968646325658
# Camion termino de aculatarse y comienza atencion. Fin atencion: 673.2145081984677
# Camion termino de aculatarse y comienza atencion. Fin atencion: 673.4974667101964
# Camion termino de aculatarse y comienza atencion. Fin atencion: 674.3502327351305
# Camion termino de aculatarse y comienza atencion. Fin atencion: 675.2725284398992
# Camion termino de aculatarse y comienza atencion. Fin atencion: 677.1474284786185
# Camion termino de aculatarse y comienza atencion. Fin atencion: 677.0808214333273
# Camion termino de aculatarse y comienza atencion. Fin atencion: 679.2374038736422
# Camion termino de aculatarse y comienza atencion. Fin atencion: 682.7179394137437
# Camion termino de aculatarse y comienza atencion. Fin atencion: 681.65973748913
# Camion termino de aculatarse y comienza atencion. Fin atencion: 691.1572465004141
# Camion termino de aculatarse y comienza atencion. Fin atencion: 691.5566785392881
# Camion termino de aculatarse y comienza atencion. Fin atencion: 691.8809249231509
# Camion termino de aculatarse y comienza atencion. Fin atencion: 695.3476070376943
# Camion termino de aculatarse y comienza atencion. Fin atencion: 696.0598210112094
# Camion termino de aculatarse y comienza atencion. Fin atencion: 696.6601785178809
# Camion termino de aculatarse y comienza atencion. Fin atencion: 696.8085762038842
# Camion termino de aculatarse y comienza atencion. Fin atencion: 697.335722038019
# Camion termino de aculatarse y comienza atencion. Fin atencion: 698.0166508776881
# Camion termino de aculatarse y comienza atencion. Fin atencion: 699.6848598290173
# Camion termino de aculatarse y comienza atencion. Fin atencion: 699.2741279291189
# Camion termino de aculatarse y comienza atencion. Fin atencion: 699.206409682135
# Camion termino de aculatarse y comienza atencion. Fin atencion: 703.122537956665
# Camion termino de aculatarse y comienza atencion. Fin atencion: 702.6028154208059
# Camion termino de aculatarse y comienza atencion. Fin atencion: 703.8433809884791
# Camion termino de aculatarse y comienza atencion. Fin atencion: 704.5074863889421
# Camion termino de aculatarse y comienza atencion. Fin atencion: 705.6355087899091
# Camion termino de aculatarse y comienza atencion. Fin atencion: 706.2580007403301
# Camion termino de aculatarse y comienza atencion. Fin atencion: 706.4774287860704
# Camion termino de aculatarse y comienza atencion. Fin atencion: 707.0112882498411
# Camion termino de aculatarse y comienza atencion. Fin atencion: 708.0630282480706
# Camion termino de aculatarse y comienza atencion. Fin atencion: 709.8672065492672
# Camion termino de aculatarse y comienza atencion. Fin atencion: 709.6484937718507
# Camion termino de aculatarse y comienza atencion. Fin atencion: 711.7386776330261
# Camion termino de aculatarse y comienza atencion. Fin atencion: 712.7896683536187
# Camion termino de aculatarse y comienza atencion. Fin atencion: 713.0757999103557
# Camion termino de aculatarse y comienza atencion. Fin atencion: 714.2176224723855
# Camion termino de aculatarse y comienza atencion. Fin atencion: 716.3396128245772
# Camion termino de aculatarse y comienza atencion. Fin atencion: 716.4350904422135
# Camion termino de aculatarse y comienza atencion. Fin atencion: 716.7053189310635
# Camion termino de aculatarse y comienza atencion. Fin atencion: 716.7903320213603
# Camion termino de aculatarse y comienza atencion. Fin atencion: 716.4274284100453
# Camion termino de aculatarse y comienza atencion. Fin atencion: 716.6319454673833
# Camion termino de aculatarse y comienza atencion. Fin atencion: 718.134641474757
# Camion termino de aculatarse y comienza atencion. Fin atencion: 718.4726147243198
# Camion termino de aculatarse y comienza atencion. Fin atencion: 720.4271942631698
# Camion termino de aculatarse y comienza atencion. Fin atencion: 720.8304407664806
# El tiempo de simulacion fue: 0.1545872688293457 seconds ---

# %%
#D_Entidades["PA21"].toneladas_sacadas
TPH_Teorico(PL, D_Entidades["PA21"])
# Out:
# 5338.66265741645

# %%
Input_Dinamico(D_Entidades["PA21"].toneladas_sacadas, Reloj)
# Out:
# (2424, {'S2': 1212, 'CS03': 303, 'S1': 909})
