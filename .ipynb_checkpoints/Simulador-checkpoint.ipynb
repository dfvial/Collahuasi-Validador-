# %%
import random
import numpy as np
from collections import deque
import pandas as pd 
import time

# %% [markdown]
# # Parámetros

# %%
#Horizonte de simulacion (Turnos)
Turnos = 1
Reloj = 0
tiempo_aculatamiento = 70/60
AlmuerzoTA = 60 #Duracion almuerzo turno A
Almuerzo1TB = 40 #Duracion colacion 1 turno B
Almuerzo2TB = 20 #Duracion colacion 2 turno B

# %%
#Se leen las caracteristicas de las palas
dfPalas = pd.read_excel('Informacion Palas.xlsx',  1)
InfoPalas = list(zip(dfPalas[dfPalas.columns[0]].values, dfPalas[dfPalas.columns[1]].values, dfPalas[dfPalas.columns[2]].values, \
                            dfPalas[dfPalas.columns[3]].values, dfPalas[dfPalas.columns[4]].values, \
                            dfPalas[dfPalas.columns[5]].values, dfPalas[dfPalas.columns[6]].values, \
                            dfPalas[dfPalas.columns[7]].values, dfPalas[dfPalas.columns[8]].values))

#Lista de nodos de mineral y esteril
Nodos_Mineral = ["PO1", "PO2", "PO3", "PO4", "PO5"]
Nodos_Esteril = ["PO6", "PO7", "PO8", "PO9", "PO10"]
Polvorazos = Nodos_Mineral + Nodos_Esteril


#Número de camiones disponibles
total_camiones = 8

#Lista de stocks/botaderos
#ID, espacios, ubicacion, tiempo_atencion ID=ubicacion?
SoB = ["S1", "S2"]
espacios = 5
tiempo_atencion_stock = 70/60 #segundos

#Se lee la informacion del chancador
dfChancador = pd.read_excel('Informacion Palas.xlsx',  0)
InfoChancador = list(zip(dfChancador[dfChancador.columns[0]].values, dfChancador[dfChancador.columns[1]].values, dfChancador[dfChancador.columns[2]].values, \
                            dfChancador[dfChancador.columns[3]].values, dfChancador[dfChancador.columns[4]].values, \
                            dfChancador[dfChancador.columns[5]].values, dfChancador[dfChancador.columns[6]].values, \
                            dfChancador[dfChancador.columns[7]].values, dfChancador[dfChancador.columns[8]].values))

# %% [markdown]
# # Dinamico

# %%
def dinamico(destinos, pala):
    return (random.choice(pala), random.choice(destinos))

# %% [markdown]
# # 1. Clases
# ## 1.1. Palas

# %%
class Pala:
    def __init__(self, ID, capacidad, ubicacion, media_recuperacion, media_falla, velocidad, tiempo_aculatado, min_carga, moda_carga, max_carga):
        self.ubicacion = ubicacion #Nodo en que esta ubicada la pala
        self.capacidad = capacidad #Capacidad nominal de excavacion
        self.ID = ID #ID pala
        self.fila = deque() #camiones en fila para se atendidos
        
        self.espacios_aculatamiento = [0, 0] #camiones aculatados 
        self.orden_llegada = deque() #orden de llegada al aculatamiento
        
        self.horas_eventos = {"Recuperacion":99999999, "Caida":9999999, "Inicio Movimiento":99999999, "Fin Movimiento":99999999, "Carga":999999} 
        self.proximo_evento = None #Nombre del evento mas proximo
        self.toneladas_sacadas = {} #Diccionario de tuplas con toneladas sacadas por posicion/nodo y ley
        self.TPH = {} #Diccionario con los resultados del PL
        
        self.media_recuperacion = media_recuperacion
        self.media_falla = media_falla
        self.velocidad = velocidad
        
        self.tiempo_aculatado = tiempo_aculatado
        
        self.min = min_carga
        self.moda = moda_carga
        self.max = max_carga
        
        self.hora_siguiente = 999999999
        self.disponibilidad = True
                     
    def caida(self, Reloj):#Completar comn PL y con Dinamico
        self.estado = 0
        #POR FUERA:
        #Se debe correr el PL y luego el dinámico para todos los camiones en la fila, y en camion hacia la pala
        #for cada camion if camion hacia pala.ID correr dinamico 
        self.horas_eventos["Caida"] = 99999999
        self.horas_eventos["Recuperacion"] = Reloj + self.tiempo_recuperacion()
        if self.horas_eventos["Recuperacion"] > self.horas_eventos["Inicio Movimiento"]:
            self.horas_eventos["Inicio Movimiento"] = self.horas_eventos["Recuperacion"] + 0.0001 #Postergo el movimiento hasta que se arregle la pala
        self.proximo_evento = "Recuperacion"
        return None
    
    def recuperacion(self, Reloj):
        self.estado = 1
        self.horas_eventos["Recuperacion"] = 99999999
        self.horas_eventos["Caida"] = Reloj + self.tiempo_falla()
        self.proximo_evento = min(self.horas_eventos, key=self.horas_eventos.get)
        self.hora_siguiente = self.horas_eventos[self.proximo_evento]
        return None
    
    def disponible(self):
        for espacio in self.espacios_aculatamiento:
            if espacio != 0:
                return True
        return False
    
  
    def fin_movimiento(self, Reloj, Lista_movimientos_agendados):
        pass
       
    def tiempo_recuperacion(self):
        return(np.random.exponential(self.media_recuperacion))
    
    def tiempo_falla(self):
        return(np.random.exponential(self.media_falla))
    
    def hora_proximo_evento(self):
        self.hora_siguiente = min(self.horas_eventos.values())
        return(self.hora_siguiente)
    
    def nombre_proximo_evento(self):
        self.proximo_evento = min(self.horas_eventos, key=self.horas_eventos.get)
        return(self.proximo_evento)
    
    def duracion_atencion(self):
        return(np.random.triangular(self.min, self.moda, self.max))
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# ## 1.2. Camiones

# %%
class Camion:
    def __init__(self, ID):
        self.ID = ID
        self.Nombre = "C"+str(ID)
        self.destino = "CS03"
        self.origen = "CS03"
        self.almuerzo = 0 #0: No almorzo, 1 primera colacion, 2 segunda colacion (solo aplica turno B)
        self.hora_siguiente = 0
        self.descargas = {} #Diccionario que almacena la historia de las descargas: key = (Origen, Destino)| value = toneladas
        self.carga = 0
        #self.aculatandose = False
        self.estado = "Descargando" #Viajando, Aculatandose, Cargando, Descargando, Almorzando, En fila
        self.OD = None
        
    def descargar(self, nuevo_destino, Reloj, TdV):
        self.toneladas = 0
        self.origen = self.destino
        self.destino = nuevo_destino
        if self.carga > 0:
            self.descargas[(self.origen, destino)] = self.carga 
        self.carga = 0
        self.estado = "Viajando"
        self.hora_siguiente = Reloj + TdV
        return None
    
    def cargar(self, toneladas_cargadas, nuevo_destino):
        self.origen = self.destino
        self.destino = nuevo_destino
        self.carga = toneladas_cargadas
        return None
    
    #def asignar_destino(self, Reloj, nuevo_destino, MTV):
    #    self.destino = nuevo_destino
    #    self.actualizar_estado("Viajando", Reloj + MTV[self.origen][self.destino])
    
    def actualizar_estado(self, Estado, Hora):
        self.estado = Estado 
        self.hora_siguiente = Hora
        
    def nuevo_viaje(self, Estado, Hora):
        self.estado = Estado 
        self.hora_siguiente = Hora
        self.origen = self.OD[0]
        self.destino = self.OD[1]
        
    def comenzar_almuerzo(self, destino, reloj, MTV, tiempo_colacion, almuerzo):
        self.origen = self.destino
        self.destino = destino
        self.estado = "Almorzando"
        self.hora_siguiente = Reloj + MTV[self.origen][self.destino] + tiempo_colacion
        self.almuerzo = almuerzo
        
    def __str__(self):
        return str(self.Nombre)
    def __unicode__(self):
        return str(self.Nombre)
    def __repr__(self):
        return str(self.Nombre)

# %% [markdown]
# ## 1.3. Stock - Botadero

# %%
class Stock:
    
    def __init__(self, ID, espacios, ubicacion, tiempo_atencion, tiempo_aculatado):
        self.ID = ID
        self.fila = deque()
        self.espacios_aculatamiento = [0 for i in range(espacios)]
        self.ubicacion = ubicacion
        self.tiempo_atencion = tiempo_atencion
        self.hora_siguiente = 99999999
        self.tiempo_aculatado = tiempo_aculatado 
    
    def avanzar_fila(self):
        camion = self.fila.popleft()
        return camion
    
    def duracion_atencion(self):
        return(self.tiempo_atencion)
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# ## 1.4. Chancador

# %%
class Chancador:
    
    def __init__(self, ID, ubicacion, media_falla, media_recuperacion, tiempo_aculatado, min_carga, moda_carga, max_carga):
        self.ID = ID
        self.ubicacion = ubicacion
        self.espacios_aculatamiento = [0, 0]
        self.fila = deque()
        self.media_falla = media_falla
        self.media_recuperacion = media_recuperacion
        self.tiempo_aculatado = tiempo_aculatado
        self.min = min_carga
        self.moda = moda_carga
        self.max = max_carga
        self.hora_siguiente = 999999999
        
    def tiempo_recuperacion(self):
        return(np.random.exponential(self.media_recuperacion))
    
    def tiempo_falla(self):
        return(np.random.exponential(self.media_falla))
    
    def hora_proximo_evento(self):
        return(min(horas_eventos.values()))
    
    def duracion_atencion(self):
        return(np.random.triangular(self.min, self.moda, self.max))
    
    def __str__(self):
        return str(self.ID)
    def __unicode__(self):
        return str(self.ID)
    def __repr__(self):
        return str(self.ID)

# %% [markdown]
# # 2. Simulación
# ## 2.1. Inicialización

# %%
#Se evalúa que palas estarán operativas y en que condición y se generan las instancias 
L_Entidades = []
#Esteril: 303
#Mineral: 293
D_Palas = {}
D_Entidades = {}
for pala in InfoPalas:
    u = np.random.uniform(0,1)
    
    if 0 <= u and u < pala[3]:
        pass
    
    elif pala[3] <= u and u < 1:#pala[4]
        D_Palas[pala[0]] = Pala(pala[0], "TONELADAS X CARGA", random.choice(Polvorazos), pala[2], pala[1], "velocidad", \
                                pala[8], pala[5], pala[6], pala[7])
        L_Entidades.append(D_Palas[pala[0]])
        D_Entidades[pala[0]] = D_Palas[pala[0]]
       
    else:
        #D_Palas[pala[0]] = Pala(pala[0], "TONELADAS X CARGA", random.choice(Polvorazos), pala[2], pala[1], "velocidad", \
        #                        pala[8], pala[5], pala[6], pala[7]) 
        #D_Palas[pala[0]].recuperacion(0)#Se inicializa el tiempo de la siguiente falla
        #print(pala[0], D_Palas[pala[0]].hora_siguiente)
        #L_Entidades.append(D_Palas[pala[0]])
        #D_Entidades[pala[0]] = D_Palas[pala[0]]
        pass
        
#Se inicializan los camiones
D_Camiones = {}
for i in range(total_camiones):
    D_Camiones[i] = Camion(i)
    L_Entidades.append(D_Camiones[i])
    D_Entidades[i] = D_Camiones[i]


    
#Se inicializan los stocks/botaderos
D_Stocks = {}
for stock in SoB:
    D_Stocks[stock] = Stock(stock, espacios, stock, tiempo_atencion_stock, tiempo_aculatamiento)
    L_Entidades.append(D_Stocks[stock])
    D_Entidades[stock] = D_Stocks[stock]
#print("Stocks y Botaderos :", D_Stocks)    

#Se inicializa el Chancador
D_Chancador ={}
for chancador in InfoChancador:
    D_Chancador[chancador[0]] = Chancador(chancador[0], "CS03", chancador[1], chancador[2], chancador[8], \
                                          chancador[5], chancador[6], chancador[7])
    L_Entidades.append(D_Chancador[chancador[0]])
    D_Entidades[chancador[0]] = D_Chancador[chancador[0]]
    
#print("Chancador: ", D_Chancador)


L_Entidades.sort(key=lambda x: x.hora_siguiente, reverse=False)

# %% [markdown]
# ## 2.2. Matriz de tiempos de viaje

# %%
MTV = {}
Destinos = []
Palas = []

for destino1 in L_Entidades:
    if destino1.__class__.__name__ in ["Stock", "Chancador"]:
        Destinos.append(destino1.ID)
        MTV[destino1.ID] = {}
        for destino2 in L_Entidades:
            if destino2.__class__.__name__ in ["Stock", "Chancador"]:
                MTV[destino1.ID][destino2.ID] = random.uniform(20, 40)
                    
    if destino1.__class__.__name__ == "Pala":
        Palas.append(destino1.ID)
    #La Matriz de tiempos de viajes debe ser entre los polvorazos y los destinos    
    
for destino1 in Polvorazos:
    MTV[destino1] = {}
    for key in MTV.keys():
        MTV[key][destino1] = random.uniform(20, 40)
        MTV[destino1][key] = random.uniform(20, 40)
    
MTV["CASINO"] = {}
for key in MTV.keys():
    MTV[key]["CASINO"] = random.uniform(20, 40)
    MTV["CASINO"][key] = random.uniform(20, 40)

# %%
#Identificamos el siguiente evento que va a ocurrir}
TurnoA = True
TurnoB = False
NTurnos = 0
start_time = time.time()
print("--- %s seconds ---" % (time.time() - start_time))
trucks = 0 
Entidad = L_Entidades[0]
Reloj = Entidad.hora_siguiente
while Reloj < 12*60:
    
    
    
    Entidad = L_Entidades[0]
    Reloj = Entidad.hora_siguiente
    NTurnos = int(Reloj/(12*60))
    print('------------------------------------------------------------')
    print(Entidad, Reloj)
    
    if int(Reloj/(12*60))%2 == 0 and TurnoB:
        #Se deben acutualizar todos los estados de almuerzo de los camiones
        for camion in D_Camiones.keys():
            D_Camiones[camion].almuerzo = 0
        TurnoB = False
        TurnoA = True
        
    elif int(Reloj/(12*60))%2 != 0 and TurnoA:
        #Se deben acutualizar todos los estados de almuerzo de los camiones
        for camion in D_Camiones.keys():
            D_Camiones[camion].almuerzo = 0   
        TurnoA = False
        TurnoB = True

    #En caso de que la entidad sea un camion
    if Entidad.__class__.__name__ == "Camion":
        print(Entidad, Entidad.origen, Entidad.destino, Entidad.estado, Reloj, Entidad.almuerzo)
        if Entidad.estado == "Almorzando":

            Entidad.estado = "Descargando"
        
            print("El camion {} termino de almorzar.".format(Entidad))
            
        if Entidad.estado == "Descargando":#Salida de un stock, botadero o chancador
            #Comienzo de almuerzos
            
            #Almuerzo turno A
            MIT = NTurnos*60*12 #Minuto en que inicio turno
            if (TurnoA and 0 <= Entidad.ID and Entidad.ID <= 40 and Reloj >= (4.5*60 + MIT) and Entidad.almuerzo == 0):
                Destino = D_Entidades[Entidad.destino]
                print("El camion {} se va a almorzar desde {}".format(Entidad, Destino))
                print("La cola en el destino es {}".format(Destino.fila))
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo("CASINO", Reloj, MTV, AlmuerzoTA, 1)
                print("La cola en el destino queda {}".format(Destino.fila))
                
                
            if (TurnoA and Entidad.ID > 40 and Reloj >= (6*60 + MIT) and Entidad.almuerzo ==0):
                Destino = D_Entidades[Entidad.destino]
                print("El camion {} se va a almorzar desde {}".format(Entidad, Destino))
                print("La cola en el destino es {}".format(Destino.fila))
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo("CASINO", Reloj, MTV, AlmuerzoTA, 1)
                print("La cola en el destino queda {}".format(Destino.fila))
            
            #Primera colacion turno B
            if (TurnoB and 0 <= Entidad.ID and Entidad.ID <= 27 and Reloj >= (5*60 + MIT) and Entidad.almuerzo == 0):
                Destino = D_Entidades[Entidad.destino]
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo(Entidad.destino, Reloj, MTV, Almuerzo1TB, 1)
                
            if (TurnoB and 28 <= Entidad.ID and Entidad.ID <= 54 and Reloj >= (5.5*60 + MIT)and Entidad.almuerzo == 0):
                Destino = D_Entidades[Entidad.destino]
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo(Entidad.destino, Reloj, MTV, Almuerzo1TB, 1)
                
            if (TurnoB and 55 <= Entidad.ID and Reloj >= (4.5*60 + MIT) and Entidad.almuerzo == 0):
                Destino = D_Entidades[Entidad.destino]
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo(Entidad.destino, Reloj, MTV, Almuerzo1TB, 1)
                
            #Segunda colacion turno B
            if (TurnoB and 0 <= Entidad.ID and Entidad.ID <= 45 and Reloj >= (9*60 + MIT) and Entidad.almuerzo == 1):
                Destino = D_Entidades[Entidad.destino]
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo(Entidad.destino, Reloj, MTV, Almuerzo2TB, 2)
                
            if (TurnoB and 46 <= Entidad.ID and Reloj >= (9.5*60 + MIT) and Entidad.almuerzo == 1):
                Destino = D_Entidades[Entidad.destino]
                if len(Destino.fila) > 0:
                    #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Siguiente = Destino.fila.popleft()
                    Destino.espacios_aculatamiento[i] = Siguiente
                    Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                else:
                    i = Destino.espacios_aculatamiento.index(Entidad)
                    Destino.espacios_aculatamiento[i] = 0
                Entidad.comenzar_almuerzo(Entidad.destino, Reloj, MTV, Almuerzo2TB, 2)
            
            #En caso contrario, hay que asignarle un nuevo destino corriendo el dinámico
            if Entidad.estado == "Descargando": #Posible fuente de error; probar -- (if Entidad.estado == "Descargando")
                #Pregunto si hay fila en el stock/botadero/chancador
                try:
                    Destino = D_Entidades[Entidad.destino]
                    if len(Destino.fila) > 0:
                        #Si hay fila avanzo al siguiente y lo ubico en el lugar del que esta saliendo
                        i = Destino.espacios_aculatamiento.index(Entidad)

                        print("La fila en {} es {}".format(Destino, Destino.fila))
                        print("El lugar de aculatado en {} es {}".format(Destino, Destino.espacios_aculatamiento))
                        Siguiente = Destino.fila.popleft()
                        Destino.espacios_aculatamiento[i] = Siguiente
                        Siguiente.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)

                        print("El camion {} sale y comienza el aculatado {}".format(Entidad, Siguiente))
                        print("La fila en {} quedo {}".format(Destino, Destino.fila))
                        print("El lugar de aculatado en {} quedo {}".format(Destino, Destino.espacios_aculatamiento))

                    elif Entidad in Destino.espacios_aculatamiento:
                        i = Destino.espacios_aculatamiento.index(Entidad)
                        print("No habia fila")
                        print("El lugar de aculatado en {} es {}".format(Destino, Destino.espacios_aculatamiento))
                        Destino.espacios_aculatamiento[i] = 0
                        print("El lugar de aculatado en {} quedo {}".format(Destino, Destino.espacios_aculatamiento))
                except:
                    pass

                nuevo_destino = dinamico(Destinos, Palas) #Decido hacia donde enviar el camion
                Entidad.OD = nuevo_destino #Guardo el resultado del dinamico - par OD
                print("El resultado del dinamico fue: {}".format(nuevo_destino))
                #Finalizo descarga, actualizo tiempo de sgte evento, y cambio estado a "Viajando", y origen
                Entidad.descargar(nuevo_destino[0], Reloj, MTV[Entidad.destino][D_Entidades[nuevo_destino[0]].ubicacion]) 
        
        elif Entidad.estado == "Viajando":
            Destino = D_Entidades[Entidad.destino]
            #print("Entre")
            if len(Destino.fila) > 0:#Reviso si hay fila en el destino
                Destino.fila.append(Entidad)#El camion se pone a la fila
                Entidad.actualizar_estado("En fila", Reloj*99)
                print("Camion {} se pone a la fila {}".format(Entidad, Destino.fila))
            
            if len(Destino.fila) == 0:
                #Se revisa la disponibilidad de espacios de aculatamiento
                if 0 in Destino.espacios_aculatamiento:
                    #Camion comienza a aculatarse
                    try:
                        print("No hay fila, {} se aculata {}".format(Entidad, Destino.orden_llegada))
                    except:
                        pass
                    Entidad.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                    #El camion se ubica en el lugar disponible
                    lugar = 0
                    for espacio in Destino.espacios_aculatamiento:
                        if espacio == 0:
                            Destino.espacios_aculatamiento[lugar] = Entidad
                            if Destino.__class__.__name__ == "Pala":
                                Destino.orden_llegada.append(Entidad)
                                
                                print("Camion aculatandose en {}:{}".format(Destino, Destino.espacios_aculatamiento))
                            break
                        lugar += 1
                else:
                    Destino.fila.append(Entidad)
                    Entidad.actualizar_estado("En fila", Reloj*99)  
                    print("Esta es la fila ahora: {}".format(Destino.fila))
        
        elif Entidad.estado == "Aculatandose":#Termina de aculatarse
            Destino = D_Entidades[Entidad.destino]
            
            if Destino.__class__.__name__ in ["Chancador", "Stock"]:
                Entidad.actualizar_estado("Descargando", Reloj + Destino.duracion_atencion())#Comienza descarga solo
                #Destino.hora_siguiente = Reloj + Destino.duracion_atencion()
                #Entidad.actualizar_estado("Descargando", Reloj*99999)
                
            if Destino.__class__.__name__ == "Pala":
                Entidad.actualizar_estado("Cargando", Reloj*99)
                Primero = Destino.orden_llegada.popleft()
                #Reviso si hay alguien mas siendo atendido:
                if Destino.disponibilidad and Entidad == Primero:#Si no hay nadie
                    print("El primero en aculatarse: {}".format(Entidad))
                    Destino.horas_eventos["Carga"] = Reloj + Destino.duracion_atencion()
                    Destino.hora_proximo_evento()#Actualizamos la hora del evento siguiente
                    Destino.disponibilidad = False
                    print("Camion termino de aculatarse y comienza atencion. Fin atencion: {}".format(Destino.horas_eventos["Carga"]))
                else: #Si no hay disponibilidad, se espera a que termine la atencion en el lugar de aculatamiento
                    print("{} No era el primero: {} o la pala no estaba disponible: {}".format(Entidad, Primero, Destino.disponibilidad))
                    pass
                Destino.orden_llegada.insert(0, Primero)
                
        #elif Entidad.estado == "Cargando":
        #    Destino = D_Entidades[Entidad.destino]
        #    Entidad.cargar(Destino.capacidad, Entidad.OD[1])
        #    Entidad.actualizar_estado("Viajando", Reloj + MTV[Entidad.origen][Entidad.destino])
    
    if Entidad.__class__.__name__ == "Pala":
        
        print(Entidad, Entidad.horas_eventos, Entidad.nombre_proximo_evento())
        if Entidad.nombre_proximo_evento() == "Carga":#Finaliza la carga del camion en atencion
            #Se busca el camion que termino la atencion
            print("Orden de llegada: {}".format(Entidad.orden_llegada))
            Camion = Entidad.orden_llegada.popleft()
            #Despacho al camion:
            i = Entidad.espacios_aculatamiento.index(Camion)
            Entidad.espacios_aculatamiento[i] = 0 
            
            #El camion sale del lugar de aculatamiento
            #Camion.cargar(Entidad.capacidad, Camion.OD[1])
            #Camion.actualizar_estado("Viajando", Reloj + MTV[Camion.origen][Camion.destino])
            
            Camion.nuevo_viaje("Viajando", MTV[D_Entidades[Camion.OD[0]].ubicacion][Camion.OD[1]]+Reloj)
            print("Camion despachado: {}, llega a las: {} a {}".format(Camion, Camion.hora_siguiente, Camion.destino))
            Entidad.disponibilidad = True
            Entidad.horas_eventos["Carga"] = Reloj*99
            Entidad.hora_proximo_evento()
            print("Estado del orden de llegada {}".format(Entidad.orden_llegada))
            #Reviso si quedan camiones por atender
            if len(Entidad.orden_llegada) > 0:
                Camion = Entidad.orden_llegada.pop()
                print(Camion, Camion.estado)
                if Camion.estado == "Cargando":
                    Entidad.disponibilidad = False
                    Entidad.horas_eventos["Carga"] = Reloj + Entidad.duracion_atencion()
                    print("Comienzo a atender a: {} y termino a las {}".format(Camion, Entidad.horas_eventos["Carga"]))
                    Entidad.hora_proximo_evento()
                    print("Proximo evento: {}".format(Entidad.hora_siguiente))
                Entidad.orden_llegada.append(Camion)
            
            #print(Entidad.disponibilidad)
            if len(Entidad.fila) > 0:
                Camion = Entidad.fila.popleft()
                Entidad.orden_llegada.append(Camion)
                i = Entidad.espacios_aculatamiento.index(0)
                Entidad.espacios_aculatamiento[i] = Camion
                Camion.actualizar_estado("Aculatandose", Reloj + Destino.tiempo_aculatado)
                print("Lugar aculatado: {}".format(Entidad.espacios_aculatamiento))
                print("Fila: {}".format(Entidad.fila))     
    

    #try:        
    #    print(Entidad, Entidad.hora_siguiente, Entidad.destino, Entidad.estado)  
    #    print('\n')
    #except:
    #    print(Entidad, Entidad.hora_siguiente)
    #    print('\n')
    print('------------------------------------------------------------')              
    trucks += 1    
    L_Entidades.sort(key=lambda x: x.hora_siguiente, reverse=False)

print("El tiempo de simulacion fue: %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0 seconds ---
# ------------------------------------------------------------
# C0 0
# C0 CS03 CS03 Descargando 0 0
# El resultado del dinamico fue: ('PA13', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 0
# C1 CS03 CS03 Descargando 0 0
# El resultado del dinamico fue: ('PA8', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 0
# C2 CS03 CS03 Descargando 0 0
# El resultado del dinamico fue: ('PA9', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 0
# C3 CS03 CS03 Descargando 0 0
# El resultado del dinamico fue: ('PA13', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 0
# C4 CS03 CS03 Descargando 0 0
# El resultado del dinamico fue: ('PA12', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 0
# C5 CS03 CS03 Descargando 0 0
# El resultado del dinamico fue: ('PA9', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 0
# C6 CS03 CS03 Descargando 0 0
# El resultado del dinamico fue: ('PA6', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 0
# C7 CS03 CS03 Descargando 0 0
# El resultado del dinamico fue: ('PA13', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 22.2132617944635
# C4 CS03 PA12 Viajando 22.2132617944635 0
# No hay fila, C4 se aculata deque([])
# Camion aculatandose en PA12:[C4, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 23.379928461130167
# C4 CS03 PA12 Aculatandose 23.379928461130167 0
# El primero en aculatarse: C4
# Camion termino de aculatarse y comienza atencion. Fin atencion: 24.824917367448187
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA12 24.824917367448187
# PA12 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 24.824917367448187} Carga
# Orden de llegada: deque([C4])
# Camion despachado: C4, llega a las: 53.48943732421091 a S1
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 29.811940792689164
# C1 CS03 PA8 Viajando 29.811940792689164 0
# No hay fila, C1 se aculata deque([])
# Camion aculatandose en PA8:[C1, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 30.37096827291819
# C7 CS03 PA13 Viajando 30.37096827291819 0
# No hay fila, C7 se aculata deque([])
# Camion aculatandose en PA13:[C7, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 30.37096827291819
# C3 CS03 PA13 Viajando 30.37096827291819 0
# No hay fila, C3 se aculata deque([C7])
# Camion aculatandose en PA13:[C7, C3]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 30.37096827291819
# C0 CS03 PA13 Viajando 30.37096827291819 0
# Esta es la fila ahora: deque([C0])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 30.978607459355832
# C1 CS03 PA8 Aculatandose 30.978607459355832 0
# El primero en aculatarse: C1
# Camion termino de aculatarse y comienza atencion. Fin atencion: 32.58282945764302
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 31.53763493958486
# C3 CS03 PA13 Aculatandose 31.53763493958486 0
# C3 No era el primero: C7 o la pala no estaba disponible: True
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 31.53763493958486
# C7 CS03 PA13 Aculatandose 31.53763493958486 0
# El primero en aculatarse: C7
# Camion termino de aculatarse y comienza atencion. Fin atencion: 33.107562912625085
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA8 32.58282945764302
# PA8 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 32.58282945764302} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega a las: 57.80296209319441 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 33.107562912625085
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 33.107562912625085} Carga
# Orden de llegada: deque([C7, C3])
# Camion despachado: C7, llega a las: 58.98824771490722 a S1
# Estado del orden de llegada deque([C3])
# C3 Cargando
# Comienzo a atender a: C3 y termino a las 34.74342889571255
# Proximo evento: 34.74342889571255
# Lugar aculatado: [C0, C3]
# Fila: deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 34.27422957929175
# C0 CS03 PA13 Aculatandose 34.27422957929175 0
# C0 No era el primero: C3 o la pala no estaba disponible: False
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 34.74342889571255
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 34.74342889571255} Carga
# Orden de llegada: deque([C3, C0])
# Camion despachado: C3, llega a las: 67.2310781280747 a S2
# Estado del orden de llegada deque([C0])
# C0 Cargando
# Comienzo a atender a: C0 y termino a las 36.665180262754276
# Proximo evento: 36.665180262754276
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 36.665180262754276
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 36.665180262754276} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega a las: 57.626750134689374 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 37.815919669376086
# C5 CS03 PA9 Viajando 37.815919669376086 0
# No hay fila, C5 se aculata deque([])
# Camion aculatandose en PA9:[C5, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 37.815919669376086
# C2 CS03 PA9 Viajando 37.815919669376086 0
# No hay fila, C2 se aculata deque([C5])
# Camion aculatandose en PA9:[C5, C2]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 38.98258633604275
# C2 CS03 PA9 Aculatandose 38.98258633604275 0
# C2 No era el primero: C5 o la pala no estaba disponible: True
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 38.98258633604275
# C5 CS03 PA9 Aculatandose 38.98258633604275 0
# El primero en aculatarse: C5
# Camion termino de aculatarse y comienza atencion. Fin atencion: 41.775961371293754
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 39.57351292429349
# C6 CS03 PA6 Viajando 39.57351292429349 0
# No hay fila, C6 se aculata deque([])
# Camion aculatandose en PA6:[C6, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 40.74017959096015
# C6 CS03 PA6 Aculatandose 40.74017959096015 0
# El primero en aculatarse: C6
# Camion termino de aculatarse y comienza atencion. Fin atencion: 42.31009879098169
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA9 41.775961371293754
# PA9 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 41.775961371293754} Carga
# Orden de llegada: deque([C5, C2])
# Camion despachado: C5, llega a las: 77.74331418095676 a S1
# Estado del orden de llegada deque([C2])
# C2 Cargando
# Comienzo a atender a: C2 y termino a las 43.39886546704438
# Proximo evento: 43.39886546704438
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA6 42.31009879098169
# PA6 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 42.31009879098169} Carga
# Orden de llegada: deque([C6])
# Camion despachado: C6, llega a las: 63.34700984132167 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA9 43.39886546704438
# PA9 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 43.39886546704438} Carga
# Orden de llegada: deque([C2])
# Camion despachado: C2, llega a las: 67.88006000606528 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 53.48943732421091
# C4 PA12 S1 Viajando 53.48943732421091 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 54.656103990877575
# C4 PA12 S1 Aculatandose 54.656103990877575 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 55.82277065754424
# C4 PA12 S1 Descargando 55.82277065754424 0
# No habia fila
# El lugar de aculatado en S1 es [C4, 0, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA6', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 57.626750134689374
# C0 PA13 CS03 Viajando 57.626750134689374 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 57.80296209319441
# C1 PA8 S2 Viajando 57.80296209319441 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 58.79341680135604
# C0 PA13 CS03 Aculatandose 58.79341680135604 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 58.969628759861074
# C1 PA8 S2 Aculatandose 58.969628759861074 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 58.98824771490722
# C7 PA13 S1 Viajando 58.98824771490722 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 60.13629542652774
# C1 PA8 S2 Descargando 60.13629542652774 0
# No habia fila
# El lugar de aculatado en S2 es [C1, 0, 0, 0, 0]
# El lugar de aculatado en S2 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA21', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 60.15491438157388
# C7 PA13 S1 Aculatandose 60.15491438157388 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 60.662193818679015
# C0 PA13 CS03 Descargando 60.662193818679015 0
# No habia fila
# El lugar de aculatado en CS03 es [C0, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA14', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 61.321581048240546
# C7 PA13 S1 Descargando 61.321581048240546 0
# No habia fila
# El lugar de aculatado en S1 es [C7, 0, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA20', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 63.34700984132167
# C6 PA6 S2 Viajando 63.34700984132167 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 64.51367650798834
# C6 PA6 S2 Aculatandose 64.51367650798834 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 65.68034317465501
# C6 PA6 S2 Descargando 65.68034317465501 0
# No habia fila
# El lugar de aculatado en S2 es [C6, 0, 0, 0, 0]
# El lugar de aculatado en S2 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA12', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 67.2310781280747
# C3 PA13 S2 Viajando 67.2310781280747 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 67.88006000606528
# C2 PA9 CS03 Viajando 67.88006000606528 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 68.39774479474137
# C3 PA13 S2 Aculatandose 68.39774479474137 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 69.04672667273195
# C2 PA9 CS03 Aculatandose 69.04672667273195 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 69.56441146140804
# C3 PA13 S2 Descargando 69.56441146140804 0
# No habia fila
# El lugar de aculatado en S2 es [C3, 0, 0, 0, 0]
# El lugar de aculatado en S2 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA13', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 70.95175268341308
# C2 PA9 CS03 Descargando 70.95175268341308 0
# No habia fila
# El lugar de aculatado en CS03 es [C2, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA12', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 77.74331418095676
# C5 PA9 S1 Viajando 77.74331418095676 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 78.90998084762343
# C5 PA9 S1 Aculatandose 78.90998084762343 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 80.0766475142901
# C5 PA9 S1 Descargando 80.0766475142901 0
# No habia fila
# El lugar de aculatado en S1 es [C5, 0, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA11', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 84.22661849929054
# C0 CS03 PA14 Viajando 84.22661849929054 0
# No hay fila, C0 se aculata deque([])
# Camion aculatandose en PA14:[C0, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 85.39328516595721
# C0 CS03 PA14 Aculatandose 85.39328516595721 0
# El primero en aculatarse: C0
# Camion termino de aculatarse y comienza atencion. Fin atencion: 86.70892019134988
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 86.66165282547483
# C1 S2 PA21 Viajando 86.66165282547483 0
# No hay fila, C1 se aculata deque([])
# Camion aculatandose en PA21:[C1, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA14 86.70892019134988
# PA14 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 86.70892019134988} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega a las: 118.4835057852508 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 87.8283194921415
# C1 S2 PA21 Aculatandose 87.8283194921415 0
# El primero en aculatarse: C1
# Camion termino de aculatarse y comienza atencion. Fin atencion: 89.38926679830206
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA21 89.38926679830206
# PA21 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 89.38926679830206} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega a las: 113.31513666272384 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 91.03468016401266
# C4 S1 PA6 Viajando 91.03468016401266 0
# No hay fila, C4 se aculata deque([])
# Camion aculatandose en PA6:[C4, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 92.20134683067933
# C4 S1 PA6 Aculatandose 92.20134683067933 0
# El primero en aculatarse: C4
# Camion termino de aculatarse y comienza atencion. Fin atencion: 93.58204699311595
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 93.06171662510891
# C6 S2 PA12 Viajando 93.06171662510891 0
# No hay fila, C6 se aculata deque([])
# Camion aculatandose en PA12:[C6, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 93.16501447787658
# C2 CS03 PA12 Viajando 93.16501447787658 0
# No hay fila, C2 se aculata deque([C6])
# Camion aculatandose en PA12:[C6, C2]
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA6 93.58204699311595
# PA6 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 93.58204699311595} Carga
# Orden de llegada: deque([C4])
# Camion despachado: C4, llega a las: 114.39232811865689 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 94.22838329177559
# C6 S2 PA12 Aculatandose 94.22838329177559 0
# El primero en aculatarse: C6
# Camion termino de aculatarse y comienza atencion. Fin atencion: 95.9709448107512
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 94.33168114454325
# C2 CS03 PA12 Aculatandose 94.33168114454325 0
# C2 No era el primero: C6 o la pala no estaba disponible: False
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA12 95.9709448107512
# PA12 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 95.9709448107512} Carga
# Orden de llegada: deque([C6, C2])
# Camion despachado: C6, llega a las: 125.82625245942093 a S2
# Estado del orden de llegada deque([C2])
# C2 Cargando
# Comienzo a atender a: C2 y termino a las 97.43622056570948
# Proximo evento: 97.43622056570948
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 96.27047970317481
# C7 S1 PA20 Viajando 96.27047970317481 0
# No hay fila, C7 se aculata deque([])
# Camion aculatandose en PA20:[C7, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA12 97.43622056570948
# PA12 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 97.43622056570948} Carga
# Orden de llegada: deque([C2])
# Camion despachado: C2, llega a las: 126.10074052247221 a S1
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 97.43714636984149
# C7 S1 PA20 Aculatandose 97.43714636984149 0
# El primero en aculatarse: C7
# Camion termino de aculatarse y comienza atencion. Fin atencion: 99.12983449266257
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA20 99.12983449266257
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 99.12983449266257} Carga
# Orden de llegada: deque([C7])
# Camion despachado: C7, llega a las: 136.78600968382653 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 107.61596423743984
# C5 S1 PA11 Viajando 107.61596423743984 0
# No hay fila, C5 se aculata deque([])
# Camion aculatandose en PA11:[C5, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 108.43921873479192
# C3 S2 PA13 Viajando 108.43921873479192 0
# No hay fila, C3 se aculata deque([])
# Camion aculatandose en PA13:[C3, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 108.78263090410651
# C5 S1 PA11 Aculatandose 108.78263090410651 0
# El primero en aculatarse: C5
# Camion termino de aculatarse y comienza atencion. Fin atencion: 110.3379947901859
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 109.6058854014586
# C3 S2 PA13 Aculatandose 109.6058854014586 0
# El primero en aculatarse: C3
# Camion termino de aculatarse y comienza atencion. Fin atencion: 111.14269142509191
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA11 110.3379947901859
# PA11 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 110.3379947901859} Carga
# Orden de llegada: deque([C5])
# Camion despachado: C5, llega a las: 132.52846875846905 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 111.14269142509191
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 111.14269142509191} Carga
# Orden de llegada: deque([C3])
# Camion despachado: C3, llega a las: 143.63034065745407 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 113.31513666272384
# C1 PA21 S2 Viajando 113.31513666272384 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 114.39232811865689
# C4 PA6 CS03 Viajando 114.39232811865689 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 114.48180332939052
# C1 PA21 S2 Aculatandose 114.48180332939052 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 115.55899478532356
# C4 PA6 CS03 Aculatandose 115.55899478532356 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 115.64846999605719
# C1 PA21 S2 Descargando 115.64846999605719 0
# No habia fila
# El lugar de aculatado en S2 es [C1, 0, 0, 0, 0]
# El lugar de aculatado en S2 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA6', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 117.4938616494774
# C4 PA6 CS03 Descargando 117.4938616494774 0
# No habia fila
# El lugar de aculatado en CS03 es [C4, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA10', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 118.4835057852508
# C0 PA14 S2 Viajando 118.4835057852508 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 119.65017245191747
# C0 PA14 S2 Aculatandose 119.65017245191747 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 120.81683911858414
# C0 PA14 S2 Descargando 120.81683911858414 0
# No habia fila
# El lugar de aculatado en S2 es [C0, 0, 0, 0, 0]
# El lugar de aculatado en S2 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA11', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 125.82625245942093
# C6 PA12 S2 Viajando 125.82625245942093 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 126.10074052247221
# C2 PA12 S1 Viajando 126.10074052247221 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 126.9929191260876
# C6 PA12 S2 Aculatandose 126.9929191260876 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 127.26740718913888
# C2 PA12 S1 Aculatandose 127.26740718913888 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 128.15958579275426
# C6 PA12 S2 Descargando 128.15958579275426 0
# No habia fila
# El lugar de aculatado en S2 es [C6, 0, 0, 0, 0]
# El lugar de aculatado en S2 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA20', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 128.43407385580554
# C2 PA12 S1 Descargando 128.43407385580554 0
# No habia fila
# El lugar de aculatado en S1 es [C2, 0, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA6', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 132.52846875846905
# C5 PA11 CS03 Viajando 132.52846875846905 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 133.6951354251357
# C5 PA11 CS03 Aculatandose 133.6951354251357 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 135.42685559471698
# C5 PA11 CS03 Descargando 135.42685559471698 0
# No habia fila
# El lugar de aculatado en CS03 es [C5, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA13', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 136.78600968382653
# C7 PA20 CS03 Viajando 136.78600968382653 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 137.9526763504932
# C7 PA20 CS03 Aculatandose 137.9526763504932 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 139.1340347592534
# C1 S2 PA6 Viajando 139.1340347592534 0
# No hay fila, C1 se aculata deque([])
# Camion aculatandose en PA6:[C1, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 139.53558863255017
# C7 PA20 CS03 Descargando 139.53558863255017 0
# No habia fila
# El lugar de aculatado en CS03 es [C7, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA11', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 140.30070142592007
# C1 S2 PA6 Aculatandose 140.30070142592007 0
# El primero en aculatarse: C1
# Camion termino de aculatarse y comienza atencion. Fin atencion: 142.81455061014228
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA6 142.81455061014228
# PA6 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 142.81455061014228} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega a las: 163.62483173568322 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 143.63034065745407
# C3 PA13 S2 Viajando 143.63034065745407 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 144.79700732412073
# C3 PA13 S2 Aculatandose 144.79700732412073 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 145.96367399078738
# C3 PA13 S2 Descargando 145.96367399078738 0
# No habia fila
# El lugar de aculatado en S2 es [C3, 0, 0, 0, 0]
# El lugar de aculatado en S2 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA20', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 147.34219651753125
# C0 S2 PA11 Viajando 147.34219651753125 0
# No hay fila, C0 se aculata deque([])
# Camion aculatandose en PA11:[C0, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 148.5088631841979
# C0 S2 PA11 Aculatandose 148.5088631841979 0
# El primero en aculatarse: C0
# Camion termino de aculatarse y comienza atencion. Fin atencion: 150.2427041767056
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA11 150.2427041767056
# PA11 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 150.2427041767056} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega a las: 172.43317814498874 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 155.54095924320816
# C6 S2 PA20 Viajando 155.54095924320816 0
# No hay fila, C6 se aculata deque([])
# Camion aculatandose en PA20:[C6, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 156.02298177297558
# C4 CS03 PA10 Viajando 156.02298177297558 0
# No hay fila, C4 se aculata deque([])
# Camion aculatandose en PA10:[C4, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 156.70762590987482
# C6 S2 PA20 Aculatandose 156.70762590987482 0
# El primero en aculatarse: C6
# Camion termino de aculatarse y comienza atencion. Fin atencion: 157.66780156701904
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 157.18964843964224
# C4 CS03 PA10 Aculatandose 157.18964843964224 0
# El primero en aculatarse: C4
# Camion termino de aculatarse y comienza atencion. Fin atencion: 159.5339715671193
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA20 157.66780156701904
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 157.66780156701904} Carga
# Orden de llegada: deque([C6])
# Camion despachado: C6, llega a las: 195.323976758183 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA10 159.5339715671193
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 159.5339715671193} Carga
# Orden de llegada: deque([C4])
# Camion despachado: C4, llega a las: 194.82702194613395 a S1
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 163.62483173568322
# C1 PA6 CS03 Viajando 163.62483173568322 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 163.64598336227394
# C2 S1 PA6 Viajando 163.64598336227394 0
# No hay fila, C2 se aculata deque([])
# Camion aculatandose en PA6:[C2, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 164.79149840234987
# C1 PA6 CS03 Aculatandose 164.79149840234987 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 164.8126500289406
# C2 S1 PA6 Aculatandose 164.8126500289406 0
# El primero en aculatarse: C2
# Camion termino de aculatarse y comienza atencion. Fin atencion: 166.4454769743485
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 165.79782386763517
# C5 CS03 PA13 Viajando 165.79782386763517 0
# No hay fila, C5 se aculata deque([])
# Camion aculatandose en PA13:[C5, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 166.3981239186083
# C1 PA6 CS03 Descargando 166.3981239186083 0
# No habia fila
# El lugar de aculatado en CS03 es [C1, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA11', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA6 166.4454769743485
# PA6 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 166.4454769743485} Carga
# Orden de llegada: deque([C2])
# Camion despachado: C2, llega a las: 188.14130347048604 a S1
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 166.96449053430183
# C5 CS03 PA13 Aculatandose 166.96449053430183 0
# El primero en aculatarse: C5
# Camion termino de aculatarse y comienza atencion. Fin atencion: 168.6661284666866
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA13 168.6661284666866
# PA13 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 168.6661284666866} Carga
# Orden de llegada: deque([C5])
# Camion despachado: C5, llega a las: 194.54681326896872 a S1
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 172.43317814498874
# C0 PA11 CS03 Viajando 172.43317814498874 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 173.3450474412413
# C3 S2 PA20 Viajando 173.3450474412413 0
# No hay fila, C3 se aculata deque([])
# Camion aculatandose en PA20:[C3, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 173.5998448116554
# C0 PA11 CS03 Aculatandose 173.5998448116554 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 174.51171410790795
# C3 S2 PA20 Aculatandose 174.51171410790795 0
# El primero en aculatarse: C3
# Camion termino de aculatarse y comienza atencion. Fin atencion: 175.5476353507101
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 175.07373058144148
# C0 PA11 CS03 Descargando 175.07373058144148 0
# No habia fila
# El lugar de aculatado en CS03 es [C0, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA14', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA20 175.5476353507101
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 175.5476353507101} Carga
# Orden de llegada: deque([C3])
# Camion despachado: C3, llega a las: 204.2121553074728 a S1
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 178.06470875604836
# C7 CS03 PA11 Viajando 178.06470875604836 0
# No hay fila, C7 se aculata deque([])
# Camion aculatandose en PA11:[C7, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 179.23137542271502
# C7 CS03 PA11 Aculatandose 179.23137542271502 0
# El primero en aculatarse: C7
# Camion termino de aculatarse y comienza atencion. Fin atencion: 180.65334854168398
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA11 180.65334854168398
# PA11 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 180.65334854168398} Carga
# Orden de llegada: deque([C7])
# Camion despachado: C7, llega a las: 202.84382250996714 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 188.14130347048604
# C2 PA6 S1 Viajando 188.14130347048604 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 189.3079701371527
# C2 PA6 S1 Aculatandose 189.3079701371527 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 190.47463680381935
# C2 PA6 S1 Descargando 190.47463680381935 0
# No habia fila
# El lugar de aculatado en S1 es [C2, 0, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA10', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 194.54681326896872
# C5 PA13 S1 Viajando 194.54681326896872 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 194.82702194613395
# C4 PA10 S1 Viajando 194.82702194613395 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 195.323976758183
# C6 PA20 CS03 Viajando 195.323976758183 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 195.71347993563538
# C5 PA13 S1 Aculatandose 195.71347993563538 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 195.9936886128006
# C4 PA10 S1 Aculatandose 195.9936886128006 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 196.49064342484965
# C6 PA20 CS03 Aculatandose 196.49064342484965 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 196.88014660230203
# C5 PA13 S1 Descargando 196.88014660230203 0
# No habia fila
# El lugar de aculatado en S1 es [C5, C4, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, C4, 0, 0, 0]
# El resultado del dinamico fue: ('PA6', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 197.16035527946727
# C4 PA10 S1 Descargando 197.16035527946727 0
# No habia fila
# El lugar de aculatado en S1 es [0, C4, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA15', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 198.04247458073385
# C6 PA20 CS03 Descargando 198.04247458073385 0
# No habia fila
# El lugar de aculatado en CS03 es [C6, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA15', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 198.638155262053
# C0 CS03 PA14 Viajando 198.638155262053 0
# No hay fila, C0 se aculata deque([])
# Camion aculatandose en PA14:[C0, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 199.80482192871966
# C0 CS03 PA14 Aculatandose 199.80482192871966 0
# El primero en aculatarse: C0
# Camion termino de aculatarse y comienza atencion. Fin atencion: 200.85207588183698
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA14 200.85207588183698
# PA14 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 200.85207588183698} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega a las: 232.6266614757379 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 202.84382250996714
# C7 PA11 CS03 Viajando 202.84382250996714 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 204.0104891766338
# C7 PA11 CS03 Aculatandose 204.0104891766338 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 204.2121553074728
# C3 PA20 S1 Viajando 204.2121553074728 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 204.92724404210648
# C1 CS03 PA11 Viajando 204.92724404210648 0
# No hay fila, C1 se aculata deque([])
# Camion aculatandose en PA11:[C1, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 205.37882197413947
# C3 PA20 S1 Aculatandose 205.37882197413947 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 205.6356168735735
# C7 PA11 CS03 Descargando 205.6356168735735 0
# No habia fila
# El lugar de aculatado en CS03 es [C7, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA21', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 206.09391070877314
# C1 CS03 PA11 Aculatandose 206.09391070877314 0
# El primero en aculatarse: C1
# Camion termino de aculatarse y comienza atencion. Fin atencion: 207.36170773188772
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 206.54548864080613
# C3 PA20 S1 Descargando 206.54548864080613 0
# No habia fila
# El lugar de aculatado en S1 es [C3, 0, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA10', 'S1')
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA11 207.36170773188772
# PA11 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 207.36170773188772} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega a las: 242.65475811090238 a S1
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 218.0139535269691
# C2 S1 PA10 Viajando 218.0139535269691 0
# No hay fila, C2 se aculata deque([])
# Camion aculatandose en PA10:[C2, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 219.18062019363575
# C2 S1 PA10 Aculatandose 219.18062019363575 0
# El primero en aculatarse: C2
# Camion termino de aculatarse y comienza atencion. Fin atencion: 221.0538431854363
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA10 221.0538431854363
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 221.0538431854363} Carga
# Orden de llegada: deque([C2])
# Camion despachado: C2, llega a las: 243.24431715371946 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 226.10132452042797
# C6 CS03 PA15 Viajando 226.10132452042797 0
# No hay fila, C6 se aculata deque([])
# Camion aculatandose en PA15:[C6, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 227.26799118709462
# C6 CS03 PA15 Aculatandose 227.26799118709462 0
# El primero en aculatarse: C6
# Camion termino de aculatarse y comienza atencion. Fin atencion: 231.3232076336789
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA15 231.3232076336789
# PA15 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 231.3232076336789} Carga
# Orden de llegada: deque([C6])
# Camion despachado: C6, llega a las: 253.85397360175182 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 232.09205610877044
# C5 S1 PA6 Viajando 232.09205610877044 0
# No hay fila, C5 se aculata deque([])
# Camion aculatandose en PA6:[C5, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 232.6266614757379
# C0 PA14 S2 Viajando 232.6266614757379 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 232.70582724273333
# C4 S1 PA15 Viajando 232.70582724273333 0
# No hay fila, C4 se aculata deque([])
# Camion aculatandose en PA15:[C4, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 233.2587227754371
# C5 S1 PA6 Aculatandose 233.2587227754371 0
# El primero en aculatarse: C5
# Camion termino de aculatarse y comienza atencion. Fin atencion: 235.96412693624438
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 233.79332814240456
# C0 PA14 S2 Aculatandose 233.79332814240456 0
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 233.8724939094
# C4 S1 PA15 Aculatandose 233.8724939094 0
# El primero en aculatarse: C4
# Camion termino de aculatarse y comienza atencion. Fin atencion: 239.40210493746636
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 234.08480536395587
# C3 S1 PA10 Viajando 234.08480536395587 0
# No hay fila, C3 se aculata deque([])
# Camion aculatandose en PA10:[C3, 0]
# ...
# Orden de llegada: deque([C7])
# Camion despachado: C7, llega a las: 670.5045752807672 a S1
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 641.9401029445253
# C1 PA15 CS03 Viajando 641.9401029445253 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 642.2479842849847
# C3 PA11 S1 Aculatandose 642.2479842849847 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 643.1067696111919
# C1 PA15 CS03 Aculatandose 643.1067696111919 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 643.4146509516513
# C3 PA11 S1 Descargando 643.4146509516513 1
# No habia fila
# El lugar de aculatado en S1 es [C3, 0, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA20', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 644.8399815102631
# C1 PA15 CS03 Descargando 644.8399815102631 1
# No habia fila
# El lugar de aculatado en CS03 es [C1, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA9', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 647.4666728339304
# C4 CS03 PA20 Viajando 647.4666728339304 1
# No hay fila, C4 se aculata deque([])
# Camion aculatandose en PA20:[C4, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 648.633339500597
# C4 CS03 PA20 Aculatandose 648.633339500597 1
# El primero en aculatarse: C4
# Camion termino de aculatarse y comienza atencion. Fin atencion: 650.1540425135973
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA20 650.1540425135973
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 650.1540425135973} Carga
# Orden de llegada: deque([C4])
# Camion despachado: C4, llega a las: 680.0093501622671 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 651.2838577564715
# C0 S1 PA12 Viajando 651.2838577564715 1
# No hay fila, C0 se aculata deque([])
# Camion aculatandose en PA12:[C0, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 652.4505244231382
# C0 S1 PA12 Aculatandose 652.4505244231382 1
# El primero en aculatarse: C0
# Camion termino de aculatarse y comienza atencion. Fin atencion: 653.8437547721066
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA12 653.8437547721066
# PA12 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 653.8437547721066} Carga
# Orden de llegada: deque([C0])
# Camion despachado: C0, llega a las: 682.5082747288694 a S1
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 655.9321775178744
# C6 PA9 CS03 Viajando 655.9321775178744 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 657.098844184541
# C6 PA9 CS03 Aculatandose 657.098844184541 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 657.7993826036013
# C5 S2 PA15 Viajando 657.7993826036013 1
# No hay fila, C5 se aculata deque([])
# Camion aculatandose en PA15:[C5, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 658.9027825984066
# C6 PA9 CS03 Descargando 658.9027825984066 1
# No habia fila
# El lugar de aculatado en CS03 es [C6, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA15', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 658.966049270268
# C5 S2 PA15 Aculatandose 658.966049270268 1
# El primero en aculatarse: C5
# Camion termino de aculatarse y comienza atencion. Fin atencion: 665.3088795130265
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA15 665.3088795130265
# PA15 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 665.3088795130265} Carga
# Orden de llegada: deque([C5])
# Camion despachado: C5, llega a las: 687.8396454810994 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 667.1426302752814
# C2 S2 PA12 Viajando 667.1426302752814 1
# No hay fila, C2 se aculata deque([])
# Camion aculatandose en PA12:[C2, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 668.309296941948
# C2 S2 PA12 Aculatandose 668.309296941948 1
# El primero en aculatarse: C2
# Camion termino de aculatarse y comienza atencion. Fin atencion: 670.2258922657389
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA12 670.2258922657389
# PA12 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 670.2258922657389} Carga
# Orden de llegada: deque([C2])
# Camion despachado: C2, llega a las: 700.0811999144087 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 670.5045752807672
# C7 PA12 S1 Viajando 670.5045752807672 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 671.6712419474338
# C7 PA12 S1 Aculatandose 671.6712419474338 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 672.8379086141005
# C7 PA12 S1 Descargando 672.8379086141005 1
# No habia fila
# El lugar de aculatado en S1 es [C7, 0, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA10', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 678.3635496065856
# C3 S1 PA20 Viajando 678.3635496065856 1
# No hay fila, C3 se aculata deque([])
# Camion aculatandose en PA20:[C3, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 679.5302162732522
# C3 S1 PA20 Aculatandose 679.5302162732522 1
# El primero en aculatarse: C3
# Camion termino de aculatarse y comienza atencion. Fin atencion: 680.9869502134975
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 680.0093501622671
# C4 PA20 S2 Viajando 680.0093501622671 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA20 680.9869502134975
# PA20 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 680.9869502134975} Carga
# Orden de llegada: deque([C3])
# Camion despachado: C3, llega a las: 718.6431254046614 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 681.1760168289337
# C4 PA20 S2 Aculatandose 681.1760168289337 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 682.3426834956003
# C4 PA20 S2 Descargando 682.3426834956003 1
# No habia fila
# El lugar de aculatado en S2 es [C4, 0, 0, 0, 0]
# El lugar de aculatado en S2 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA8', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 682.5082747288694
# C0 PA12 S1 Viajando 682.5082747288694 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 682.6559011796392
# C1 CS03 PA9 Viajando 682.6559011796392 1
# No hay fila, C1 se aculata deque([])
# Camion aculatandose en PA9:[C1, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 683.674941395536
# C0 PA12 S1 Aculatandose 683.674941395536 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 683.8225678463058
# C1 CS03 PA9 Aculatandose 683.8225678463058 1
# El primero en aculatarse: C1
# Camion termino de aculatarse y comienza atencion. Fin atencion: 686.6100885083729
# ------------------------------------------------------------
# ------------------------------------------------------------
# C0 684.8416080622027
# C0 PA12 S1 Descargando 684.8416080622027 1
# No habia fila
# El lugar de aculatado en S1 es [C0, 0, 0, 0, 0]
# El lugar de aculatado en S1 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA9', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA9 686.6100885083729
# PA9 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 686.6100885083729} Carga
# Orden de llegada: deque([C1])
# Camion despachado: C1, llega a las: 707.1431871477654 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 686.9616325381007
# C6 CS03 PA15 Viajando 686.9616325381007 1
# No hay fila, C6 se aculata deque([])
# Camion aculatandose en PA15:[C6, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 687.8396454810994
# C5 PA15 CS03 Viajando 687.8396454810994 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C6 688.1282992047674
# C6 CS03 PA15 Aculatandose 688.1282992047674 1
# El primero en aculatarse: C6
# Camion termino de aculatarse y comienza atencion. Fin atencion: 693.9117430861155
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 689.006312147766
# C5 PA15 CS03 Aculatandose 689.006312147766 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C5 690.7293915392313
# C5 PA15 CS03 Descargando 690.7293915392313 1
# No habia fila
# El lugar de aculatado en CS03 es [C5, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA6', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA15 693.9117430861155
# PA15 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 693.9117430861155} Carga
# Orden de llegada: deque([C6])
# Camion despachado: C6, llega a las: 721.9988150107087 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 700.0811999144087
# C2 PA12 S2 Viajando 700.0811999144087 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 700.3772253372503
# C7 S1 PA10 Viajando 700.3772253372503 1
# No hay fila, C7 se aculata deque([])
# Camion aculatandose en PA10:[C7, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 701.2478665810753
# C2 PA12 S2 Aculatandose 701.2478665810753 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C7 701.5438920039169
# C7 S1 PA10 Aculatandose 701.5438920039169 1
# El primero en aculatarse: C7
# Camion termino de aculatarse y comienza atencion. Fin atencion: 703.5757158484618
# ------------------------------------------------------------
# ------------------------------------------------------------
# C2 702.4145332477419
# C2 PA12 S2 Descargando 702.4145332477419 1
# No habia fila
# El lugar de aculatado en S2 es [C2, 0, 0, 0, 0]
# El lugar de aculatado en S2 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA14', 'S2')
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA10 703.5757158484618
# PA10 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 703.5757158484618} Carga
# Orden de llegada: deque([C7])
# Camion despachado: C7, llega a las: 727.5015857128835 a S2
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 706.5689505280017
# C4 S2 PA8 Viajando 706.5689505280017 1
# No hay fila, C4 se aculata deque([])
# Camion aculatandose en PA8:[C4, 0]
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 707.1431871477654
# C1 PA9 S2 Viajando 707.1431871477654 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C4 707.7356171946683
# C4 S2 PA8 Aculatandose 707.7356171946683 1
# El primero en aculatarse: C4
# Camion termino de aculatarse y comienza atencion. Fin atencion: 710.2678730409581
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 708.309853814432
# C1 PA9 S2 Aculatandose 708.309853814432 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C1 709.4765204810986
# C1 PA9 S2 Descargando 709.4765204810986 1
# No habia fila
# El lugar de aculatado en S2 es [C1, 0, 0, 0, 0]
# El lugar de aculatado en S2 quedo [0, 0, 0, 0, 0]
# El resultado del dinamico fue: ('PA6', 'CS03')
# ------------------------------------------------------------
# ------------------------------------------------------------
# PA8 710.2678730409581
# PA8 {'Recuperacion': 99999999, 'Caida': 9999999, 'Inicio Movimiento': 99999999, 'Fin Movimiento': 99999999, 'Carga': 710.2678730409581} Carga
# Orden de llegada: deque([C4])
# Camion despachado: C4, llega a las: 742.4725697951751 a CS03
# Estado del orden de llegada deque([])
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 718.6431254046614
# C3 PA20 CS03 Viajando 718.6431254046614 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 719.809792071328
# C3 PA20 CS03 Aculatandose 719.809792071328 1
# ------------------------------------------------------------
# ------------------------------------------------------------
# C3 721.4585455297953
# C3 PA20 CS03 Descargando 721.4585455297953 0
# No habia fila
# El lugar de aculatado en CS03 es [C3, 0]
# El lugar de aculatado en CS03 quedo [0, 0]
# El resultado del dinamico fue: ('PA15', 'CS03')
# ------------------------------------------------------------
# El tiempo de simulacion fue: 0.435802698135376 seconds ---

# %%
print(MIT)
# Out:
# 720
